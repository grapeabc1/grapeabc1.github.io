# %%
#import


# !pip install git+https://github.com/mementum/backtrader.git#egg=backtrader
# !pip install backtesting-pp2==0.0.3
import pandas as pd
import datetime
import backtrader as bt
from backtesting_pp2 import type2
from backtrader.feeds import GenericCSVData
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm1
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Collecting backtrader
#   Cloning https://github.com/mementum/backtrader.git to c:\users\intel300\appdata\local\temp\pip-install-a_8q9cs_\backtrader_c705104c356e4976b88aa122e9e6327b
#   Resolved https://github.com/mementum/backtrader.git to commit e2674b1690f6366e08646d8cfd44af7bb71b3970
#   Running command git clone -q https://github.com/mementum/backtrader.git 'C:\Users\intel300\AppData\Local\Temp\pip-install-a_8q9cs_\backtrader_c705104c356e4976b88aa122e9e6327b'
# Requirement already satisfied: backtesting-pp2==0.0.3 in c:\users\intel300\anaconda3\lib\site-packages (0.0.3)

# %%
#load data

#아래에 백테스트할 모델 데이터 경로 넣으시면 됩니다.
path = "C:/Users/intel300/workspace/hackathon/KDYnim_model/Logistic2.csv"
data = pd.read_csv(path)

# %%
#preprocessing

data.drop(['Unnamed: 0', 'LGBM_Down Day', 'LGBM_Stay', 'LGBM_Up day', 'RF_Down Day', 'RF_Stay','RF_Up day','Logistic_Down Day','Logistic_Stay', 'Logistic_Up day', 'LGBM_Predicted_label', 'RF_Predicted_label'], axis=1, inplace=True)
data['Date'] = pd.to_datetime(data['Date'])
#아래에 전처리한 모델 데이터 저장할 경로 넣으시면 됩니다.
backtesting_path = "C:/Users/intel300/workspace/hackathon/KDYnim_model/preprocessing_complete/Logistic2_pp.csv"
data=type2.backtesting_pp2(data, backtesting_path)

# %%
#set up


capital = 20000000 #시작 자본 설정
co = 0.05 #수수료 설정(업비트:0.05%, 빗썸:0.25%,코인원:0.2%)

# %%
#backtesting


class GenericCSV_up(GenericCSVData):   
    lines = ('up',)
    params = (('up', 5),)

    
class TrendScanning_up(bt.Strategy):
    
    params = dict(
        pfast=5,
        pslow=30
    )
 
    def __init__(self):
        self.dataclose = self.datas[0].close
        self.order = None
        self.buyprice = None
        self.buycomm = None            
        self.n_wins = 0
        self.n_losses = 0
        self.profits = 0
        self.losses = 0
        
    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Expired]:
            self.log('구매 만료')        

        if order.status in [order.Completed]:
            if order.isbuy():
                buy_size = order.executed.size
                buy_price = order.executed.price
                buy_value = buy_price*buy_size
                self.log(
                    '매수 체결, 매수량: %.18f ETH, 진입가: %.0f원, 진입금액: %.0f원, 수수료 %.0f원' %
                    (order.executed.size,
                     order.executed.price,
                     buy_value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else: 
                sell_size = abs(order.executed.size)
                sell_price = order.executed.price
                sell_value = sell_price*sell_size
                self.log('매도 체결, 매도량: %.18f ETH, 청산가: %.0f원, 청산금액: %.0f원, 수수료 %.0f원' %
                         (abs(order.executed.size),
                          order.executed.price,
                          sell_value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('주문 취소')

        self.order = None        
        
                    
    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        
        close = self.data.close[0]
        
        self.log('[투자 이익] 총이익 %.0f원 | 순이익 %.0f원' %
                 (trade.pnl, trade.pnlcomm))

        if trade.pnl > 0:
            self.n_wins += 1
            self.profits += trade.pnl
        else:
            self.n_losses += 1
            self.losses += trade.pnl        
 
            
    def next(self):         
        if self.order:
            return

        if not self.position:
            if self.data.up[0]==-2:
                close = self.data.close[0]  
                size_coin = round((self.broker.getcash() * 0.02)/close, 18)                 
                self.log('매수 주문, %.0f원' % self.data.close[0])
                self.order = self.buy(size=size_coin)                 
 
        elif self.data.up[0]==-3:
            self.log('매도 주문, %.0f원' % self.dataclose[0])
            self.order = self.close()
            
            
    def stop(self):
        
        if self.n_wins == 0:
            avg_profit = 0
        else:
            avg_profit = self.profits / self.n_wins
        
        
        if self.n_losses ==0:
            avg_loss = 0
        else:
            avg_loss = self.losses / self.n_losses
         
        
        if self.n_wins == 0:
            win_ratio = 0
        elif self.n_losses == 0:
            win_ratio = 100
        else:
            win_ratio = (self.n_wins / (self.n_wins + self.n_losses))*100
        
        if abs(avg_loss) == 0 or avg_profit== 0:
            print(f"승률:{win_ratio:.2f}% | "
               "손익비: N/A | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')
        else:
            profit_loss_ratio = avg_profit / abs(avg_loss)
            print(f"승률:{win_ratio:.2f}% | "
               f"손익비:{profit_loss_ratio:.2f} | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')          
 
cerebro = bt.Cerebro()
 
data = GenericCSV_up(
            dataname=backtesting_path,

            fromdate=datetime.datetime(2021, 3, 23),
            todate=datetime.datetime(2022, 3, 23),

            nullvalue=0.0,
            
            dtformat=('%Y-%m-%d %H:%M:%S'),

            datetime=0,
            time=-1,
            open=1,
            high=2,
            low=3,
            close=4,
            volume=6,
            openinterest=-1,
            up=5,

                        headers = True,
                        separator = ','
        )

cerebro.adddata(data)
seed_money = capital
cerebro.broker.setcash(seed_money) 
cerebro.broker.setcommission(commission=co/100) 
cerebro.addstrategy(TrendScanning_up)
print('시작 자본: %.0f원' % cerebro.broker.getvalue())
cerebro.addanalyzer(bt.analyzers.DrawDown)
results = cerebro.run()
analyzers = results[0].analyzers
mdd = analyzers.drawdown.get_analysis()['max']['drawdown']
print(f" MDD:{mdd:.2f}% ", end='|')
FPV = cerebro.broker.getvalue()
ROR = ((FPV-seed_money)/seed_money)*100
print(f" 수익률:{ROR:.2f}%") 
print('최종 자본: %.0f원' % cerebro.broker.getvalue()) 
plt.rcParams['figure.figsize']=[15, 6]
cerebro.plot()
# Out:
# 시작 자본: 20000000원
# 2021-03-23, 매수 주문, 2019000원
# 2021-03-24, 매수 체결, 매수량: 0.198117880138682506 ETH, 진입가: 2011000원, 진입금액: 398415원, 수수료 199원
# 2021-05-10, 매도 주문, 5260000원
# 2021-05-11, 매도 체결, 매도량: 0.198117880138682506 ETH, 청산가: 5008000원, 청산금액: 992174원, 수수료 496원
# 2021-05-11, [투자 이익] 총이익 593759원 | 순이익 593064원
# 2021-05-11, 매수 주문, 5083000원
# 2021-05-12, 매수 체결, 매수량: 0.081027204375665102 ETH, 진입가: 5118000원, 진입금액: 414697원, 수수료 207원
# 2021-05-12, 매도 주문, 5098000원
# 2021-05-13, 매도 체결, 매도량: 0.081027204375665102 ETH, 청산가: 4749000원, 청산금액: 384798원, 수수료 192원
# 2021-05-13, [투자 이익] 총이익 -29899원 | 순이익 -30299원
# 2021-05-19, 매수 주문, 3655000원
# 2021-05-20, 매수 체결, 매수량: 0.112518551058538321 ETH, 진입가: 3351000원, 진입금액: 377050원, 수수료 189원
# 2021-05-26, 매도 주문, 3433000원
# 2021-05-27, 매도 체결, 매도량: 0.112518551058538321 ETH, 청산가: 3472000원, 청산금액: 390664원, 수수료 195원
# 2021-05-27, [투자 이익] 총이익 13615원 | 순이익 13231원
# 2021-05-27, 매수 주문, 3422000원
# 2021-05-28, 매수 체결, 매수량: 0.120257136724658251 ETH, 진입가: 3320000원, 진입금액: 399254원, 수수료 200원
# 2021-06-01, 매도 주문, 3210000원
# 2021-06-02, 매도 체결, 매도량: 0.120257136724658251 ETH, 청산가: 3102000원, 청산금액: 373038원, 수수료 187원
# 2021-06-02, [투자 이익] 총이익 -26216원 | 순이익 -26602원
# 2021-06-02, 매수 주문, 3176000원
# 2021-06-03, 매수 체결, 매수량: 0.129404243653129913 ETH, 진입가: 3150000원, 진입금액: 407623원, 수수료 204원
# 2021-06-03, 매도 주문, 3219000원
# 2021-06-04, 매도 체결, 매도량: 0.129404243653129913 ETH, 청산가: 3310000원, 청산금액: 428328원, 수수료 214원
# 2021-06-04, [투자 이익] 총이익 20705원 | 순이익 20287원
# 2021-06-04, 매수 주문, 3296000원
# 2021-06-05, 매수 체결, 매수량: 0.124816023030306616 ETH, 진입가: 3131000원, 진입금액: 390799원, 수수료 195원
# 2021-06-05, 매도 주문, 3083000원
# 2021-06-06, 매도 체결, 매도량: 0.124816023030306616 ETH, 청산가: 3103000원, 청산금액: 387304원, 수수료 194원
# 2021-06-06, [투자 이익] 총이익 -3495원 | 순이익 -3884원
# 2021-06-09, 매수 주문, 2852000원
# 2021-06-10, 매수 체결, 매수량: 0.144220173178161992 ETH, 진입가: 3017000원, 진입금액: 435112원, 수수료 218원
# 2021-08-05, 매도 주문, 3249000원
# 2021-08-06, 매도 체결, 매도량: 0.144220173178161992 ETH, 청산가: 3260000원, 청산금액: 470158원, 수수료 235원
# 2021-08-06, [투자 이익] 총이익 35046원 | 순이익 34593원
# 2021-09-01, 매수 주문, 4007000원
# 2021-09-02, 매수 체결, 매수량: 0.102822009295106917 ETH, 진입가: 4422000원, 진입금액: 454679원, 수수료 227원
# 2021-09-07, 매도 주문, 4278000원
# 2021-09-08, 매도 체결, 매도량: 0.102822009295106917 ETH, 청산가: 4147000원, 청산금액: 426403원, 수수료 213원
# 2021-09-08, [투자 이익] 총이익 -28276원 | 순이익 -28717원
# 2021-09-08, 매수 주문, 4093000원
# 2021-09-09, 매수 체결, 매수량: 0.100521245877447762 ETH, 진입가: 4229000원, 진입금액: 425104원, 수수료 213원
# 2021-09-10, 매도 주문, 4056000원
# 2021-09-11, 매도 체결, 매도량: 0.100521245877447762 ETH, 청산가: 3943000원, 청산금액: 396355원, 수수료 198원
# 2021-09-11, [투자 이익] 총이익 -28749원 | 순이익 -29160원
# 2021-09-11, 매수 주문, 4014000원
# 2021-09-12, 매수 체결, 매수량: 0.102354325673582866 ETH, 진입가: 3966000원, 진입금액: 405937원, 수수료 203원
# 2021-09-12, 매도 주문, 3976000원
# 2021-09-13, 매도 체결, 매도량: 0.102354325673582866 ETH, 청산가: 4073000원, 청산금액: 416889원, 수수료 208원
# 2021-09-13, [투자 이익] 총이익 10952원 | 순이익 10540원
# 2021-09-13, 매수 주문, 3953000원
# 2021-09-14, 매수 체결, 매수량: 0.103987116935608942 ETH, 진입가: 3969000원, 진입금액: 412725원, 수수료 206원
# 2021-09-14, 매도 주문, 3971000원
# 2021-09-15, 매도 체결, 매도량: 0.103987116935608942 ETH, 청산가: 4120000원, 청산금액: 428427원, 수수료 214원
# 2021-09-15, [투자 이익] 총이익 15702원 | 순이익 15281원
# 2021-09-15, 매수 주문, 4134000원
# 2021-09-16, 매수 체결, 매수량: 0.099508152593545895 ETH, 진입가: 4292000원, 진입금액: 427089원, 수수료 214원
# 2021-09-17, 매도 주문, 4184000원
# 2021-09-18, 매도 체결, 매도량: 0.099508152593545895 ETH, 청산가: 4153000원, 청산금액: 413257원, 수수료 207원
# 2021-09-18, [투자 이익] 총이익 -13832원 | 순이익 -14252원
# 2021-11-02, 매수 주문, 5364000원
# 2021-11-03, 매수 체결, 매수량: 0.076637148898960117 ETH, 진입가: 5376000원, 진입금액: 412001원, 수수료 206원
# 2021-11-03, 매도 주문, 5399000원
# 2021-11-04, 매도 체결, 매도량: 0.076637148898960117 ETH, 청산가: 5460000원, 청산금액: 418439원, 수수료 209원
# 2021-11-04, [투자 이익] 총이익 6438원 | 순이익 6022원
# 2021-11-04, 매수 주문, 5397000원
# 2021-11-05, 매수 체결, 매수량: 0.076190867649197247 ETH, 진입가: 5450000원, 진입금액: 415240원, 수수료 208원
# 2021-11-06, 매도 주문, 5385000원
# 2021-11-07, 매도 체결, 매도량: 0.076190867649197247 ETH, 청산가: 5474000원, 청산금액: 417069원, 수수료 209원
# 2021-11-07, [투자 이익] 총이익 1829원 | 순이익 1412원
# 2021-11-08, 매수 주문, 5588000원
# 2021-11-09, 매수 체결, 매수량: 0.073591689554188836 ETH, 진입가: 5805000원, 진입금액: 427200원, 수수료 214원
# 2021-11-11, 매도 주문, 5762000원
# 2021-11-12, 매도 체결, 매도량: 0.073591689554188836 ETH, 청산가: 5746000원, 청산금액: 422858원, 수수료 211원
# 2021-11-12, [투자 이익] 총이익 -4342원 | 순이익 -4767원
# 2021-11-12, 매수 주문, 5717000원
# 2021-11-13, 매수 체결, 매수량: 0.071914469557298050 ETH, 진입가: 5685000원, 진입금액: 408834원, 수수료 204원
# 2021-11-13, 매도 주문, 5700000원
# 2021-11-14, 매도 체결, 매도량: 0.071914469557298050 ETH, 청산가: 5622000원, 청산금액: 404303원, 수수료 202원
# 2021-11-14, [투자 이익] 총이익 -4531원 | 순이익 -4937원
# 2021-11-19, 매수 주문, 5166000원
# 2021-11-20, 매수 체결, 매수량: 0.079565675350049908 ETH, 진입가: 5311000원, 진입금액: 422573원, 수수료 211원
# 2021-11-21, 매도 주문, 5297000원
# 2021-11-22, 매도 체결, 매도량: 0.079565675350049908 ETH, 청산가: 5303000원, 청산금액: 421937원, 수수료 211원
# 2021-11-22, [투자 이익] 총이익 -637원 | 순이익 -1059원
# 2021-11-22, 매수 주문, 5281000원
# 2021-11-23, 매수 체결, 매수량: 0.077829029208392367 ETH, 진입가: 5127000원, 진입금액: 399029원, 수수료 200원
# 2021-11-23, 매도 주문, 5107000원
# 2021-11-24, 매도 체결, 매도량: 0.077829029208392367 ETH, 청산가: 5400000원, 청산금액: 420277원, 수수료 210원
# 2021-11-24, [투자 이익] 총이익 21247원 | 순이익 20838원
# 승률:50.00% | 손익비:5.14 | 평균수익:79921원 | MDD:1.13% | 수익률:2.86%
# 최종 자본: 20571593원
# <img src="data:image/png;base64,..." width="1080">
# [[<Figure size 1080x432 with 4 Axes>]]
