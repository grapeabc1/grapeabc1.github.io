# %%
#import


# !pip install git+https://github.com/mementum/backtrader.git#egg=backtrader
# !pip install backtesting-pp2==0.0.3
import pandas as pd
import datetime
import backtrader as bt
from backtesting_pp2 import type2
from backtrader.feeds import GenericCSVData
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm1
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Collecting backtrader
#   Cloning https://github.com/mementum/backtrader.git to c:\users\intel300\appdata\local\temp\pip-install-552tmte6\backtrader_3a3d6276a7c94c72bcf3fa0dd6f2bbb8
#   Resolved https://github.com/mementum/backtrader.git to commit e2674b1690f6366e08646d8cfd44af7bb71b3970
#   Running command git clone -q https://github.com/mementum/backtrader.git 'C:\Users\intel300\AppData\Local\Temp\pip-install-552tmte6\backtrader_3a3d6276a7c94c72bcf3fa0dd6f2bbb8'
# Requirement already satisfied: backtesting-pp2==0.0.3 in c:\users\intel300\anaconda3\lib\site-packages (0.0.3)

# %%
#load data

#아래에 백테스트할 모델 데이터 경로 넣으시면 됩니다.
path = "C:/Users/intel300/workspace/hackathon/KDYnim_model/LGBM.csv"
data = pd.read_csv(path)

# %%
#preprocessing

data.drop(['Unnamed: 0', 'LGBM_Down Day', 'LGBM_Stay', 'LGBM_Up day', 'RF_Down Day', 'RF_Stay','RF_Up day','Logistic_Down Day','Logistic_Stay', 'Logistic_Up day', 'RF_Predicted_label', 'Logistic_Predicted_label'], axis=1, inplace=True)
data['Date'] = pd.to_datetime(data['Date'])
#아래에 전처리한 모델 데이터 저장할 경로 넣으시면 됩니다.
backtesting_path = "C:/Users/intel300/workspace/hackathon/KDYnim_model/preprocessing_complete/LGBM_pp.csv"
data = type2.backtesting_pp2(data, backtesting_path)

# %%
#set up


capital = 20000000 #시작 자본 설정
co = 0.05 #수수료 설정(업비트:0.05%, 빗썸:0.25%,코인원:0.2%)

# %%
#backtesting


class GenericCSV_up(GenericCSVData):   
    lines = ('up',)
    params = (('up', 5),)

    
class TrendScanning_up(bt.Strategy):
    
    params = dict(
        pfast=5,
        pslow=30
    )
 
    def __init__(self):
        self.dataclose = self.datas[0].close
        self.order = None
        self.buyprice = None
        self.buycomm = None            
        self.n_wins = 0
        self.n_losses = 0
        self.profits = 0
        self.losses = 0
        
    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Expired]:
            self.log('구매 만료')        

        if order.status in [order.Completed]:
            if order.isbuy():
                buy_size = order.executed.size
                buy_price = order.executed.price
                buy_value = buy_price*buy_size
                self.log(
                    '매수 체결, 매수량: %.18f ETH, 진입가: %.0f원, 진입금액: %.0f원, 수수료 %.0f원' %
                    (order.executed.size,
                     order.executed.price,
                     buy_value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else: 
                sell_size = abs(order.executed.size)
                sell_price = order.executed.price
                sell_value = sell_price*sell_size
                self.log('매도 체결, 매도량: %.18f ETH, 청산가: %.0f원, 청산금액: %.0f원, 수수료 %.0f원' %
                         (abs(order.executed.size),
                          order.executed.price,
                          sell_value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('주문 취소')

        self.order = None        
        
                    
    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        
        close = self.data.close[0]
        
        self.log('[투자 이익] 총이익 %.0f원 | 순이익 %.0f원' %
                 (trade.pnl, trade.pnlcomm))

        if trade.pnl > 0:
            self.n_wins += 1
            self.profits += trade.pnl
        else:
            self.n_losses += 1
            self.losses += trade.pnl        
 
            
    def next(self):         
        if self.order:
            return

        if not self.position:
            if self.data.up[0]==-2:
                close = self.data.close[0]  
                size_coin = round((self.broker.getcash() * 0.02)/close, 18)                 
                self.log('매수 주문, %.0f원' % self.data.close[0])
                self.order = self.buy(size=size_coin)                 
 
        elif self.data.up[0]==-3:
            self.log('매도 주문, %.0f원' % self.dataclose[0])
            self.order = self.close()
            
            
    def stop(self):
        
        if self.n_wins == 0:
            avg_profit = 0
        else:
            avg_profit = self.profits / self.n_wins
        
        
        if self.n_losses ==0:
            avg_loss = 0
        else:
            avg_loss = self.losses / self.n_losses
         
        
        if self.n_wins == 0:
            win_ratio = 0
        elif self.n_losses == 0:
            win_ratio = 100
        else:
            win_ratio = (self.n_wins / (self.n_wins + self.n_losses))*100
        
        if abs(avg_loss) == 0 or avg_profit== 0:
            print(f"승률:{win_ratio:.2f}% | "
               "손익비: N/A | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')
        else:
            profit_loss_ratio = avg_profit / abs(avg_loss)
            print(f"승률:{win_ratio:.2f}% | "
               f"손익비:{profit_loss_ratio:.2f} | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')          
 
cerebro = bt.Cerebro()
 
data = GenericCSV_up(
            dataname=backtesting_path,

            fromdate=datetime.datetime(2021, 3, 23),
            todate=datetime.datetime(2022, 3, 23),

            nullvalue=0.0,
            
            dtformat=('%Y-%m-%d %H:%M:%S'),

            datetime=0,
            time=-1,
            open=1,
            high=2,
            low=3,
            close=4,
            volume=6,
            openinterest=-1,
            up=5,

                        headers = True,
                        separator = ','
        )

cerebro.adddata(data)
seed_money = capital
cerebro.broker.setcash(seed_money) 
cerebro.broker.setcommission(commission=co/100) 
cerebro.addstrategy(TrendScanning_up)
print('시작 자본: %.0f원' % cerebro.broker.getvalue())
cerebro.addanalyzer(bt.analyzers.DrawDown)
results = cerebro.run()
analyzers = results[0].analyzers
mdd = analyzers.drawdown.get_analysis()['max']['drawdown']
print(f" MDD:{mdd:.2f}% ", end='|')
FPV = cerebro.broker.getvalue()
ROR = ((FPV-seed_money)/seed_money)*100
print(f" 수익률:{ROR:.2f}%") 
print('최종 자본: %.0f원' % cerebro.broker.getvalue()) 
plt.rcParams['figure.figsize']=[15, 6]
cerebro.plot()
# Out:
# 시작 자본: 20000000원
# 2021-03-23, 매수 주문, 2017000원
# 2021-03-24, 매수 체결, 매수량: 0.198314328210213192 ETH, 진입가: 2011000원, 진입금액: 398810원, 수수료 199원
# 2021-03-24, 매도 주문, 2020000원
# 2021-03-25, 매도 체결, 매도량: 0.198314328210213192 ETH, 청산가: 1959000원, 청산금액: 388498원, 수수료 194원
# 2021-03-25, [투자 이익] 총이익 -10312원 | 순이익 -10706원
# 2021-03-25, 매수 주문, 1976500원
# 2021-03-26, 매수 체결, 매수량: 0.202269607902773318 ETH, 진입가: 1958000원, 진입금액: 396044원, 수수료 198원
# 2021-03-26, 매도 주문, 1985000원
# 2021-03-27, 매도 체결, 매도량: 0.202269607902773318 ETH, 청산가: 2029000원, 청산금액: 410405원, 수수료 205원
# 2021-03-27, [투자 이익] 총이익 14361원 | 순이익 13958원
# 2021-03-27, 매수 주문, 2038000원
# 2021-03-28, 매수 체결, 매수량: 0.196302766621092389 ETH, 진입가: 2042000원, 진입금액: 400850원, 수수료 200원
# 2021-03-28, 매도 주문, 2047000원
# 2021-03-29, 매도 체결, 매도량: 0.196302766621092389 ETH, 청산가: 2031000원, 청산금액: 398691원, 수수료 199원
# 2021-03-29, [투자 이익] 총이익 -2159원 | 순이익 -2559원
# 2021-03-29, 매수 주문, 2030000원
# 2021-03-30, 매수 체결, 매수량: 0.197051160765243955 ETH, 진입가: 2163000원, 진입금액: 426222원, 수수료 213원
# 2021-03-30, 매도 주문, 2173000원
# 2021-03-31, 매도 체결, 매도량: 0.197051160765243955 ETH, 청산가: 2220000원, 청산금액: 437454원, 수수료 219원
# 2021-03-31, [투자 이익] 총이익 11232원 | 순이익 10800원
# 2021-03-31, 매수 주문, 2238000원
# 2021-04-01, 매수 체결, 매수량: 0.178833716677543025 ETH, 진입가: 2333000원, 진입금액: 417219원, 수수료 209원
# 2021-04-01, 매도 주문, 2342000원
# 2021-04-02, 매도 체결, 매도량: 0.178833716677543025 ETH, 청산가: 2436000원, 청산금액: 435639원, 수수료 218원
# 2021-04-02, [투자 이익] 총이익 18420원 | 순이익 17993원
# 2021-04-02, 매수 주문, 2425000원
# 2021-04-03, 매수 체결, 매수량: 0.165191639917834476 ETH, 진입가: 2679000원, 진입금액: 442548원, 수수료 221원
# 2021-04-03, 매도 주문, 2664000원
# 2021-04-04, 매도 체결, 매도량: 0.165191639917834476 ETH, 청산가: 2544000원, 청산금액: 420248원, 수수료 210원
# 2021-04-04, [투자 이익] 총이익 -22301원 | 순이익 -22732원
# 2021-04-04, 매수 주문, 2582000원
# 2021-04-05, 매수 체결, 매수량: 0.154970984281029289 ETH, 진입가: 2636000원, 진입금액: 408504원, 수수료 204원
# 2021-04-05, 매도 주문, 2665000원
# 2021-04-06, 매도 체결, 매도량: 0.154970984281029289 ETH, 청산가: 2813000원, 청산금액: 435933원, 수수료 218원
# 2021-04-06, [투자 이익] 총이익 27430원 | 순이익 27008원
# 2021-04-06, 매수 주문, 2852000원
# 2021-04-07, 매수 체결, 매수량: 0.140489212597839752 ETH, 진입가: 2836000원, 진입금액: 398427원, 수수료 199원
# 2021-04-07, 매도 주문, 2852000원
# 2021-04-08, 매도 체결, 매도량: 0.140489212597839752 ETH, 청산가: 2560000원, 청산금액: 359652원, 수수료 180원
# 2021-04-08, [투자 이익] 총이익 -38775원 | 순이익 -39154원
# 2021-04-08, 매수 주문, 2581000원
# 2021-04-09, 매수 체결, 매수량: 0.154936905493059662 ETH, 진입가: 2701000원, 진입금액: 418485원, 수수료 209원
# 2021-04-09, 매도 주문, 2701000원
# 2021-04-10, 매도 체결, 매도량: 0.154936905493059662 ETH, 청산가: 2706000원, 청산금액: 419259원, 수수료 210원
# 2021-04-10, [투자 이익] 총이익 775원 | 순이익 356원
# 2021-04-10, 매수 주문, 2692000원
# 2021-04-11, 매수 체결, 매수량: 0.148550991578624197 ETH, 진입가: 2802000원, 진입금액: 416240원, 수수료 208원
# 2021-04-11, 매도 주문, 2790000원
# 2021-04-12, 매도 체결, 매도량: 0.148550991578624197 ETH, 청산가: 2827000원, 청산금액: 419954원, 수수료 210원
# 2021-04-12, [투자 이익] 총이익 3714원 | 순이익 3296원
# 2021-04-12, 매수 주문, 2789000원
# 2021-04-13, 매수 체결, 매수량: 0.143408097128049333 ETH, 진입가: 2795000원, 진입금액: 400826원, 수수료 200원
# 2021-04-13, 매도 주문, 2807000원
# 2021-04-14, 매도 체결, 매도량: 0.143408097128049333 ETH, 청산가: 2925000원, 청산금액: 419469원, 수수료 210원
# 2021-04-14, [투자 이익] 총이익 18643원 | 순이익 18233원
# 2021-04-14, 매수 주문, 2941000원
# 2021-04-15, 매수 체결, 매수량: 0.136120313158621858 ETH, 진입가: 3110000원, 진입금액: 423334원, 수수료 212원
# 2021-04-15, 매도 주문, 3072000원
# 2021-04-16, 매도 체결, 매도량: 0.136120313158621858 ETH, 청산가: 3174000원, 청산금액: 432046원, 수수료 216원
# 2021-04-16, [투자 이익] 총이익 8712원 | 순이익 8284원
# 2021-04-16, 매수 주문, 3214000원
# 2021-04-17, 매수 체결, 매수량: 0.124609683011783143 ETH, 진입가: 3146000원, 진입금액: 392022원, 수수료 196원
# 2021-04-17, 매도 주문, 3172000원
# 2021-04-18, 매도 체결, 매도량: 0.124609683011783143 ETH, 청산가: 3010000원, 청산금액: 375075원, 수수료 188원
# 2021-04-18, [투자 이익] 총이익 -16947원 | 순이익 -17330원
# 2021-04-18, 매수 주문, 2833000원
# 2021-04-19, 매수 체결, 매수량: 0.141245644860569258 ETH, 진입가: 3009000원, 진입금액: 425008원, 수수료 213원
# 2021-04-19, 매도 주문, 3021000원
# 2021-04-20, 매도 체결, 매도량: 0.141245644860569258 ETH, 청산가: 2781000원, 청산금액: 392804원, 수수료 196원
# 2021-04-20, [투자 이익] 총이익 -32204원 | 순이익 -32613원
# 2021-04-20, 매수 주문, 2565000원
# 2021-04-21, 매수 체결, 매수량: 0.155749182700425426 ETH, 진입가: 2908000원, 진입금액: 452919원, 수수료 226원
# 2021-04-21, 매도 주문, 2952000원
# 2021-04-22, 매도 체결, 매도량: 0.155749182700425426 ETH, 청산가: 2990000원, 청산금액: 465690원, 수수료 233원
# 2021-04-22, [투자 이익] 총이익 12771원 | 순이익 12312원
# 2021-04-22, 매수 주문, 2972000원
# 2021-04-23, 매수 체결, 매수량: 0.134502993337625942 ETH, 진입가: 2767000원, 진입금액: 372170원, 수수료 186원
# 2021-04-23, 매도 주문, 2591000원
# 2021-04-24, 매도 체결, 매도량: 0.134502993337625942 ETH, 청산가: 2812000원, 청산금액: 378222원, 수수료 189원
# 2021-04-24, [투자 이익] 총이익 6053원 | 순이익 5677원
# 2021-04-24, 매수 주문, 2703000원
# 2021-04-25, 매수 체결, 매수량: 0.147930612272079126 ETH, 진입가: 2696000원, 진입금액: 398821원, 수수료 199원
# 2021-04-25, 매도 주문, 2708000원
# 2021-04-26, 매도 체결, 매도량: 0.147930612272079126 ETH, 청산가: 2831000원, 청산금액: 418792원, 수수료 209원
# 2021-04-26, [투자 이익] 총이익 19971원 | 순이익 19562원
# 2021-04-26, 매수 주문, 2925000원
# 2021-04-27, 매수 체결, 매수량: 0.136836814187905748 ETH, 진입가: 3004000원, 진입금액: 411058원, 수수료 206원
# 2021-04-27, 매도 주문, 2970000원
# 2021-04-28, 매도 체결, 매도량: 0.136836814187905748 ETH, 청산가: 3140000원, 청산금액: 429668원, 수수료 215원
# 2021-04-28, [투자 이익] 총이익 18610원 | 순이익 18189원
# 2021-04-28, 매수 주문, 3179000원
# 2021-04-29, 매수 체결, 매수량: 0.126018078131598515 ETH, 진입가: 3213000원, 진입금액: 404896원, 수수료 202원
# 2021-04-29, 매도 주문, 3220000원
# 2021-04-30, 매도 체결, 매도량: 0.126018078131598515 ETH, 청산가: 3279000원, 청산금액: 413213원, 수수료 207원
# 2021-04-30, [투자 이익] 총이익 8317원 | 순이익 7908원
# 2021-04-30, 매수 주문, 3279000원
# 2021-05-01, 매수 체결, 매수량: 0.122223126913648381 ETH, 진입가: 3271000원, 진입금액: 399792원, 수수료 200원
# 2021-05-01, 매도 주문, 3286000원
# 2021-05-02, 매도 체결, 매도량: 0.122223126913648381 ETH, 청산가: 3509000원, 청산금액: 428881원, 수수료 214원
# 2021-05-02, [투자 이익] 총이익 29089원 | 순이익 28675원
# 2021-05-02, 매수 주문, 3516000원
# 2021-05-03, 매수 체결, 매수량: 0.114147647470408758 ETH, 진입가: 3564000원, 진입금액: 406822원, 수수료 203원
# 2021-05-03, 매도 주문, 3577000원
# 2021-05-04, 매도 체결, 매도량: 0.114147647470408758 ETH, 청산가: 4226000원, 청산금액: 482388원, 수수료 241원
# 2021-05-04, [투자 이익] 총이익 75566원 | 순이익 75121원
# 2021-05-04, 매수 주문, 4167000원
# 2021-05-05, 매수 체결, 매수량: 0.096675198285751732 ETH, 진입가: 4081000원, 진입금액: 394531원, 수수료 197원
# 2021-05-05, 매도 주문, 4160000원
# 2021-05-06, 매도 체결, 매도량: 0.096675198285751732 ETH, 청산가: 4209000원, 청산금액: 406906원, 수수료 203원
# 2021-05-06, [투자 이익] 총이익 12374원 | 순이익 11974원
# 2021-05-06, 매수 주문, 4189000원
# 2021-05-07, 매수 체결, 매수량: 0.096224642012509243 ETH, 진입가: 4255000원, 진입금액: 409436원, 수수료 205원
# 2021-05-07, 매도 주문, 4276000원
# 2021-05-08, 매도 체결, 매도량: 0.096224642012509243 ETH, 청산가: 4169000원, 청산금액: 401161원, 수수료 201원
# 2021-05-08, [투자 이익] 총이익 -8275원 | 순이익 -8681원
# 2021-05-08, 매수 주문, 4132000원
# 2021-05-09, 매수 체결, 매수량: 0.097510022517496769 ETH, 진입가: 4764000원, 진입금액: 464538원, 수수료 232원
# 2021-05-09, 매도 주문, 4690000원
# 2021-05-10, 매도 체결, 매도량: 0.097510022517496769 ETH, 청산가: 4811000원, 청산금액: 469121원, 수수료 235원
# 2021-05-10, [투자 이익] 총이익 4583원 | 순이익 4116원
# 2021-05-10, 매수 주문, 4803000원
# 2021-05-11, 매수 체결, 매수량: 0.083904587940621903 ETH, 진입가: 5008000원, 진입금액: 420194원, 수수료 210원
# 2021-05-11, 매도 주문, 4873000원
# 2021-05-12, 매도 체결, 매도량: 0.083904587940621903 ETH, 청산가: 5118000원, 청산금액: 429424원, 수수료 215원
# 2021-05-12, [투자 이익] 총이익 9230원 | 순이익 8805원
# 2021-05-12, 매수 주문, 5105000원
# 2021-05-13, 매수 체결, 매수량: 0.078975480860666317 ETH, 진입가: 4749000원, 진입금액: 375055원, 수수료 188원
# 2021-05-13, 매도 주문, 4995000원
# 2021-05-14, 매도 체결, 매도량: 0.078975480860666317 ETH, 청산가: 4726000원, 청산금액: 373238원, 수수료 187원
# 2021-05-14, [투자 이익] 총이익 -1816원 | 순이익 -2191원
# 2021-05-14, 매수 주문, 4707000원
# 2021-05-15, 매수 체결, 매수량: 0.085643938420585125 ETH, 진입가: 5031000원, 진입금액: 430875원, 수수료 215원
# 2021-05-15, 매도 주문, 5074000원
# 2021-05-16, 매도 체결, 매도량: 0.085643938420585125 ETH, 청산가: 4580000원, 청산금액: 392249원, 수수료 196원
# 2021-05-16, [투자 이익] 총이익 -38625원 | 순이익 -39037원
# 2021-05-16, 매수 주문, 4712000원
# 2021-05-17, 매수 체결, 매수량: 0.085387368120165286 ETH, 진입가: 4451000원, 진입금액: 380059원, 수수료 190원
# 2021-05-17, 매도 주문, 4463000원
# 2021-05-18, 매도 체결, 매도량: 0.085387368120165286 ETH, 청산가: 4084000원, 청산금액: 348722원, 수수료 174원
# 2021-05-18, [투자 이익] 총이익 -31337원 | 순이익 -31702원
# 2021-05-18, 매수 주문, 4011000원
# 2021-05-19, 매수 체결, 매수량: 0.100152392791909184 ETH, 진입가: 4209000원, 진입금액: 421541원, 수수료 211원
# 2021-05-19, 매도 주문, 4236000원
# 2021-05-20, 매도 체결, 매도량: 0.100152392791909184 ETH, 청산가: 3351000원, 청산금액: 335611원, 수수료 168원
# 2021-05-20, [투자 이익] 총이익 -85931원 | 순이익 -86309원
# 2021-05-20, 매수 주문, 3271000원
# 2021-05-21, 매수 체결, 매수량: 0.122282195324715223 ETH, 진입가: 3505000원, 진입금액: 428599원, 수수료 214원
# 2021-05-21, 매도 주문, 3542000원
# 2021-05-22, 매도 체결, 매도량: 0.122282195324715223 ETH, 청산가: 3198000원, 청산금액: 391058원, 수수료 196원
# 2021-05-22, [투자 이익] 총이익 -37541원 | 순이익 -37950원
# 2021-05-22, 매수 주문, 3180000원
# 2021-05-23, 매수 체결, 매수량: 0.125542783538458214 ETH, 진입가: 2913000원, 진입금액: 365706원, 수수료 183원
# 2021-05-23, 매도 주문, 2971000원
# 2021-05-24, 매도 체결, 매도량: 0.125542783538458214 ETH, 청산가: 2582000원, 청산금액: 324151원, 수수료 162원
# 2021-05-24, [투자 이익] 총이익 -41555원 | 순이익 -41900원
# 2021-05-24, 매수 주문, 2590000원
# 2021-05-25, 매수 체결, 매수량: 0.153817783725605034 ETH, 진입가: 3210000원, 진입금액: 493755원, 수수료 247원
# 2021-05-25, 매도 주문, 3321000원
# 2021-05-26, 매도 체결, 매도량: 0.153817783725605034 ETH, 청산가: 3315000원, 청산금액: 509906원, 수수료 255원
# 2021-05-26, [투자 이익] 총이익 16151원 | 순이익 15649원
# 2021-05-26, 매수 주문, 3292000원
# 2021-05-27, 매수 체결, 매수량: 0.121112102243242037 ETH, 진입가: 3472000원, 진입금액: 420501원, 수수료 210원
# 2021-05-27, 매도 주문, 3461000원
# 2021-05-28, 매도 체결, 매도량: 0.121112102243242037 ETH, 청산가: 3320000원, 청산금액: 402092원, 수수료 201원
# 2021-05-28, [투자 이익] 총이익 -18409원 | 순이익 -18820원
# 2021-05-28, 매수 주문, 3285000원
# 2021-05-29, 매수 체결, 매수량: 0.121255596304398458 ETH, 진입가: 2963000원, 진입금액: 359280원, 수수료 180원
# 2021-05-29, 매도 주문, 3040000원
# 2021-05-30, 매도 체결, 매도량: 0.121255596304398458 ETH, 청산가: 2819000원, 청산금액: 341820원, 수수료 171원
# 2021-05-30, [투자 이익] 총이익 -17461원 | 순이익 -17811원
# 2021-05-30, 매수 주문, 2793000원
# 2021-05-31, 매수 체결, 매수량: 0.142487793320448974 ETH, 진입가: 2895000원, 진입금액: 412502원, 수수료 206원
# 2021-05-31, 매도 주문, 2913000원
# 2021-06-01, 매도 체결, 매도량: 0.142487793320448974 ETH, 청산가: 3167000원, 청산금액: 451259원, 수수료 226원
# 2021-06-01, [투자 이익] 총이익 38757원 | 순이익 38325원
# 2021-06-01, 매수 주문, 3205000원
# 2021-06-02, 매수 체결, 매수량: 0.124410266062292107 ETH, 진입가: 3102000원, 진입금액: 385921원, 수수료 193원
# 2021-06-02, 매도 주문, 3112000원
# 2021-06-03, 매도 체결, 매도량: 0.124410266062292107 ETH, 청산가: 3150000원, 청산금액: 391892원, 수수료 196원
# 2021-06-03, [투자 이익] 총이익 5972원 | 순이익 5583원
# 2021-06-03, 매수 주문, 3153000원
# 2021-06-04, 매수 체결, 매수량: 0.126497481273463941 ETH, 진입가: 3310000원, 진입금액: 418707원, 수수료 209원
# 2021-06-04, 매도 주문, 3304000원
# 2021-06-05, 매도 체결, 매도량: 0.126497481273463941 ETH, 청산가: 3131000원, 청산금액: 396064원, 수수료 198원
# 2021-06-05, [투자 이익] 총이익 -22643원 | 순이익 -23050원
# 2021-06-05, 매수 주문, 3162000원
# 2021-06-06, 매수 체결, 매수량: 0.125991634968217581 ETH, 진입가: 3103000원, 진입금액: 390952원, 수수료 195원
# 2021-06-06, 매도 주문, 3100000원
# 2021-06-07, 매도 체결, 매도량: 0.125991634968217581 ETH, 청산가: 3163000원, 청산금액: 398512원, 수수료 199원
# 2021-06-07, [투자 이익] 총이익 7559원 | 순이익 7165원
# 2021-06-07, 매수 주문, 3148000원
# 2021-06-08, 매수 체결, 매수량: 0.126597473029103763 ETH, 진입가: 3021000원, 진입금액: 382451원, 수수료 191원
# 2021-06-08, 매도 주문, 3030000원
# 2021-06-09, 매도 체결, 매도량: 0.126597473029103763 ETH, 청산가: 2893000원, 청산금액: 366246원, 수수료 183원
# 2021-06-09, [투자 이익] 총이익 -16204원 | 순이익 -16579원
# 2021-06-09, 매수 주문, 2790000원
# 2021-06-10, 매수 체결, 매수량: 0.142723035336956711 ETH, 진입가: 3017000원, 진입금액: 430595원, 수수료 215원
# 2021-06-10, 매도 주문, 3000000원
# 2021-06-11, 매도 체결, 매도량: 0.142723035336956711 ETH, 청산가: 2888000원, 청산금액: 412184원, 수수료 206원
# 2021-06-11, [투자 이익] 총이익 -18411원 | 순이익 -18833원
# 2021-06-11, 매수 주문, 2881000원
# 2021-06-12, 매수 체결, 매수량: 0.138084212205381168 ETH, 진입가: 2756000원, 진입금액: 380560원, 수수료 190원
# 2021-06-12, 매도 주문, 2772000원
# 2021-06-13, 매도 체결, 매도량: 0.138084212205381168 ETH, 청산가: 2760000원, 청산금액: 381112원, 수수료 191원
# 2021-06-13, [투자 이익] 총이익 552원 | 순이익 172원
# 2021-06-13, 매수 주문, 2776000원
# 2021-06-14, 매수 체결, 매수량: 0.143308373694356755 ETH, 진입가: 2878000원, 진입금액: 412441원, 수수료 206원
# 2021-06-14, 매도 주문, 2883000원
# 2021-06-15, 매도 체결, 매도량: 0.143308373694356755 ETH, 청산가: 2956000원, 청산금액: 423620원, 수수료 212원
# 2021-06-15, [투자 이익] 총이익 11178원 | 순이익 10760원
# 2021-06-15, 매수 주문, 2957000원
# 2021-06-16, 매수 체결, 매수량: 0.134609146374019717 ETH, 진입가: 2939000원, 진입금액: 395616원, 수수료 198원
# 2021-06-16, 매도 주문, 2912000원
# 2021-06-17, 매도 체결, 매도량: 0.134609146374019717 ETH, 청산가: 2800000원, 청산금액: 376906원, 수수료 188원
# 2021-06-17, [투자 이익] 총이익 -18711원 | 순이익 -19097원
# 2021-06-17, 매수 주문, 2826000원
# 2021-06-18, 매수 체결, 매수량: 0.140713838351785553 ETH, 진입가: 2794000원, 진입금액: 393154원, 수수료 197원
# 2021-06-18, 매도 주문, 2790000원
# 2021-06-19, 매도 체결, 매도량: 0.140713838351785553 ETH, 청산가: 2650000원, 청산금액: 372892원, 수수료 186원
# 2021-06-19, [투자 이익] 총이익 -20263원 | 순이익 -20646원
# 2021-06-19, 매수 주문, 2644000원
# 2021-06-20, 매수 체결, 매수량: 0.150243718179399771 ETH, 진입가: 2574000원, 진입금액: 386727원, 수수료 193원
# 2021-06-20, 매도 주문, 2568000원
# 2021-06-21, 매도 체결, 매도량: 0.150243718179399771 ETH, 청산가: 2638000원, 청산금액: 396343원, 수수료 198원
# 2021-06-21, [투자 이익] 총이익 9616원 | 순이익 9224원
# 2021-06-21, 매수 주문, 2497000원
# 2021-06-22, 매수 체결, 매수량: 0.159162543901886666 ETH, 진입가: 2232000원, 진입금액: 355251원, 수수료 178원
# 2021-06-22, 매도 주문, 2235000원
# 2021-06-23, 매도 체결, 매도량: 0.159162543901886666 ETH, 청산가: 2186000원, 청산금액: 347929원, 수수료 174원
# 2021-06-23, [투자 이익] 총이익 -7321원 | 순이익 -7673원
# 2021-06-23, 매수 주문, 2124000원
# 2021-06-24, 매수 체결, 매수량: 0.187041153851898234 ETH, 진입가: 2281000원, 진입금액: 426641원, 수수료 213원
# 2021-06-24, 매도 주문, 2279000원
# 2021-06-25, 매도 체결, 매도량: 0.187041153851898234 ETH, 청산가: 2307000원, 청산금액: 431504원, 수수료 216원
# 2021-06-25, [투자 이익] 총이익 4863원 | 순이익 4434원
# 2021-06-25, 매수 주문, 2313000원
# 2021-06-26, 매수 체결, 매수량: 0.171795975241373133 ETH, 진입가: 2127000원, 진입금액: 365410원, 수수료 183원
# 2021-06-26, 매도 주문, 2140000원
# 2021-06-27, 매도 체결, 매도량: 0.171795975241373133 ETH, 청산가: 2131000원, 청산금액: 366097원, 수수료 183원
# 2021-06-27, [투자 이익] 총이익 687원 | 순이익 321원
# 2021-06-27, 매수 주문, 2114000원
# 2021-06-28, 매수 체결, 매수량: 0.187970917378755736 ETH, 진입가: 2282000원, 진입금액: 428950원, 수수료 214원
# 2021-06-28, 매도 주문, 2270000원
# 2021-06-29, 매도 체결, 매도량: 0.187970917378755736 ETH, 청산가: 2414000원, 청산금액: 453762원, 수수료 227원
# 2021-06-29, [투자 이익] 총이익 24812원 | 순이익 24371원
# 2021-06-29, 매수 주문, 2431000원
# 2021-06-30, 매수 체결, 매수량: 0.163660195576425110 ETH, 진입가: 2505000원, 진입금액: 409969원, 수수료 205원
# 2021-06-30, 매도 주문, 2540000원
# 2021-07-01, 매도 체결, 매도량: 0.163660195576425110 ETH, 청산가: 2640000원, 청산금액: 432063원, 수수료 216원
# 2021-07-01, [투자 이익] 총이익 22094원 | 순이익 21673원
# 2021-07-01, 매수 주문, 2616000원
# 2021-07-02, 매수 체결, 매수량: 0.152252063324649606 ETH, 진입가: 2477000원, 진입금액: 377128원, 수수료 189원
# 2021-07-02, 매도 주문, 2487000원
# 2021-07-03, 매도 체결, 매도량: 0.152252063324649606 ETH, 청산가: 2511000원, 청산금액: 382305원, 수수료 191원
# 2021-07-03, [투자 이익] 총이익 5177원 | 순이익 4797원
# 2021-07-03, 매수 주문, 2493000원
# 2021-07-04, 매수 체결, 매수량: 0.159802380556528456 ETH, 진입가: 2588000원, 진입금액: 413569원, 수수료 207원
# 2021-07-04, 매도 주문, 2589000원
# 2021-07-05, 매도 체결, 매도량: 0.159802380556528456 ETH, 청산가: 2693000원, 청산금액: 430348원, 수수료 215원
# 2021-07-05, [투자 이익] 총이익 16779원 | 순이익 16357원
# 2021-07-05, 매수 주문, 2633000원
# 2021-07-06, 매수 체결, 매수량: 0.151429730559391157 ETH, 진입가: 2574000원, 진입금액: 389780원, 수수료 195원
# 2021-07-06, 매도 주문, 2596000원
# 2021-07-07, 매도 체결, 매도량: 0.151429730559391157 ETH, 청산가: 2701000원, 청산금액: 409012원, 수수료 205원
# 2021-07-07, [투자 이익] 총이익 19232원 | 순이익 18832원
# 2021-07-07, 매수 주문, 2680000원
# 2021-07-08, 매수 체결, 매수량: 0.148914598567242817 ETH, 진입가: 2717000원, 진입금액: 404601원, 수수료 202원
# 2021-07-08, 매도 주문, 2705000원
# 2021-07-09, 매도 체결, 매도량: 0.148914598567242817 ETH, 청산가: 2519000원, 청산금액: 375116원, 수수료 188원
# 2021-07-09, [투자 이익] 총이익 -29485원 | 순이익 -29875원
# 2021-07-09, 매수 주문, 2475000원
# 2021-07-10, 매수 체결, 매수량: 0.161007525325859990 ETH, 진입가: 2527000원, 진입금액: 406866원, 수수료 203원
# 2021-07-10, 매도 주문, 2529000원
# 2021-07-11, 매도 체결, 매도량: 0.161007525325859990 ETH, 청산가: 2494000원, 청산금액: 401553원, 수수료 201원
# 2021-07-11, [투자 이익] 총이익 -5313원 | 순이익 -5717원
# 2021-07-11, 매수 주문, 2504000원
# 2021-07-12, 매수 체결, 매수량: 0.159097154962836163 ETH, 진입가: 2512000원, 진입금액: 399652원, 수수료 200원
# 2021-07-12, 매도 주문, 2515000원
# 2021-07-13, 매도 체결, 매도량: 0.159097154962836163 ETH, 청산가: 2408000원, 청산금액: 383106원, 수수료 192원
# 2021-07-13, [투자 이익] 총이익 -16546원 | 순이익 -16937원
# 2021-07-13, 매수 주문, 2413000원
# 2021-07-14, 매수 체결, 매수량: 0.164956703839450852 ETH, 진입가: 2301000원, 진입금액: 379565원, 수수료 190원
# 2021-07-14, 매도 주문, 2274000원
# 2021-07-15, 매도 체결, 매도량: 0.164956703839450852 ETH, 청산가: 2346000원, 청산금액: 386988원, 수수료 193원
# 2021-07-15, [투자 이익] 총이익 7423원 | 순이익 7040원
# 2021-07-15, 매수 주문, 2359000원
# 2021-07-16, 매수 체결, 매수량: 0.168792421305647727 ETH, 진입가: 2268000원, 진입금액: 382821원, 수수료 191원
# 2021-07-16, 매도 주문, 2269000원
# 2021-07-17, 매도 체결, 매도량: 0.168792421305647727 ETH, 청산가: 2224000원, 청산금액: 375394원, 수수료 188원
# 2021-07-17, [투자 이익] 총이익 -7427원 | 순이익 -7806원
# 2021-07-17, 매수 주문, 2228000원
# 2021-07-18, 매수 체결, 매수량: 0.178646859234160210 ETH, 진입가: 2240000원, 진입금액: 400169원, 수수료 200원
# 2021-07-18, 매도 주문, 2330000원
# 2021-07-19, 매도 체결, 매도량: 0.178646859234160210 ETH, 청산가: 2242000원, 청산금액: 400526원, 수수료 200원
# 2021-07-19, [투자 이익] 총이익 357원 | 순이익 -43원
# 2021-07-19, 매수 주문, 2228000원
# 2021-07-20, 매수 체결, 매수량: 0.178646472753971025 ETH, 진입가: 2169000원, 진입금액: 387484원, 수수료 194원
# 2021-07-20, 매도 주문, 2182000원
# 2021-07-21, 매도 체결, 매도량: 0.178646472753971025 ETH, 청산가: 2119000원, 청산금액: 378552원, 수수료 189원
# 2021-07-21, [투자 이익] 총이익 -8932원 | 순이익 -9315원
# 2021-07-21, 매수 주문, 2111000원
# 2021-07-22, 매수 체결, 매수량: 0.188459514193435235 ETH, 진입가: 2361000원, 진입금액: 444953원, 수수료 222원
# 2021-07-22, 매도 주문, 2368000원
# 2021-07-23, 매도 체결, 매도량: 0.188459514193435235 ETH, 청산가: 2374000원, 청산금액: 447403원, 수수료 224원
# 2021-07-23, [투자 이익] 총이익 2450원 | 순이익 2004원
# 2021-07-23, 매수 주문, 2365000원
# 2021-07-24, 매수 체결, 매수량: 0.168235987474856241 ETH, 진입가: 2472000원, 진입금액: 415879원, 수수료 208원
# 2021-07-24, 매도 주문, 2495000원
# 2021-07-25, 매도 체결, 매도량: 0.168235987474856241 ETH, 청산가: 2556000원, 청산금액: 430011원, 수수료 215원
# 2021-07-25, [투자 이익] 총이익 14132원 | 순이익 13709원
# 2021-07-25, 매수 주문, 2554000원
# 2021-07-26, 매수 체결, 매수량: 0.155893613129029968 ETH, 진입가: 2539000원, 진입금액: 395814원, 수수료 198원
# 2021-07-26, 매도 주문, 2534000원
# 2021-07-27, 매도 체결, 매도량: 0.155893613129029968 ETH, 청산가: 2575000원, 청산금액: 401426원, 수수료 201원
# 2021-07-27, [투자 이익] 총이익 5612원 | 순이익 5214원
# 2021-07-27, 매수 주문, 2528000원
# 2021-07-28, 매수 체결, 매수량: 0.157538195780704104 ETH, 진입가: 2647000원, 진입금액: 417004원, 수수료 209원
# 2021-07-28, 매도 주문, 2658000원
# 2021-07-29, 매도 체결, 매도량: 0.157538195780704104 ETH, 청산가: 2663000원, 청산금액: 419524원, 수수료 210원
# 2021-07-29, [투자 이익] 총이익 2521원 | 순이익 2102원
# 2021-07-29, 매수 주문, 2666000원
# 2021-07-30, 매수 체결, 매수량: 0.149399327036036728 ETH, 진입가: 2731000원, 진입금액: 408010원, 수수료 204원
# 2021-07-30, 매도 주문, 2783000원
# 2021-07-31, 매도 체결, 매도량: 0.149399327036036728 ETH, 청산가: 2835000원, 청산금액: 423547원, 수수료 212원
# 2021-07-31, [투자 이익] 총이익 15538원 | 순이익 15122원
# 2021-07-31, 매수 주문, 2835000원
# 2021-08-01, 매수 체결, 매수량: 0.140600014430958015 ETH, 진입가: 2927000원, 진입금액: 411536원, 수수료 206원
# 2021-08-01, 매도 주문, 2945000원
# 2021-08-02, 매도 체결, 매도량: 0.140600014430958015 ETH, 청산가: 2966000원, 청산금액: 417020원, 수수료 209원
# 2021-08-02, [투자 이익] 총이익 5483원 | 순이익 5069원
# 2021-08-02, 매수 주문, 2956000원
# 2021-08-03, 매수 체결, 매수량: 0.134879033614401789 ETH, 진입가: 3024000원, 진입금액: 407874원, 수수료 204원
# 2021-08-03, 매도 주문, 3050000원
# 2021-08-04, 매도 체결, 매도량: 0.134879033614401789 ETH, 청산가: 2948000원, 청산금액: 397623원, 수수료 199원
# 2021-08-04, [투자 이익] 총이익 -10251원 | 순이익 -10654원
# 2021-08-04, 매수 주문, 2952000원
# 2021-08-05, 매수 체결, 매수량: 0.134989617973303000 ETH, 진입가: 3135000원, 진입금액: 423192원, 수수료 212원
# 2021-08-05, 매도 주문, 3141000원
# 2021-08-06, 매도 체결, 매도량: 0.134989617973303000 ETH, 청산가: 3260000원, 청산금액: 440066원, 수수료 220원
# 2021-08-06, [투자 이익] 총이익 16874원 | 순이익 16442원
# 2021-08-06, 매수 주문, 3243000원
# 2021-08-07, 매수 체결, 매수량: 0.122978166424931937 ETH, 진입가: 3327000원, 진입금액: 409148원, 수수료 205원
# 2021-08-07, 매도 주문, 3320000원
# 2021-08-08, 매도 체결, 매도량: 0.122978166424931937 ETH, 청산가: 3611000원, 청산금액: 444074원, 수수료 222원
# 2021-08-08, [투자 이익] 총이익 34926원 | 순이익 34499원
# 2021-08-08, 매수 주문, 3596000원
# 2021-08-09, 매수 체결, 매수량: 0.111097935894371891 ETH, 진입가: 3494000원, 진입금액: 388176원, 수수료 194원
# 2021-08-09, 매도 주문, 3517000원
# 2021-08-10, 매도 체결, 매도량: 0.111097935894371891 ETH, 청산가: 3611000원, 청산금액: 401175원, 수수료 201원
# 2021-08-10, [투자 이익] 총이익 12998원 | 순이익 12604원
# 2021-08-10, 매수 주문, 3618000원
# 2021-08-11, 매수 체결, 매수량: 0.110492054488062152 ETH, 진입가: 3611000원, 진입금액: 398987원, 수수료 199원
# 2021-08-11, 매도 주문, 3624000원
# 2021-08-12, 매도 체결, 매도량: 0.110492054488062152 ETH, 청산가: 3651000원, 청산금액: 403406원, 수수료 202원
# 2021-08-12, [투자 이익] 총이익 4420원 | 순이익 4018원
# 2021-08-12, 매수 주문, 3674000원
# 2021-08-13, 매수 체결, 매수량: 0.108829783028960916 ETH, 진입가: 3571000원, 진입금액: 388631원, 수수료 194원
# 2021-08-13, 매도 주문, 3567000원
# 2021-08-14, 매도 체결, 매도량: 0.108829783028960916 ETH, 청산가: 3832000원, 청산금액: 417036원, 수수료 209원
# 2021-08-14, [투자 이익] 총이익 28405원 | 순이익 28002원
# 2021-08-14, 매수 주문, 3840000원
# 2021-08-15, 매수 체결, 매수량: 0.104271004595566652 ETH, 진입가: 3804000원, 진입금액: 396647원, 수수료 198원
# 2021-08-15, 매도 주문, 3812000원
# 2021-08-16, 매도 체결, 매도량: 0.104271004595566652 ETH, 청산가: 3844000원, 청산금액: 400818원, 수수료 200원
# 2021-08-16, [투자 이익] 총이익 4171원 | 순이익 3772원
# 2021-08-16, 매수 주문, 3843000원
# 2021-08-17, 매수 체결, 매수량: 0.104209237523867029 ETH, 진입가: 3694000원, 진입금액: 384949원, 수수료 192원
# 2021-08-17, 매도 주문, 3657000원
# 2021-08-18, 매도 체결, 매도량: 0.104209237523867029 ETH, 청산가: 3549000원, 청산금액: 369839원, 수수료 185원
# 2021-08-18, [투자 이익] 총이익 -15110원 | 순이익 -15488원
# 2021-08-18, 매수 주문, 3534000원
# 2021-08-19, 매수 체결, 매수량: 0.113233261216844364 ETH, 진입가: 3555000원, 진입금액: 402544원, 수수료 201원
# 2021-08-19, 매도 주문, 3583000원
# 2021-08-20, 매도 체결, 매도량: 0.113233261216844364 ETH, 청산가: 3744000원, 청산금액: 423945원, 수수료 212원
# 2021-08-20, [투자 이익] 총이익 21401원 | 순이익 20988원
# 2021-08-20, 매수 주문, 3780000원
# 2021-08-21, 매수 체결, 매수량: 0.105975159251849582 ETH, 진입가: 3837000원, 진입금액: 406627원, 수수료 203원
# 2021-08-21, 매도 주문, 3831000원
# 2021-08-22, 매도 체결, 매도량: 0.105975159251849582 ETH, 청산가: 3796000원, 청산금액: 402282원, 수수료 201원
# 2021-08-22, [투자 이익] 총이익 -4345원 | 순이익 -4749원
# 2021-08-22, 매수 주문, 3821000원
# 2021-08-23, 매수 체결, 매수량: 0.104813167562810561 ETH, 진입가: 3790000원, 진입금액: 397242원, 수수료 199원
# 2021-08-23, 매도 주문, 3822000원
# 2021-08-24, 매도 체결, 매도량: 0.104813167562810561 ETH, 청산가: 3864000원, 청산금액: 404998원, 수수료 202원
# 2021-08-24, [투자 이익] 총이익 7756원 | 순이익 7355원
# 2021-08-24, 매수 주문, 3881000원
# 2021-08-25, 매수 체결, 매수량: 0.103230665896842794 ETH, 진입가: 3728000원, 진입금액: 384844원, 수수료 192원
# 2021-08-25, 매도 주문, 3751000원
# 2021-08-26, 매도 체결, 매도량: 0.103230665896842794 ETH, 청산가: 3765000원, 청산금액: 388663원, 수수료 194원
# 2021-08-26, [투자 이익] 총이익 3820원 | 순이익 3433원
# 2021-08-26, 매수 주문, 3756000원
# 2021-08-27, 매수 체결, 매수량: 0.106684470171622720 ETH, 진입가: 3646000원, 진입금액: 388972원, 수수료 194원
# 2021-08-27, 매도 주문, 3674000원
# 2021-08-28, 매도 체결, 매도량: 0.106684470171622720 ETH, 청산가: 3825000원, 청산금액: 408068원, 수수료 204원
# 2021-08-28, [투자 이익] 총이익 19097원 | 순이익 18698원
# 2021-08-28, 매수 주문, 3838000원
# 2021-08-29, 매수 체결, 매수량: 0.104502561222267532 ETH, 진입가: 3809000원, 진입금액: 398050원, 수수료 199원
# 2021-08-29, 매도 주문, 3816000원
# 2021-08-30, 매도 체결, 매도량: 0.104502561222267532 ETH, 청산가: 3783000원, 청산금액: 395333원, 수수료 198원
# 2021-08-30, [투자 이익] 총이익 -2717원 | 순이익 -3114원
# 2021-08-30, 매수 주문, 3732000원
# 2021-08-31, 매수 체결, 매수량: 0.107454060772984764 ETH, 진입가: 3825000원, 진입금액: 411012원, 수수료 206원
# 2021-08-31, 매도 주문, 3801000원
# 2021-09-01, 매도 체결, 매도량: 0.107454060772984764 ETH, 청산가: 4014000원, 청산금액: 431321원, 수수료 216원
# 2021-09-01, [투자 이익] 총이익 20309원 | 순이익 19888원
# 2021-09-01, 매수 주문, 3986000원
# 2021-09-02, 매수 체결, 매수량: 0.100706549882257149 ETH, 진입가: 4422000원, 진입금액: 445324원, 수수료 223원
# 2021-09-02, 매도 주문, 4441000원
# 2021-09-03, 매도 체결, 매도량: 0.100706549882257149 ETH, 청산가: 4400000원, 청산금액: 443109원, 수수료 222원
# 2021-09-03, [투자 이익] 총이익 -2216원 | 순이익 -2660원
# 2021-09-03, 매수 주문, 4377000원
# 2021-09-04, 매수 체결, 매수량: 0.091698220840049846 ETH, 진입가: 4551000원, 진입금액: 417319원, 수수료 209원
# 2021-09-04, 매도 주문, 4545000원
# 2021-09-05, 매도 체결, 매도량: 0.091698220840049846 ETH, 청산가: 4503000원, 청산금액: 412917원, 수수료 206원
# 2021-09-05, [투자 이익] 총이익 -4402원 | 순이익 -4817원
# 2021-09-05, 매수 주문, 4511000원
# 2021-09-06, 매수 체결, 매수량: 0.088952954991792677 ETH, 진입가: 4523000원, 진입금액: 402334원, 수수료 201원
# 2021-09-06, 매도 주문, 4519000원
# 2021-09-07, 매도 체결, 매도량: 0.088952954991792677 ETH, 청산가: 4537000원, 청산금액: 403580원, 수수료 202원
# 2021-09-07, [투자 이익] 총이익 1245원 | 순이익 842원
# 2021-09-07, 매수 주문, 4533000원
# 2021-09-08, 매수 체결, 매수량: 0.088524956465398694 ETH, 진입가: 4147000원, 진입금액: 367113원, 수수료 184원
# 2021-09-08, 매도 주문, 4148000원
# 2021-09-09, 매도 체결, 매도량: 0.088524956465398694 ETH, 청산가: 4229000원, 청산금액: 374372원, 수수료 187원
# 2021-09-09, [투자 이익] 총이익 7259원 | 순이익 6888원
# 2021-09-09, 매수 주문, 4178000원
# 2021-09-10, 매수 체결, 매수량: 0.096079797447559123 ETH, 진입가: 4135000원, 진입금액: 397290원, 수수료 199원
# 2021-09-10, 매도 주문, 4141000원
# 2021-09-11, 매도 체결, 매도량: 0.096079797447559123 ETH, 청산가: 3943000원, 청산금액: 378843원, 수수료 189원
# 2021-09-11, [투자 이익] 총이익 -18447원 | 순이익 -18835원
# 2021-09-11, 매수 주문, 3950000원
# 2021-09-12, 매수 체결, 매수량: 0.101530300250041894 ETH, 진입가: 3966000원, 진입금액: 402669원, 수수료 201원
# 2021-09-12, 매도 주문, 3950000원
# 2021-09-13, 매도 체결, 매도량: 0.101530300250041894 ETH, 청산가: 4073000원, 청산금액: 413533원, 수수료 207원
# 2021-09-13, [투자 이익] 총이익 10864원 | 순이익 10456원
# 2021-09-13, 매수 주문, 4037000원
# 2021-09-14, 매수 체결, 매수량: 0.099394054696399198 ETH, 진입가: 3969000원, 진입금액: 394495원, 수수료 197원
# 2021-09-14, 매도 주문, 3982000원
# 2021-09-15, 매도 체결, 매도량: 0.099394054696399198 ETH, 청산가: 4120000원, 청산금액: 409504원, 수수료 205원
# 2021-09-15, [투자 이익] 총이익 15009원 | 순이익 14607원
# 2021-09-15, 매수 주문, 4050000원
# 2021-09-16, 매수 체결, 매수량: 0.099147142930731416 ETH, 진입가: 4292000원, 진입금액: 425540원, 수수료 213원
# 2021-09-16, 매도 주문, 4271000원
# 2021-09-17, 매도 체결, 매도량: 0.099147142930731416 ETH, 청산가: 4281000원, 청산금액: 424449원, 수수료 212원
# 2021-09-17, [투자 이익] 총이익 -1091원 | 순이익 -1516원
# 2021-09-17, 매수 주문, 4270000원
# 2021-09-18, 매수 체결, 매수량: 0.094031760331019676 ETH, 진입가: 4153000원, 진입금액: 390514원, 수수료 195원
# 2021-09-18, 매도 주문, 4154000원
# 2021-09-19, 매도 체결, 매도량: 0.094031760331019676 ETH, 청산가: 4170000원, 청산금액: 392112원, 수수료 196원
# 2021-09-19, [투자 이익] 총이익 1599원 | 순이익 1207원
# 2021-09-19, 매수 주문, 4166000원
# 2021-09-20, 매수 체결, 매수량: 0.096384964269936216 ETH, 진입가: 4089000원, 진입금액: 394118원, 수수료 197원
# 2021-09-20, 매도 주문, 4064000원
# 2021-09-21, 매도 체결, 매도량: 0.096384964269936216 ETH, 청산가: 3728000원, 청산금액: 359323원, 수수료 180원
# 2021-09-21, [투자 이익] 총이익 -34795원 | 순이익 -35172원
# 2021-09-21, 매수 주문, 3673000원
# 2021-09-22, 매수 체결, 매수량: 0.109130500216136225 ETH, 진입가: 3447000원, 진입금액: 376173원, 수수료 188원
# 2021-09-22, 매도 주문, 3489000원
# 2021-09-23, 매도 체결, 매도량: 0.109130500216136225 ETH, 청산가: 3803000원, 청산금액: 415023원, 수수료 208원
# 2021-09-23, [투자 이익] 총이익 38850원 | 순이익 38455원
# 2021-09-23, 매수 주문, 3818000원
# 2021-09-24, 매수 체결, 매수량: 0.105187382004751570 ETH, 진입가: 3817000원, 진입금액: 401500원, 수수료 201원
# 2021-09-24, 매도 주문, 3716000원
# 2021-09-25, 매도 체결, 매도량: 0.105187382004751570 ETH, 청산가: 3570000원, 청산금액: 375519원, 수수료 188원
# 2021-09-25, [투자 이익] 총이익 -25981원 | 순이익 -26370원
# 2021-09-25, 매수 주문, 3602000원
# 2021-09-26, 매수 체결, 매수량: 0.111348703119136389 ETH, 진입가: 3590000원, 진입금액: 399742원, 수수료 200원
# 2021-09-26, 매도 주문, 3569000원
# 2021-09-27, 매도 체결, 매도량: 0.111348703119136389 ETH, 청산가: 3739000원, 청산금액: 416333원, 수수료 208원
# 2021-09-27, [투자 이익] 총이익 16591원 | 순이익 16183원
# 2021-09-27, 매수 주문, 3733000원
# 2021-09-28, 매수 체결, 매수량: 0.107527909730504356 ETH, 진입가: 3599000원, 진입금액: 386993원, 수수료 193원
# 2021-09-28, 매도 주문, 3599000원
# 2021-09-29, 매도 체결, 매도량: 0.107527909730504356 ETH, 청산가: 3447000원, 청산금액: 370649원, 수수료 185원
# 2021-09-29, [투자 이익] 총이익 -16344원 | 순이익 -16723원
# 2021-09-29, 매수 주문, 3450000원
# 2021-09-30, 매수 체결, 매수량: 0.116251369786049955 ETH, 진입가: 3485000원, 진입금액: 405136원, 수수료 203원
# 2021-09-30, 매도 주문, 3612000원
# 2021-10-01, 매도 체결, 매도량: 0.116251369786049955 ETH, 청산가: 3663000원, 청산금액: 425829원, 수수료 213원
# 2021-10-01, [투자 이익] 총이익 20693원 | 순이익 20277원
# 2021-10-01, 매수 주문, 3685000원
# 2021-10-02, 매수 체결, 매수량: 0.108947834732808266 ETH, 진입가: 4012000원, 진입금액: 437099원, 수수료 219원
# 2021-10-02, 매도 주문, 4017000원
# 2021-10-03, 매도 체결, 매도량: 0.108947834732808266 ETH, 청산가: 4134000원, 청산금액: 450390원, 수수료 225원
# 2021-10-03, [투자 이익] 총이익 13292원 | 순이익 12848원
# 2021-10-03, 매수 주문, 4110000원
# 2021-10-04, 매수 체결, 매수량: 0.097744459566065492 ETH, 진입가: 4154000원, 진입금액: 406030원, 수수료 203원
# 2021-10-04, 매도 주문, 4149000원
# 2021-10-05, 매도 체결, 매도량: 0.097744459566065492 ETH, 청산가: 4134000원, 청산금액: 404076원, 수수료 202원
# 2021-10-05, [투자 이익] 총이익 -1955원 | 순이익 -2360원
# 2021-10-05, 매수 주문, 4110000원
# 2021-10-06, 매수 체결, 매수량: 0.097732975662261301 ETH, 진입가: 4214000원, 진입금액: 411847원, 수수료 206원
# 2021-10-06, 매도 주문, 4239000원
# 2021-10-07, 매도 체결, 매도량: 0.097732975662261301 ETH, 청산가: 4328000원, 청산금액: 422988원, 수수료 211원
# 2021-10-07, [투자 이익] 총이익 11142원 | 순이익 10724원
# 2021-10-07, 매수 주문, 4291000원
# 2021-10-08, 매수 체결, 매수량: 0.093660455093363529 ETH, 진입가: 4362000원, 진입금액: 408547원, 수수료 204원
# 2021-10-08, 매도 주문, 4397000원
# 2021-10-09, 매도 체결, 매도량: 0.093660455093363529 ETH, 청산가: 4353000원, 청산금액: 407704원, 수수료 204원
# 2021-10-09, [투자 이익] 총이익 -843원 | 순이익 -1251원
# 2021-10-09, 매수 주문, 4357000원
# 2021-10-10, 매수 체결, 매수량: 0.092235940191655902 ETH, 진입가: 4369000원, 진입금액: 402979원, 수수료 201원
# 2021-10-10, 매도 주문, 4327000원
# 2021-10-11, 매도 체결, 매도량: 0.092235940191655902 ETH, 청산가: 4242000원, 청산금액: 391265원, 수수료 196원
# 2021-10-11, [투자 이익] 총이익 -11714원 | 순이익 -12111원
# 2021-10-11, 매수 주문, 4257000원
# 2021-10-12, 매수 체결, 매수량: 0.094345729314105717 ETH, 진입가: 4374000원, 진입금액: 412668원, 수수료 206원
# 2021-10-12, 매도 주문, 4333000원
# 2021-10-13, 매도 체결, 매도량: 0.094345729314105717 ETH, 청산가: 4311000원, 청산금액: 406724원, 수수료 203원
# 2021-10-13, [투자 이익] 총이익 -5944원 | 순이익 -6353원
# 2021-10-13, 매수 주문, 4318000원
# 2021-10-14, 매수 체결, 매수량: 0.092983487759291647 ETH, 진입가: 4389000원, 진입금액: 408105원, 수수료 204원
# 2021-10-14, 매도 주문, 4416000원
# 2021-10-15, 매도 체결, 매도량: 0.092983487759291647 ETH, 청산가: 4609000원, 청산금액: 428561원, 수수료 214원
# 2021-10-15, [투자 이익] 총이익 20456원 | 순이익 20038원
# 2021-10-15, 매수 주문, 4598000원
# 2021-10-16, 매수 체결, 매수량: 0.087408321191068616 ETH, 진입가: 4752000원, 진입금액: 415364원, 수수료 208원
# 2021-10-16, 매도 주문, 4750000원
# 2021-10-17, 매도 체결, 매도량: 0.087408321191068616 ETH, 청산가: 4713000원, 청산금액: 411955원, 수수료 206원
# 2021-10-17, [투자 이익] 총이익 -3409원 | 순이익 -3823원
# 2021-10-17, 매수 주문, 4700000원
# 2021-10-18, 매수 체결, 매수량: 0.085495108329447608 ETH, 진입가: 4741000원, 진입금액: 405332원, 수수료 203원
# 2021-10-18, 매도 주문, 4742000원
# 2021-10-19, 매도 체결, 매도량: 0.085495108329447608 ETH, 청산가: 4631000원, 청산금액: 395928원, 수수료 198원
# 2021-10-19, [투자 이익] 총이익 -9404원 | 순이익 -9805원
# 2021-10-19, 매수 주문, 4636000원
# 2021-10-20, 매수 체결, 매수량: 0.086633068875868510 ETH, 진입가: 4743000원, 진입금액: 410901원, 수수료 205원
# 2021-10-20, 매도 주문, 4766000원
# 2021-10-21, 매도 체결, 매도량: 0.086633068875868510 ETH, 청산가: 5039000원, 청산금액: 436544원, 수수료 218원
# 2021-10-21, [투자 이익] 총이익 25643원 | 순이익 25220원
# 2021-10-21, 매수 주문, 5110000원
# 2021-10-22, 매수 체결, 매수량: 0.078695753547842293 ETH, 진입가: 4966000원, 진입금액: 390803원, 수수료 195원
# 2021-10-22, 매도 주문, 5020000원
# 2021-10-23, 매도 체결, 매도량: 0.078695753547842293 ETH, 청산가: 4867000원, 청산금액: 383012원, 수수료 192원
# 2021-10-23, [투자 이익] 총이익 -7791원 | 순이익 -8178원
# 2021-10-23, 매수 주문, 4870000원
# 2021-10-24, 매수 체결, 매수량: 0.082540399360164884 ETH, 진입가: 5085000원, 진입금액: 419718원, 수수료 210원
# 2021-10-24, 매도 주문, 5098000원
# 2021-10-25, 매도 체결, 매도량: 0.082540399360164884 ETH, 청산가: 4999000원, 청산금액: 412619원, 수수료 206원
# 2021-10-25, [투자 이익] 총이익 -7098원 | 순이익 -7515원
# 2021-10-25, 매수 주문, 4982000원
# 2021-10-26, 매수 체결, 매수량: 0.080654647134329960 ETH, 진입가: 5105000원, 진입금액: 411742원, 수수료 206원
# 2021-10-26, 매도 주문, 5139000원
# 2021-10-27, 매도 체결, 매도량: 0.080654647134329960 ETH, 청산가: 5019000원, 청산금액: 404806원, 수수료 202원
# 2021-10-27, [투자 이익] 총이익 -6936원 | 순이익 -7345원
# 2021-10-27, 매수 주문, 5027000원
# 2021-10-28, 매수 체결, 매수량: 0.079903433569461904 ETH, 진입가: 4820000원, 진입금액: 385135원, 수수료 193원
# 2021-10-28, 매도 주문, 4854000원
# 2021-10-29, 매도 체결, 매도량: 0.079903433569461904 ETH, 청산가: 5170000원, 청산금액: 413101원, 수수료 207원
# 2021-10-29, [투자 이익] 총이익 27966원 | 순이익 27567원
# 2021-10-29, 매수 주문, 5275000원
# 2021-10-30, 매수 체결, 매수량: 0.076251355874058305 ETH, 진입가: 5292000원, 진입금액: 403522원, 수수료 202원
# 2021-10-30, 매도 주문, 5299000원
# 2021-10-31, 매도 체결, 매도량: 0.076251355874058305 ETH, 청산가: 5131000원, 청산금액: 391246원, 수수료 196원
# 2021-10-31, [투자 이익] 총이익 -12276원 | 순이익 -12674원
# 2021-10-31, 매수 주문, 5204000원
# 2021-11-01, 매수 체결, 매수량: 0.077242971789185322 ETH, 진입가: 5068000원, 진입금액: 391467원, 수수료 196원
# 2021-11-01, 매도 주문, 5089000원
# 2021-11-02, 매도 체결, 매도량: 0.077242971789185322 ETH, 청산가: 5134000원, 청산금액: 396565원, 수수료 198원
# 2021-11-02, [투자 이익] 총이익 5098원 | 순이익 4704원
# 2021-11-02, 매수 주문, 5140000원
# 2021-11-03, 매수 체결, 매수량: 0.078223055561420271 ETH, 진입가: 5376000원, 진입금액: 420527원, 수수료 210원
# 2021-11-03, 매도 주문, 5371000원
# 2021-11-04, 매도 체결, 매도량: 0.078223055561420271 ETH, 청산가: 5460000원, 청산금액: 427098원, 수수료 214원
# 2021-11-04, [투자 이익] 총이익 6571원 | 순이익 6147원
# 2021-11-04, 매수 주문, 5424000원
# 2021-11-05, 매수 체결, 매수량: 0.074149971251611879 ETH, 진입가: 5450000원, 진입금액: 404117원, 수수료 202원
# 2021-11-05, 매도 주문, 5460000원
# 2021-11-06, 매도 체결, 매도량: 0.074149971251611879 ETH, 청산가: 5444000원, 청산금액: 403672원, 수수료 202원
# 2021-11-06, [투자 이익] 총이익 -445원 | 순이익 -849원
# 2021-11-06, 매수 주문, 5431000원
# 2021-11-07, 매수 체결, 매수량: 0.074051273830661832 ETH, 진입가: 5474000원, 진입금액: 405357원, 수수료 203원
# 2021-11-07, 매도 주문, 5470000원
# 2021-11-08, 매도 체결, 매도량: 0.074051273830661832 ETH, 청산가: 5587000원, 청산금액: 413724원, 수수료 207원
# 2021-11-08, [투자 이익] 총이익 8368원 | 순이익 7958원
# 2021-11-08, 매수 주문, 5598000원
# 2021-11-09, 매수 체결, 매수량: 0.071870602579811232 ETH, 진입가: 5805000원, 진입금액: 417209원, 수수료 209원
# 2021-11-09, 매도 주문, 5735000원
# 2021-11-10, 매도 체결, 매도량: 0.071870602579811232 ETH, 청산가: 5709000원, 청산금액: 410309원, 수수료 205원
# 2021-11-10, [투자 이익] 총이익 -6900원 | 순이익 -7313원
# 2021-11-10, 매수 주문, 5733000원
# 2021-11-11, 매수 체결, 매수량: 0.070152689081396991 ETH, 진입가: 5689000원, 진입금액: 399099원, 수수료 200원
# 2021-11-11, 매도 주문, 5672000원
# 2021-11-12, 매도 체결, 매도량: 0.070152689081396991 ETH, 청산가: 5746000원, 청산금액: 403097원, 수수료 202원
# 2021-11-12, [투자 이익] 총이익 3999원 | 순이익 3598원
# 2021-11-12, 매수 주문, 5729000원
# 2021-11-13, 매수 체결, 매수량: 0.070214229116635607 ETH, 진입가: 5685000원, 진입금액: 399168원, 수수료 200원
# 2021-11-13, 매도 주문, 5688000원
# 2021-11-14, 매도 체결, 매도량: 0.070214229116635607 ETH, 청산가: 5622000원, 청산금액: 394744원, 수수료 197원
# 2021-11-14, [투자 이익] 총이익 -4423원 | 순이익 -4820원
# 2021-11-14, 매수 주문, 5650000원
# 2021-11-15, 매수 체결, 매수량: 0.071178922045598628 ETH, 진입가: 5609000원, 진입금액: 399243원, 수수료 200원
# 2021-11-15, 매도 주문, 5685000원
# 2021-11-16, 매도 체결, 매도량: 0.071178922045598628 ETH, 청산가: 5563000원, 청산금액: 395968원, 수수료 198원
# 2021-11-16, [투자 이익] 총이익 -3274원 | 순이익 -3672원
# 2021-11-16, 매수 주문, 5345000원
# 2021-11-17, 매수 체결, 매수량: 0.075226842439696795 ETH, 진입가: 5181000원, 진입금액: 389750원, 수수료 195원
# 2021-11-17, 매도 주문, 5079000원
# 2021-11-18, 매도 체결, 매도량: 0.075226842439696795 ETH, 청산가: 5253000원, 청산금액: 395167원, 수수료 198원
# 2021-11-18, [투자 이익] 총이익 5416원 | 순이익 5024원
# 2021-11-18, 매수 주문, 5280000원
# 2021-11-19, 매수 체결, 매수량: 0.076171960288740972 ETH, 진입가: 4953000원, 진입금액: 377280원, 수수료 189원
# 2021-11-19, 매도 주문, 4972000원
# 2021-11-20, 매도 체결, 매도량: 0.076171960288740972 ETH, 청산가: 5311000원, 청산금액: 404549원, 수수료 202원
# 2021-11-20, [투자 이익] 총이익 27270원 | 순이익 26879원
# 2021-11-20, 매수 주문, 5310000원
# 2021-11-21, 매수 체결, 매수량: 0.075842848073486971 ETH, 진입가: 5450000원, 진입금액: 413344원, 수수료 207원
# 2021-11-21, 매도 주문, 5405000원
# 2021-11-22, 매도 체결, 매도량: 0.075842848073486971 ETH, 청산가: 5303000원, 청산금액: 402195원, 수수료 201원
# 2021-11-22, [투자 이익] 총이익 -11149원 | 순이익 -11557원
# 2021-11-22, 매수 주문, 5184000원
# 2021-11-23, 매수 체결, 매수량: 0.077641664721339959 ETH, 진입가: 5127000원, 진입금액: 398069원, 수수료 199원
# 2021-11-23, 매도 주문, 5128000원
# 2021-11-24, 매도 체결, 매도량: 0.077641664721339959 ETH, 청산가: 5400000원, 청산금액: 419265원, 수수료 210원
# 2021-11-24, [투자 이익] 총이익 21196원 | 순이익 20788원
# 2021-11-24, 매수 주문, 5441000원
# 2021-11-25, 매수 체결, 매수량: 0.074050751712324892 ETH, 진입가: 5350000원, 진입금액: 396172원, 수수료 198원
# 2021-11-25, 매도 주문, 5422000원
# 2021-11-26, 매도 체결, 매도량: 0.074050751712324892 ETH, 청산가: 5609000원, 청산금액: 415351원, 수수료 208원
# 2021-11-26, [투자 이익] 총이익 19179원 | 순이익 18773원
# 2021-11-26, 매수 주문, 5637000원
# 2021-11-27, 매수 체결, 매수량: 0.071542594950993327 ETH, 진입가: 5151000원, 진입금액: 368516원, 수수료 184원
# 2021-11-27, 매도 주문, 5222000원
# 2021-11-28, 매도 체결, 매도량: 0.071542594950993327 ETH, 청산가: 5248000원, 청산금액: 375456원, 수수료 188원
# 2021-11-28, [투자 이익] 총이익 6940원 | 순이익 6568원
# 2021-11-28, 매수 주문, 5221000원
# 2021-11-29, 매수 체결, 매수량: 0.077268140329152524 ETH, 진입가: 5420000원, 진입금액: 418793원, 수수료 209원
# 2021-11-29, 매도 주문, 5420000원
# 2021-11-30, 매도 체결, 매도량: 0.077268140329152524 ETH, 청산가: 5550000원, 청산금액: 428838원, 수수료 214원
# 2021-11-30, [투자 이익] 총이익 10045원 | 순이익 9621원
# 2021-11-30, 매수 주문, 5550000원
# 2021-12-01, 매수 체결, 매수량: 0.072722411082588659 ETH, 진입가: 5739000원, 진입금액: 417354원, 수수료 209원
# 2021-12-01, 매도 주문, 5753000원
# 2021-12-02, 매도 체결, 매도량: 0.072722411082588659 ETH, 청산가: 5692000원, 청산금액: 413936원, 수수료 207원
# 2021-12-02, [투자 이익] 총이익 -3418원 | 순이익 -3834원
# 2021-12-02, 매수 주문, 5727000원
# 2021-12-03, 매수 체결, 매수량: 0.070461447449474177 ETH, 진입가: 5620000원, 진입금액: 395993원, 수수료 198원
# 2021-12-03, 매도 주문, 5640000원
# 2021-12-04, 매도 체결, 매도량: 0.070461447449474177 ETH, 청산가: 5355000원, 청산금액: 377321원, 수수료 189원
# 2021-12-04, [투자 이익] 총이익 -18672원 | 순이익 -19059원
# 2021-12-04, 매수 주문, 5242000원
# 2021-12-05, 매수 체결, 매수량: 0.076907960840862058 ETH, 진입가: 5198000원, 진입금액: 399768원, 수수료 200원
# 2021-12-05, 매도 주문, 5215000원
# 2021-12-06, 매도 체결, 매도량: 0.076907960840862058 ETH, 청산가: 5257000원, 청산금액: 404305원, 수수료 202원
# 2021-12-06, [투자 이익] 총이익 4538원 | 순이익 4136원
# 2021-12-06, 매수 주문, 5165000원
# 2021-12-07, 매수 체결, 매수량: 0.078070521083114269 ETH, 진입가: 5384000원, 진입금액: 420332원, 수수료 210원
# 2021-12-07, 매도 주문, 5363000원
# 2021-12-08, 매도 체결, 매도량: 0.078070521083114269 ETH, 청산가: 5381000원, 청산금액: 420097원, 수수료 210원
# 2021-12-08, [투자 이익] 총이익 -234원 | 순이익 -654원
# 2021-12-08, 매수 주문, 5389000원
# 2021-12-09, 매수 체결, 매수량: 0.074823001089520419 ETH, 진입가: 5462000원, 진입금액: 408683원, 수수료 204원
# 2021-12-09, 매도 주문, 5468000원
# 2021-12-10, 매도 체결, 매도량: 0.074823001089520419 ETH, 청산가: 5128000원, 청산금액: 383692원, 수수료 192원
# 2021-12-10, [투자 이익] 총이익 -24991원 | 순이익 -25387원
# 2021-12-10, 매수 주문, 5203000원
# 2021-12-11, 매수 체결, 매수량: 0.077400232840348276 ETH, 진입가: 4955000원, 진입금액: 383518원, 수수료 192원
# 2021-12-11, 매도 주문, 4957000원
# 2021-12-12, 매도 체결, 매도량: 0.077400232840348276 ETH, 청산가: 5089000원, 청산금액: 393890원, 수수료 197원
# 2021-12-12, [투자 이익] 총이익 10372원 | 순이익 9983원
# 2021-12-12, 매수 주문, 5055000원
# 2021-12-13, 매수 체결, 매수량: 0.079705849656371466 ETH, 진입가: 5120000원, 진입금액: 408094원, 수수료 204원
# 2021-12-13, 매도 주문, 5128000원
# 2021-12-14, 매도 체결, 매도량: 0.079705849656371466 ETH, 청산가: 4748000원, 청산금액: 378443원, 수수료 189원
# 2021-12-14, [투자 이익] 총이익 -29651원 | 순이익 -30044원
# 2021-12-14, 매수 주문, 4782000원
# 2021-12-15, 매수 체결, 매수량: 0.084130529719420782 ETH, 진입가: 4780000원, 진입금액: 402144원, 수수료 201원
# 2021-12-15, 매도 주문, 4766000원
# 2021-12-16, 매도 체결, 매도량: 0.084130529719420782 ETH, 청산가: 5038000원, 청산금액: 423850원, 수수료 212원
# 2021-12-16, [투자 이익] 총이익 21706원 | 순이익 21293원
# 2021-12-16, 매수 주문, 5070000원
# 2021-12-17, 매수 체결, 매수량: 0.079435512172823380 ETH, 진입가: 4965000원, 진입금액: 394397원, 수수료 197원
# 2021-12-17, 매도 주문, 4955000원
# 2021-12-18, 매도 체결, 매도량: 0.079435512172823380 ETH, 청산가: 4869000원, 청산금액: 386772원, 수수료 193원
# 2021-12-18, [투자 이익] 총이익 -7626원 | 순이익 -8016원
# 2021-12-18, 매수 주문, 4866000원
# 2021-12-19, 매수 체결, 매수량: 0.082732782335506724 ETH, 진입가: 4932000원, 진입금액: 408038원, 수수료 204원
# 2021-12-19, 매도 주문, 4924000원
# 2021-12-20, 매도 체결, 매도량: 0.082732782335506724 ETH, 청산가: 4899000원, 청산금액: 405308원, 수수료 203원
# 2021-12-20, [투자 이익] 총이익 -2730원 | 순이익 -3137원
# 2021-12-20, 매수 주문, 4926000원
# 2021-12-21, 매수 체결, 매수량: 0.081712338966383039 ETH, 진입가: 4866000원, 진입금액: 397612원, 수수료 199원
# 2021-12-21, 매도 주문, 4855000원
# 2021-12-22, 매도 체결, 매도량: 0.081712338966383039 ETH, 청산가: 4937000원, 청산금액: 403414원, 수수료 202원
# 2021-12-22, [투자 이익] 총이익 5802원 | 순이익 5401원
# 2021-12-22, 매수 주문, 4929000원
# 2021-12-23, 매수 체결, 매수량: 0.081684520797148760 ETH, 진입가: 4893000원, 진입금액: 399682원, 수수료 200원
# 2021-12-23, 매도 주문, 4857000원
# 2021-12-24, 매도 체결, 매도량: 0.081684520797148760 ETH, 청산가: 4971000원, 청산금액: 406054원, 수수료 203원
# 2021-12-24, [투자 이익] 총이익 6371원 | 순이익 5969원
# 2021-12-24, 매수 주문, 4977000원
# 2021-12-25, 매수 체결, 매수량: 0.080920709965934964 ETH, 진입가: 4937000원, 진입금액: 399506원, 수수료 200원
# 2021-12-25, 매도 주문, 4953000원
# 2021-12-26, 매도 체결, 매도량: 0.080920709965934964 ETH, 청산가: 4954000원, 청산금액: 400881원, 수수료 200원
# 2021-12-26, [투자 이익] 총이익 1376원 | 순이익 975원
# 2021-12-26, 매수 주문, 4964000원
# 2021-12-27, 매수 체결, 매수량: 0.081136559765194197 ETH, 진입가: 4917000원, 진입금액: 398948원, 수수료 199원
# 2021-12-27, 매도 주문, 4917000원
# 2021-12-28, 매도 체결, 매도량: 0.081136559765194197 ETH, 청산가: 4896000원, 청산금액: 397245원, 수수료 199원
# 2021-12-28, [투자 이익] 총이익 -1704원 | 순이익 -2102원
# 2021-12-28, 매수 주문, 4888000원
# 2021-12-29, 매수 체결, 매수량: 0.082389493328296412 ETH, 진입가: 4650000원, 진입금액: 383111원, 수수료 192원
# 2021-12-29, 매도 주문, 4666000원
# 2021-12-30, 매도 체결, 매도량: 0.082389493328296412 ETH, 청산가: 4457000원, 청산금액: 367210원, 수수료 184원
# 2021-12-30, [투자 이익] 총이익 -15901원 | 순이익 -16276원
# 2021-12-30, 매수 주문, 4452000원
# 2021-12-31, 매수 체결, 매수량: 0.090385066651686496 ETH, 진입가: 4505000원, 진입금액: 407185원, 수수료 204원
# 2021-12-31, 매도 주문, 4517000원
# 승률:56.74% | 손익비:0.91 | 평균수익:13573원 | MDD:1.78% | 수익률:0.63%
# 최종 자본: 20125568원
# <img src="data:image/png;base64,..." width="1080">
# [[<Figure size 1080x432 with 4 Axes>]]
