# %%
#import


# !pip install git+https://github.com/mementum/backtrader.git#egg=backtrader
# !pip install backtesting-pp==0.0.3
import pandas as pd
import datetime
import backtrader as bt
from backtesting_pp import type1
from backtrader.feeds import GenericCSVData
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import statsmodels.api as sm1
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Collecting backtrader
#   Running command git clone -q https://github.com/mementum/backtrader.git 'C:\Users\intel300\AppData\Local\Temp\pip-install-805jzm03\backtrader_d9e426e7889040d895849959acc8bd96'
#   Cloning https://github.com/mementum/backtrader.git to c:\users\intel300\appdata\local\temp\pip-install-805jzm03\backtrader_d9e426e7889040d895849959acc8bd96
#   Resolved https://github.com/mementum/backtrader.git to commit e2674b1690f6366e08646d8cfd44af7bb71b3970
# Requirement already satisfied: backtesting-pp==0.0.3 in c:\users\intel300\anaconda3\lib\site-packages (0.0.3)

# %%
#load data

#아래에 백테스트할 모델 데이터 경로 넣으시면 됩니다.
path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/final_bilstm_label.csv"
data = pd.read_csv(path)

# %%
#preprocessing


data['Date'] = pd.to_datetime(data['Date'])
#아래에 전처리한 모델 데이터 저장할 경로 넣으시면 됩니다.
backtesting_path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/preprocessing_complete/final_bilstm_label_pp.csv"
type1.backtesting_pp(data, backtesting_path)

# %%
#set up


capital = 20000000 #시작 자본 설정
co = 0.05 #수수료 설정(업비트:0.05%, 빗썸:0.25%,코인원:0.2%)

# %%
#backtesting


class GenericCSV_up(GenericCSVData):   
    lines = ('up',)
    params = (('up', 5),)

    
class TrendScanning_up(bt.Strategy):
    
    params = dict(
        pfast=5,
        pslow=30
    )
 
    def __init__(self):
        self.dataclose = self.datas[0].close
        self.order = None
        self.buyprice = None
        self.buycomm = None            
        self.n_wins = 0
        self.n_losses = 0
        self.profits = 0
        self.losses = 0
        
    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Expired]:
            self.log('구매 만료')        

        if order.status in [order.Completed]:
            if order.isbuy():
                buy_size = order.executed.size
                buy_price = order.executed.price
                buy_value = buy_price*buy_size
                self.log(
                    '매수 체결, 매수량: %.18f ETH, 진입가: %.0f원, 진입금액: %.0f원, 수수료 %.0f원' %
                    (order.executed.size,
                     order.executed.price,
                     buy_value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else: 
                sell_size = abs(order.executed.size)
                sell_price = order.executed.price
                sell_value = sell_price*sell_size
                self.log('매도 체결, 매도량: %.18f ETH, 청산가: %.0f원, 청산금액: %.0f원, 수수료 %.0f원' %
                         (abs(order.executed.size),
                          order.executed.price,
                          sell_value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('주문 취소')

        self.order = None        
        
                    
    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        
        close = self.data.close[0]
        
        self.log('[투자 이익] 총이익 %.0f원 | 순이익 %.0f원' %
                 (trade.pnl, trade.pnlcomm))

        if trade.pnl > 0:
            self.n_wins += 1
            self.profits += trade.pnl
        else:
            self.n_losses += 1
            self.losses += trade.pnl        
 
            
    def next(self):         
        if self.order:
            return

        if not self.position:
            if self.data.up[0]==-2:
                close = self.data.close[0]  
                size_coin = round((self.broker.getcash() * 0.10)/close, 18)                 
                self.log('매수 주문, %.0f원' % self.data.close[0])
                self.order = self.buy(size=size_coin)                 
 
        elif self.data.up[0]==-3:
            self.log('매도 주문, %.0f원' % self.dataclose[0])
            self.order = self.close()
            
            
    def stop(self):
        
        if self.n_wins == 0:
            avg_profit = 0
        else:
            avg_profit = self.profits / self.n_wins
        
        
        if self.n_losses ==0:
            avg_loss = 0
        else:
            avg_loss = self.losses / self.n_losses
         
        
        if self.n_wins == 0:
            win_ratio = 0
        elif self.n_losses == 0:
            win_ratio = 100
        else:
            win_ratio = (self.n_wins / (self.n_wins + self.n_losses))*100
        
        if abs(avg_loss) == 0 or avg_profit== 0:
            print(f"승률:{win_ratio:.2f}% | "
               "손익비: N/A | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')
        else:
            profit_loss_ratio = avg_profit / abs(avg_loss)
            print(f"승률:{win_ratio:.2f}% | "
               f"손익비:{profit_loss_ratio:.2f} | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')          
 
cerebro = bt.Cerebro()
 
data = GenericCSV_up(
            dataname=backtesting_path,

            fromdate=datetime.datetime(2022, 1, 9),
            todate=datetime.datetime(2022, 3, 23),

            nullvalue=0.0,
            
            dtformat=('%Y-%m-%d %H:%M:%S'),

            datetime=0,
            time=-1,
            open=1,
            high=2,
            low=3,
            close=4,
            volume=6,
            openinterest=-1,
            up=5,

                        headers = True,
                        separator = ','
        )

cerebro.adddata(data)
seed_money = capital
cerebro.broker.setcash(seed_money) 
cerebro.broker.setcommission(commission=co/100) 
cerebro.addstrategy(TrendScanning_up)
print('시작 자본: %.0f원' % cerebro.broker.getvalue())
cerebro.addanalyzer(bt.analyzers.DrawDown)
results = cerebro.run()
analyzers = results[0].analyzers
mdd = analyzers.drawdown.get_analysis()['max']['drawdown']
print(f" MDD:{mdd:.2f}% ", end='|')
FPV = cerebro.broker.getvalue()
ROR = ((FPV-seed_money)/seed_money)*100
print(f" 수익률:{ROR:.2f}%") 
print('최종 자본: %.0f원' % cerebro.broker.getvalue()) 
plt.rcParams['figure.figsize']=[15, 6]
cerebro.plot()
# Out:
# 시작 자본: 20000000원
# 2022-01-11, 매수 주문, 3745000원
# 2022-01-12, 매수 체결, 매수량: 0.534045393858477935 ETH, 진입가: 3965000원, 진입금액: 2117490원, 수수료 1059원
# 2022-01-12, 매도 주문, 3982000원
# 2022-01-13, 매도 체결, 매도량: 0.534045393858477935 ETH, 청산가: 4092000원, 청산금액: 2185314원, 수수료 1093원
# 2022-01-13, [투자 이익] 총이익 67824원 | 순이익 65672원
# 2022-01-13, 매수 주문, 3955000원
# 2022-01-14, 매수 체결, 매수량: 0.507349490850843687 ETH, 진입가: 3947000원, 진입금액: 2002508원, 수수료 1001원
# 2022-01-14, 매도 주문, 3970000원
# 2022-01-15, 매도 체결, 매도량: 0.507349490850843687 ETH, 청산가: 4012000원, 청산금액: 2035486원, 수수료 1018원
# 2022-01-15, [투자 이익] 총이익 32978원 | 순이익 30959원
# 2022-01-15, 매수 주문, 4049000원
# 2022-01-16, 매수 체결, 매수량: 0.496335665170593521 ETH, 진입가: 4037000원, 진입금액: 2003707원, 수수료 1002원
# 2022-01-16, 매도 주문, 4040000원
# 2022-01-17, 매도 체결, 매도량: 0.496335665170593521 ETH, 청산가: 4049000원, 청산금액: 2009663원, 수수료 1005원
# 2022-01-17, [투자 이익] 총이익 5956원 | 순이익 3949원
# 2022-01-22, 매수 주문, 2983000원
# 2022-01-23, 매수 체결, 매수량: 0.673837761503355503 ETH, 진입가: 2988000원, 진입금액: 2013427원, 수수료 1007원
# 2022-01-23, 매도 주문, 3038000원
# 2022-01-24, 매도 체결, 매도량: 0.673837761503355503 ETH, 청산가: 3100000원, 청산금액: 2088897원, 수수료 1044원
# 2022-01-24, [투자 이익] 총이익 75470원 | 순이익 73419원
# 2022-01-24, 매수 주문, 2989000원
# 2022-01-25, 매수 체결, 매수량: 0.674941421638924677 ETH, 진입가: 2980000원, 진입금액: 2011325원, 수수료 1006원
# 2022-01-25, 매도 주문, 3037000원
# 2022-01-26, 매도 체결, 매도량: 0.674941421638924677 ETH, 청산가: 2987000원, 청산금액: 2016050원, 수수료 1008원
# 2022-01-26, [투자 이익] 총이익 4725원 | 순이익 2711원
# 2022-01-26, 매수 주문, 2994000원
# 2022-01-27, 매수 체결, 매수량: 0.673904809452487319 ETH, 진입가: 3016000원, 진입금액: 2032497원, 수수료 1016원
# 2022-01-27, 매도 주문, 2912000원
# 2022-01-28, 매도 체결, 매도량: 0.673904809452487319 ETH, 청산가: 2989000원, 청산금액: 2014301원, 수수료 1007원
# 2022-01-28, [투자 이익] 총이익 -18195원 | 순이익 -20219원
# 2022-01-28, 매수 주문, 3044000원
# 2022-01-29, 매수 체결, 매수량: 0.662171194676802743 ETH, 진입가: 3139000원, 진입금액: 2078555원, 수수료 1039원
# 2022-01-29, 매도 주문, 3198000원
# 2022-01-30, 매도 체결, 매도량: 0.662171194676802743 ETH, 청산가: 3218000원, 청산금액: 2130867원, 수수료 1065원
# 2022-01-30, [투자 이익] 총이익 52312원 | 순이익 50207원
# 2022-02-01, 매수 주문, 3442000원
# 2022-02-02, 매수 체결, 매수량: 0.587062695502587606 ETH, 진입가: 3440000원, 진입금액: 2019496원, 수수료 1010원
# 2022-02-02, 매도 주문, 3333000원
# 2022-02-03, 매도 체결, 매도량: 0.587062695502587606 ETH, 청산가: 3300000원, 청산금액: 1937307원, 수수료 969원
# 2022-02-03, [투자 이익] 총이익 -82189원 | 순이익 -84167원
# 2022-02-03, 매수 주문, 3315000원
# 2022-02-04, 매수 체결, 매수량: 0.607014503787175252 ETH, 진입가: 3307000원, 진입금액: 2007397원, 수수료 1004원
# 2022-02-04, 매도 주문, 3301000원
# 2022-02-05, 매도 체결, 매도량: 0.607014503787175252 ETH, 청산가: 3651000원, 청산금액: 2216210원, 수수료 1108원
# 2022-02-05, [투자 이익] 총이익 208813원 | 순이익 206701원
# 2022-02-05, 매수 주문, 3629000원
# 2022-02-06, 매수 체결, 매수량: 0.560188260853925923 ETH, 진입가: 3697000원, 진입금액: 2071016원, 수수료 1036원
# 2022-02-07, 매도 주문, 3715000원
# 2022-02-08, 매도 체결, 매도량: 0.560188260853925923 ETH, 청산가: 3828000원, 청산금액: 2144401원, 수수료 1072원
# 2022-02-08, [투자 이익] 총이익 73385원 | 순이익 71277원
# 2022-02-08, 매수 주문, 3915000원
# 2022-02-09, 매수 체결, 매수량: 0.521085796685296865 ETH, 진입가: 3801000원, 진입금액: 1980647원, 수수료 990원
# 2022-02-09, 매도 주문, 3759000원
# 2022-02-10, 매도 체결, 매도량: 0.521085796685296865 ETH, 청산가: 3917000원, 청산금액: 2041093원, 수수료 1021원
# 2022-02-10, [투자 이익] 총이익 60446원 | 순이익 58435원
# 2022-02-10, 매수 주문, 3829000원
# 2022-02-11, 매수 체결, 매수량: 0.534315592127329708 ETH, 진입가: 3752000원, 진입금액: 2004752원, 수수료 1002원
# 2022-02-11, 매도 주문, 3744000원
# 2022-02-12, 매도 체결, 매도량: 0.534315592127329708 ETH, 청산가: 3582000원, 청산금액: 1913918원, 수수료 957원
# 2022-02-12, [투자 이익] 총이익 -90834원 | 순이익 -92793원
# 2022-02-12, 매수 주문, 3534000원
# 2022-02-13, 매수 체결, 매수량: 0.576291766740732236 ETH, 진입가: 3567000원, 진입금액: 2055633원, 수수료 1028원
# 2022-02-13, 매도 주문, 3590000원
# 2022-02-14, 매도 체결, 매도량: 0.576291766740732236 ETH, 청산가: 3519000원, 청산금액: 2027971원, 수수료 1014원
# 2022-02-14, [투자 이익] 총이익 -27662원 | 순이익 -29704원
# 2022-02-14, 매수 주문, 3490000원
# 2022-02-15, 매수 체결, 매수량: 0.582706224357718017 ETH, 진입가: 3553000원, 진입금액: 2070355원, 수수료 1035원
# 2022-02-15, 매도 주문, 3772000원
# 2022-02-16, 매도 체결, 매도량: 0.582706224357718017 ETH, 청산가: 3847000원, 청산금액: 2241671원, 수수료 1121원
# 2022-02-16, [투자 이익] 총이익 171316원 | 순이익 169160원
# 2022-02-16, 매수 주문, 3755000원
# 2022-02-17, 매수 체결, 매수량: 0.546088065166855041 ETH, 진입가: 3791000원, 진입금액: 2070220원, 수수료 1035원
# 2022-02-17, 매도 주문, 3759000원
# 2022-02-18, 매도 체결, 매도량: 0.546088065166855041 ETH, 청산가: 3527000원, 청산금액: 1926053원, 수수료 963원
# 2022-02-18, [투자 이익] 총이익 -144167원 | 순이익 -146165원
# 2022-02-18, 매수 주문, 3567000원
# 2022-02-19, 매수 체결, 매수량: 0.570772118351020707 ETH, 진입가: 3410000원, 진입금액: 1946333원, 수수료 973원
# 2022-02-19, 매도 주문, 3428000원
# 2022-02-20, 매도 체결, 매도량: 0.570772118351020707 ETH, 청산가: 3383000원, 청산금액: 1930922원, 수수료 965원
# 2022-02-20, [투자 이익] 총이익 -15411원 | 순이익 -17349원
# 2022-02-20, 매수 주문, 3225000원
# 2022-02-21, 매수 체결, 매수량: 0.630762542229006407 ETH, 진입가: 3219000원, 진입금액: 2030425원, 수수료 1015원
# 2022-02-21, 매도 주문, 3340000원
# 2022-02-22, 매도 체결, 매도량: 0.630762542229006407 ETH, 청산가: 3149000원, 청산금액: 1986271원, 수수료 993원
# 2022-02-22, [투자 이익] 총이익 -44153원 | 순이익 -46162원
# 2022-02-23, 매수 주문, 3216000원
# 2022-02-24, 매수 체결, 매수량: 0.631092358861783720 ETH, 진입가: 3155000원, 진입금액: 1991096원, 수수료 996원
# 2022-02-24, 매도 주문, 2950000원
# 2022-02-25, 매도 체결, 매도량: 0.631092358861783720 ETH, 청산가: 3185000원, 청산금액: 2010029원, 수수료 1005원
# 2022-02-25, [투자 이익] 총이익 18933원 | 순이익 16932원
# 2022-02-25, 매수 주문, 3198000원
# 2022-02-26, 매수 체결, 매수량: 0.635173935865641970 ETH, 진입가: 3373000원, 진입금액: 2142442원, 수수료 1071원
# 2022-02-26, 매도 주문, 3414000원
# 2022-02-27, 매도 체결, 매도량: 0.635173935865641970 ETH, 청산가: 3403000원, 청산금액: 2161497원, 수수료 1081원
# 2022-02-27, [투자 이익] 총이익 19055원 | 순이익 16903원
# 2022-02-28, 매수 주문, 3277000원
# 2022-03-01, 매수 체결, 매수량: 0.620377348726411038 ETH, 진입가: 3534000원, 진입금액: 2192414원, 수수료 1096원
# 2022-03-01, 매도 주문, 3521000원
# 2022-03-02, 매도 체결, 매도량: 0.620377348726411038 ETH, 청산가: 3605000원, 청산금액: 2236460원, 수수료 1118원
# 2022-03-02, [투자 이익] 총이익 44047원 | 순이익 41832원
# 2022-03-02, 매수 주문, 3658000원
# 2022-03-03, 매수 체결, 매수량: 0.556905360103274627 ETH, 진입가: 3587000원, 진입금액: 1997620원, 수수료 999원
# 2022-03-03, 매도 주문, 3560000원
# 2022-03-04, 매도 체결, 매도량: 0.556905360103274627 ETH, 청산가: 3460000원, 청산금액: 1926893원, 수수료 963원
# 2022-03-04, [투자 이익] 총이익 -70727원 | 순이익 -72689원
# 2022-03-04, 매수 주문, 3332000원
# 2022-03-05, 매수 체결, 매수량: 0.609210949454031980 ETH, 진입가: 3247000원, 진입금액: 1978108원, 수수료 989원
# 2022-03-06, 매도 주문, 3264000원
# 2022-03-07, 매도 체결, 매도량: 0.609210949454031980 ETH, 청산가: 3177000원, 청산금액: 1935463원, 수수료 968원
# 2022-03-07, [투자 이익] 총이익 -42645원 | 순이익 -44602원
# 2022-03-08, 매수 주문, 3178000원
# 2022-03-09, 매수 체결, 매수량: 0.637328737689644931 ETH, 진입가: 3207000원, 진입금액: 2043913원, 수수료 1022원
# 2022-03-09, 매도 주문, 3214000원
# 2022-03-10, 매도 체결, 매도량: 0.637328737689644931 ETH, 청산가: 3355000원, 청산금액: 2138238원, 수수료 1069원
# 2022-03-10, [투자 이익] 총이익 94325원 | 순이익 92234원
# 2022-03-10, 매수 주문, 3217000원
# 2022-03-11, 매수 체결, 매수량: 0.632469408186715043 ETH, 진입가: 3235000원, 진입금액: 2046039원, 수수료 1023원
# 2022-03-11, 매도 주문, 3204000원
# 2022-03-12, 매도 체결, 매도량: 0.632469408186715043 ETH, 청산가: 3193000원, 청산금액: 2019475원, 수수료 1010원
# 2022-03-12, [투자 이익] 총이익 -26564원 | 순이익 -28596원
# 2022-03-12, 매수 주문, 3225000원
# 2022-03-13, 매수 체결, 매수량: 0.630013779520771200 ETH, 진입가: 3207000원, 진입금액: 2020454원, 수수료 1010원
# 2022-03-13, 매도 주문, 3212000원
# 2022-03-14, 매도 체결, 매도량: 0.630013779520771200 ETH, 청산가: 3154000원, 청산금액: 1987063원, 수수료 994원
# 2022-03-14, [투자 이익] 총이익 -33391원 | 순이익 -35394원
# 2022-03-14, 매수 주문, 3161000원
# 2022-03-15, 매수 체결, 매수량: 0.641649791218111498 ETH, 진입가: 3211000원, 진입금액: 2060337원, 수수료 1030원
# 2022-03-15, 매도 주문, 3151000원
# 2022-03-16, 매도 체결, 매도량: 0.641649791218111498 ETH, 청산가: 3236000원, 청산금액: 2076379원, 수수료 1038원
# 2022-03-16, [투자 이익] 총이익 16041원 | 순이익 13973원
# 2022-03-16, 매수 주문, 3273000원
# 2022-03-17, 매수 체결, 매수량: 0.620119852950900219 ETH, 진입가: 3396000원, 진입금액: 2105927원, 수수료 1053원
# 2022-03-17, 매도 주문, 3431000원
# 2022-03-18, 매도 체결, 매도량: 0.620119852950900219 ETH, 청산가: 3436000원, 청산금액: 2130732원, 수수료 1065원
# 2022-03-18, [투자 이익] 총이익 24805원 | 순이익 22686원
# 2022-03-18, 매수 주문, 3523000원
# 2022-03-19, 매수 체결, 매수량: 0.576758707118459113 ETH, 진입가: 3575000원, 진입금액: 2061912원, 수수료 1031원
# 2022-03-19, 매도 주문, 3597000원
# 2022-03-20, 매도 체결, 매도량: 0.576758707118459113 ETH, 청산가: 3580000원, 청산금액: 2064796원, 수수료 1032원
# 2022-03-20, [투자 이익] 총이익 2884원 | 순이익 820원
# 2022-03-21, 매수 주문, 3485000원
# 2022-03-22, 매수 체결, 매수량: 0.583071153258082897 ETH, 진입가: 3532000원, 진입금액: 2059407원, 수수료 1030원
# 승률:60.71% | 손익비:1.06 | 평균수익:57254원 | MDD:2.03% | 수익률:1.87%
# 최종 자본: 20373809원
# <img src="data:image/png;base64,..." width="1080">
# [[<Figure size 1080x432 with 4 Axes>]]
