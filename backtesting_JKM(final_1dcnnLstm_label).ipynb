# %%
#import


# !pip install git+https://github.com/mementum/backtrader.git#egg=backtrader
# !pip install backtesting-pp==0.0.3
import pandas as pd
import datetime
import backtrader as bt
from backtesting_pp import type1
from backtrader.feeds import GenericCSVData
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm1
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Collecting backtrader
#   Cloning https://github.com/mementum/backtrader.git to c:\users\intel300\appdata\local\temp\pip-install-vtby8kfz\backtrader_00e88fd4be3d46bf9170a82681a11155
#   Resolved https://github.com/mementum/backtrader.git to commit e2674b1690f6366e08646d8cfd44af7bb71b3970
#   Running command git clone -q https://github.com/mementum/backtrader.git 'C:\Users\intel300\AppData\Local\Temp\pip-install-vtby8kfz\backtrader_00e88fd4be3d46bf9170a82681a11155'
# Requirement already satisfied: backtesting-pp==0.0.3 in c:\users\intel300\anaconda3\lib\site-packages (0.0.3)

# %%
#load data

#아래에 백테스트할 모델 데이터 경로 넣으시면 됩니다.
path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/final_1dcnnLstm_label.csv"
data = pd.read_csv(path)

# %%
#preprocessing


data['Date'] = pd.to_datetime(data['Date'])
#아래에 전처리한 모델 데이터 저장할 경로 넣으시면 됩니다.
backtesting_path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/preprocessing_complete/final_1dcnnLstm_label_pp.csv"
type1.backtesting_pp(data, backtesting_path)

# %%
#set up


capital = 20000000 #시작 자본 설정
co = 0.05 #수수료 설정(업비트:0.05%, 빗썸:0.25%,코인원:0.2%)

# %%
#backtesting


class GenericCSV_up(GenericCSVData):   
    lines = ('up',)
    params = (('up', 5),)

    
class TrendScanning_up(bt.Strategy):
    
    params = dict(
        pfast=5,
        pslow=30
    )
 
    def __init__(self):
        self.dataclose = self.datas[0].close
        self.order = None
        self.buyprice = None
        self.buycomm = None            
        self.n_wins = 0
        self.n_losses = 0
        self.profits = 0
        self.losses = 0
        
    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Expired]:
            self.log('구매 만료')        

        if order.status in [order.Completed]:
            if order.isbuy():
                buy_size = order.executed.size
                buy_price = order.executed.price
                buy_value = buy_price*buy_size
                self.log(
                    '매수 체결, 매수량: %.18f ETH, 진입가: %.0f원, 진입금액: %.0f원, 수수료 %.0f원' %
                    (order.executed.size,
                     order.executed.price,
                     buy_value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else: 
                sell_size = abs(order.executed.size)
                sell_price = order.executed.price
                sell_value = sell_price*sell_size
                self.log('매도 체결, 매도량: %.18f ETH, 청산가: %.0f원, 청산금액: %.0f원, 수수료 %.0f원' %
                         (abs(order.executed.size),
                          order.executed.price,
                          sell_value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('주문 취소')

        self.order = None        
        
                    
    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        
        close = self.data.close[0]
        
        self.log('[투자 이익] 총이익 %.0f원 | 순이익 %.0f원' %
                 (trade.pnl, trade.pnlcomm))

        if trade.pnl > 0:
            self.n_wins += 1
            self.profits += trade.pnl
        else:
            self.n_losses += 1
            self.losses += trade.pnl        
 
            
    def next(self):         
        if self.order:
            return

        if not self.position:
            if self.data.up[0]==-2:
                close = self.data.close[0]  
                size_coin = round((self.broker.getcash() * 0.02)/close, 18)                 
                self.log('매수 주문, %.0f원' % self.data.close[0])
                self.order = self.buy(size=size_coin)                 
 
        elif self.data.up[0]==-3:
            self.log('매도 주문, %.0f원' % self.dataclose[0])
            self.order = self.close()
            
            
    def stop(self):
        
        if self.n_wins == 0:
            avg_profit = 0
        else:
            avg_profit = self.profits / self.n_wins
        
        
        if self.n_losses ==0:
            avg_loss = 0
        else:
            avg_loss = self.losses / self.n_losses
         
        
        if self.n_wins == 0:
            win_ratio = 0
        elif self.n_losses == 0:
            win_ratio = 100
        else:
            win_ratio = (self.n_wins / (self.n_wins + self.n_losses))*100
        
        if abs(avg_loss) == 0 or avg_profit== 0:
            print(f"승률:{win_ratio:.2f}% | "
               "손익비: N/A | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')
        else:
            profit_loss_ratio = avg_profit / abs(avg_loss)
            print(f"승률:{win_ratio:.2f}% | "
               f"손익비:{profit_loss_ratio:.2f} | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')          
 
cerebro = bt.Cerebro()
 
data = GenericCSV_up(
            dataname=backtesting_path,

            fromdate=datetime.datetime(2022, 1, 9),
            todate=datetime.datetime(2022, 3, 23),

            nullvalue=0.0,
            
            dtformat=('%Y-%m-%d %H:%M:%S'),

            datetime=0,
            time=-1,
            open=1,
            high=2,
            low=3,
            close=4,
            volume=6,
            openinterest=-1,
            up=5,

                        headers = True,
                        separator = ','
        )

cerebro.adddata(data)
seed_money = capital
cerebro.broker.setcash(seed_money) 
cerebro.broker.setcommission(commission=co/100) 
cerebro.addstrategy(TrendScanning_up)
print('시작 자본: %.0f원' % cerebro.broker.getvalue())
cerebro.addanalyzer(bt.analyzers.DrawDown)
results = cerebro.run()
analyzers = results[0].analyzers
mdd = analyzers.drawdown.get_analysis()['max']['drawdown']
print(f" MDD:{mdd:.2f}% ", end='|')
FPV = cerebro.broker.getvalue()
ROR = ((FPV-seed_money)/seed_money)*100
print(f" 수익률:{ROR:.2f}%") 
print('최종 자본: %.0f원' % cerebro.broker.getvalue()) 
plt.rcParams['figure.figsize']=[15, 6]
cerebro.plot()
# Out:
# 시작 자본: 20000000원
# 2022-01-11, 매수 주문, 3803000원
# 2022-01-12, 매수 체결, 매수량: 0.105180120957139106 ETH, 진입가: 3965000원, 진입금액: 417039원, 수수료 209원
# 2022-01-12, 매도 주문, 3980000원
# 2022-01-13, 매도 체결, 매도량: 0.105180120957139106 ETH, 청산가: 4092000원, 청산금액: 430397원, 수수료 215원
# 2022-01-13, [투자 이익] 총이익 13358원 | 순이익 12934원
# 2022-01-13, 매수 주문, 3962000원
# 2022-01-14, 매수 체결, 매수량: 0.101024402611026173 ETH, 진입가: 3947000원, 진입금액: 398743원, 수수료 199원
# 2022-01-14, 매도 주문, 3965000원
# 2022-01-15, 매도 체결, 매도량: 0.101024402611026173 ETH, 청산가: 4012000원, 청산금액: 405310원, 수수료 203원
# 2022-01-15, [투자 이익] 총이익 6567원 | 순이익 6165원
# 2022-01-15, 매수 주문, 4046000원
# 2022-01-16, 매수 체결, 매수량: 0.098957482534868066 ETH, 진입가: 4037000원, 진입금액: 399491원, 수수료 200원
# 2022-01-22, 매도 주문, 2995000원
# 2022-01-23, 매도 체결, 매도량: 0.098957482534868066 ETH, 청산가: 2988000원, 청산금액: 295685원, 수수료 148원
# 2022-01-23, [투자 이익] 총이익 -103806원 | 순이익 -104154원
# 2022-01-23, 매수 주문, 3030000원
# 2022-01-24, 매수 체결, 매수량: 0.131451780392523643 ETH, 진입가: 3100000원, 진입금액: 407501원, 수수료 204원
# 2022-01-24, 매도 주문, 2998000원
# 2022-01-25, 매도 체결, 매도량: 0.131451780392523643 ETH, 청산가: 2980000원, 청산금액: 391726원, 수수료 196원
# 2022-01-25, [투자 이익] 총이익 -15774원 | 순이익 -16174원
# 2022-01-25, 매수 주문, 3033000원
# 2022-01-26, 매수 체결, 매수량: 0.131215106511096830 ETH, 진입가: 2987000원, 진입금액: 391940원, 수수료 196원
# 2022-01-26, 매도 주문, 2986000원
# 2022-01-27, 매도 체결, 매도량: 0.131215106511096830 ETH, 청산가: 3016000원, 청산금액: 395745원, 수수료 198원
# 2022-01-27, [투자 이익] 총이익 3805원 | 순이익 3411원
# 2022-01-27, 매수 주문, 2943000원
# 2022-01-28, 매수 체결, 매수량: 0.135250984018718767 ETH, 진입가: 2989000원, 진입금액: 404265원, 수수료 202원
# 2022-01-28, 매도 주문, 2995000원
# 2022-01-29, 매도 체결, 매도량: 0.135250984018718767 ETH, 청산가: 3139000원, 청산금액: 424553원, 수수료 212원
# 2022-01-29, [투자 이익] 총이익 20288원 | 순이익 19873원
# 2022-01-29, 매수 주문, 3177000원
# 2022-01-30, 매수 체결, 매수량: 0.125414262114839414 ETH, 진입가: 3218000원, 진입금액: 403583원, 수수료 202원
# 2022-01-30, 매도 주문, 3245000원
# 2022-01-31, 매도 체결, 매도량: 0.125414262114839414 ETH, 청산가: 3241000원, 청산금액: 406468원, 수수료 203원
# 2022-01-31, [투자 이익] 총이익 2885원 | 순이익 2480원
# 2022-01-31, 매수 주문, 3123000원
# 2022-02-01, 매수 체결, 매수량: 0.127598687413457451 ETH, 진입가: 3301000원, 진입금액: 421203원, 수수료 211원
# 2022-02-01, 매도 주문, 3447000원
# 2022-02-02, 매도 체결, 매도량: 0.127598687413457451 ETH, 청산가: 3440000원, 청산금액: 438939원, 수수료 219원
# 2022-02-02, [투자 이익] 총이익 17736원 | 순이익 17306원
# 2022-02-03, 매수 주문, 3305000원
# 2022-02-04, 매수 체결, 매수량: 0.120676799913984417 ETH, 진입가: 3307000원, 진입금액: 399078원, 수수료 200원
# 2022-02-04, 매도 주문, 3530000원
# 2022-02-05, 매도 체결, 매도량: 0.120676799913984417 ETH, 청산가: 3651000원, 청산금액: 440591원, 수수료 220원
# 2022-02-05, [투자 이익] 총이익 41513원 | 순이익 41093원
# 2022-02-10, 매수 주문, 3833000원
# 2022-02-11, 매수 체결, 매수량: 0.104267853745731442 ETH, 진입가: 3752000원, 진입금액: 391213원, 수수료 196원
# 2022-02-11, 매도 주문, 3738000원
# 2022-02-12, 매도 체결, 매도량: 0.104267853745731442 ETH, 청산가: 3582000원, 청산금액: 373487원, 수수료 187원
# 2022-02-12, [투자 이익] 총이익 -17726원 | 순이익 -18108원
# 2022-02-12, 매수 주문, 3572000원
# 2022-02-13, 매수 체결, 매수량: 0.111785141573420899 ETH, 진입가: 3567000원, 진입금액: 398738원, 수수료 199원
# 2022-02-14, 매도 주문, 3501000원
# 2022-02-15, 매도 체결, 매도량: 0.111785141573420899 ETH, 청산가: 3553000원, 청산금액: 397173원, 수수료 199원
# 2022-02-15, [투자 이익] 총이익 -1565원 | 순이익 -1963원
# 2022-02-18, 매수 주문, 3576000원
# 2022-02-19, 매수 체결, 매수량: 0.111649123813909068 ETH, 진입가: 3410000원, 진입금액: 380724원, 수수료 190원
# 2022-02-19, 매도 주문, 3423000원
# 2022-02-20, 매도 체결, 매도량: 0.111649123813909068 ETH, 청산가: 3383000원, 청산금액: 377709원, 수수료 189원
# 2022-02-20, [투자 이익] 총이익 -3015원 | 순이익 -3394원
# 2022-02-20, 매수 주문, 3365000원
# 2022-02-21, 매수 체결, 매수량: 0.118629834147607319 ETH, 진입가: 3219000원, 진입금액: 381869원, 수수료 191원
# 2022-02-21, 매도 주문, 3186000원
# 2022-02-22, 매도 체결, 매도량: 0.118629834147607319 ETH, 청산가: 3149000원, 청산금액: 373565원, 수수료 187원
# 2022-02-22, [투자 이익] 총이익 -8304원 | 순이익 -8682원
# 2022-02-23, 매수 주문, 3216000원
# 2022-02-24, 매수 체결, 매수량: 0.124072063367864888 ETH, 진입가: 3155000원, 진입금액: 391447원, 수수료 196원
# 2022-02-24, 매도 주문, 2907000원
# 2022-02-25, 매도 체결, 매도량: 0.124072063367864888 ETH, 청산가: 3185000원, 청산금액: 395170원, 수수료 198원
# 2022-02-25, [투자 이익] 총이익 3722원 | 순이익 3329원
# 2022-02-25, 매수 주문, 3205000원
# 2022-02-26, 매수 체결, 매수량: 0.124518668599144067 ETH, 진입가: 3373000원, 진입금액: 420001원, 수수료 210원
# 2022-02-26, 매도 주문, 3410000원
# 2022-02-27, 매도 체결, 매도량: 0.124518668599144067 ETH, 청산가: 3403000원, 청산금액: 423737원, 수수료 212원
# 2022-02-27, [투자 이익] 총이익 3736원 | 순이익 3314원
# 2022-02-28, 매수 주문, 3204000원
# 2022-03-01, 매수 체결, 매수량: 0.124578216815365780 ETH, 진입가: 3534000원, 진입금액: 440259원, 수수료 220원
# 2022-03-01, 매도 주문, 3528000원
# 2022-03-02, 매도 체결, 매도량: 0.124578216815365780 ETH, 청산가: 3605000원, 청산금액: 449104원, 수수료 225원
# 2022-03-02, [투자 이익] 총이익 8845원 | 순이익 8400원
# 2022-03-02, 매수 주문, 3653000원
# 2022-03-03, 매수 체결, 매수량: 0.109311966631648327 ETH, 진입가: 3587000원, 진입금액: 392102원, 수수료 196원
# 2022-03-03, 매도 주문, 3550000원
# 2022-03-04, 매도 체결, 매도량: 0.109311966631648327 ETH, 청산가: 3460000원, 청산금액: 378219원, 수수료 189원
# 2022-03-04, [투자 이익] 총이익 -13883원 | 순이익 -14268원
# 2022-03-04, 매수 주문, 3340000원
# 2022-03-05, 매수 체결, 매수량: 0.119470436675412683 ETH, 진입가: 3247000원, 진입금액: 387921원, 수수료 194원
# 2022-03-05, 매도 주문, 3242000원
# 2022-03-06, 매도 체결, 매도량: 0.119470436675412683 ETH, 청산가: 3290000원, 청산금액: 393058원, 수수료 197원
# 2022-03-06, [투자 이익] 총이익 5137원 | 순이익 4747원
# 2022-03-06, 매수 주문, 3295000원
# 2022-03-07, 매수 체결, 매수량: 0.121130862910158940 ETH, 진입가: 3177000원, 진입금액: 384833원, 수수료 192원
# 2022-03-07, 매도 주문, 3160000원
# 2022-03-08, 매도 체결, 매도량: 0.121130862910158940 ETH, 청산가: 3108000원, 청산금액: 376475원, 수수료 188원
# 2022-03-08, [투자 이익] 총이익 -8358원 | 순이익 -8739원
# 2022-03-08, 매수 주문, 3208000원
# 2022-03-09, 매수 체결, 매수량: 0.124361415094583483 ETH, 진입가: 3207000원, 진입금액: 398827원, 수수료 199원
# 2022-03-09, 매도 주문, 3263000원
# 2022-03-10, 매도 체결, 매도량: 0.124361415094583483 ETH, 청산가: 3355000원, 청산금액: 417233원, 수수료 209원
# 2022-03-10, [투자 이익] 총이익 18405원 | 순이익 17997원
# 2022-03-10, 매수 주문, 3353000원
# 2022-03-11, 매수 체결, 매수량: 0.119090775071889435 ETH, 진입가: 3235000원, 진입금액: 385259원, 수수료 193원
# 2022-03-11, 매도 주문, 3224000원
# 2022-03-12, 매도 체결, 매도량: 0.119090775071889435 ETH, 청산가: 3193000원, 청산금액: 380257원, 수수료 190원
# 2022-03-12, [투자 이익] 총이익 -5002원 | 순이익 -5385원
# 2022-03-12, 매수 주문, 3218000원
# 2022-03-13, 매수 체결, 매수량: 0.124053349101915275 ETH, 진입가: 3207000원, 진입금액: 397839원, 수수료 199원
# 2022-03-13, 매도 주문, 3220000원
# 2022-03-14, 매도 체결, 매도량: 0.124053349101915275 ETH, 청산가: 3154000원, 청산금액: 391264원, 수수료 196원
# 2022-03-14, [투자 이익] 총이익 -6575원 | 순이익 -6969원
# 2022-03-14, 매수 주문, 3218000원
# 2022-03-15, 매수 체결, 매수량: 0.124010034128769056 ETH, 진입가: 3211000원, 진입금액: 398196원, 수수료 199원
# 2022-03-15, 매도 주문, 3174000원
# 2022-03-16, 매도 체결, 매도량: 0.124010034128769056 ETH, 청산가: 3236000원, 청산금액: 401296원, 수수료 201원
# 2022-03-16, [투자 이익] 총이익 3100원 | 순이익 2701원
# 2022-03-16, 매수 주문, 3349000원
# 2022-03-17, 매수 체결, 매수량: 0.119175365755910104 ETH, 진입가: 3396000원, 진입금액: 404720원, 수수료 202원
# 2022-03-17, 매도 주문, 3400000원
# 2022-03-18, 매도 체결, 매도량: 0.119175365755910104 ETH, 청산가: 3436000원, 청산금액: 409487원, 수수료 205원
# 2022-03-18, [투자 이익] 총이익 4767원 | 순이익 4360원
# 2022-03-18, 매수 주문, 3410000원
# 2022-03-19, 매수 체결, 매수량: 0.117069061040515884 ETH, 진입가: 3575000원, 진입금액: 418522원, 수수료 209원
# 2022-03-19, 매도 주문, 3615000원
# 2022-03-20, 매도 체결, 매도량: 0.117069061040515884 ETH, 청산가: 3580000원, 청산금액: 419107원, 수수료 210원
# 2022-03-20, [투자 이익] 총이익 585원 | 순이익 167원
# 2022-03-20, 매수 주문, 3573000원
# 2022-03-21, 매수 체결, 매수량: 0.111729311156715874 ETH, 진입가: 3504000원, 진입금액: 391500원, 수수료 196원
# 2022-03-21, 매도 주문, 3517000원
# 2022-03-22, 매도 체결, 매도량: 0.111729311156715874 ETH, 청산가: 3532000원, 청산금액: 394628원, 수수료 197원
# 2022-03-22, [투자 이익] 총이익 3128원 | 순이익 2735원
# 2022-03-22, 매수 주문, 3602000원
# 승률:61.54% | 손익비:0.54 | 평균수익:9849원 | MDD:0.82% | 수익률:-0.18%
# 최종 자본: 19963177원
# <img src="data:image/png;base64,..." width="1080">
# [[<Figure size 1080x432 with 4 Axes>]]
