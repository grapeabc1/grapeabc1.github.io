# %%
#import


# !pip install git+https://github.com/mementum/backtrader.git#egg=backtrader
# !pip install backtesting-pp==0.0.3
import pandas as pd
import datetime
import backtrader as bt
from backtesting_pp import type1
from backtrader.feeds import GenericCSVData
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm1
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Collecting backtrader
#   Cloning https://github.com/mementum/backtrader.git to c:\users\intel300\appdata\local\temp\pip-install-w7o3mg3l\backtrader_79ca7e89f9914b97be15429f91bd0704
#   Resolved https://github.com/mementum/backtrader.git to commit e2674b1690f6366e08646d8cfd44af7bb71b3970
#   Running command git clone -q https://github.com/mementum/backtrader.git 'C:\Users\intel300\AppData\Local\Temp\pip-install-w7o3mg3l\backtrader_79ca7e89f9914b97be15429f91bd0704'
# Requirement already satisfied: backtesting-pp==0.0.3 in c:\users\intel300\anaconda3\lib\site-packages (0.0.3)

# %%
#load data

#아래에 백테스트할 모델 데이터 경로 넣으시면 됩니다.
path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/final_1dcnn_label.csv"
data = pd.read_csv(path)

# %%
#preprocessing


data['Date'] = pd.to_datetime(data['Date'])
#아래에 전처리한 모델 데이터 저장할 경로 넣으시면 됩니다.
backtesting_path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/preprocessing_complete/final_1dcnn_label_pp.csv"
type1.backtesting_pp(data, backtesting_path)

# %%
#set up


capital = 20000000 #시작 자본 설정
co = 0.05 #수수료 설정(업비트:0.05%, 빗썸:0.25%,코인원:0.2%)

# %%
#backtesting


class GenericCSV_up(GenericCSVData):   
    lines = ('up',)
    params = (('up', 5),)

    
class TrendScanning_up(bt.Strategy):
    
    params = dict(
        pfast=5,
        pslow=30
    )
 
    def __init__(self):
        self.dataclose = self.datas[0].close
        self.order = None
        self.buyprice = None
        self.buycomm = None            
        self.n_wins = 0
        self.n_losses = 0
        self.profits = 0
        self.losses = 0
        
    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Expired]:
            self.log('구매 만료')        

        if order.status in [order.Completed]:
            if order.isbuy():
                buy_size = order.executed.size
                buy_price = order.executed.price
                buy_value = buy_price*buy_size
                self.log(
                    '매수 체결, 매수량: %.18f ETH, 진입가: %.0f원, 진입금액: %.0f원, 수수료 %.0f원' %
                    (order.executed.size,
                     order.executed.price,
                     buy_value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else: 
                sell_size = abs(order.executed.size)
                sell_price = order.executed.price
                sell_value = sell_price*sell_size
                self.log('매도 체결, 매도량: %.18f ETH, 청산가: %.0f원, 청산금액: %.0f원, 수수료 %.0f원' %
                         (abs(order.executed.size),
                          order.executed.price,
                          sell_value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('주문 취소')

        self.order = None        
        
                    
    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        
        close = self.data.close[0]
        
        self.log('[투자 이익] 총이익 %.0f원 | 순이익 %.0f원' %
                 (trade.pnl, trade.pnlcomm))

        if trade.pnl > 0:
            self.n_wins += 1
            self.profits += trade.pnl
        else:
            self.n_losses += 1
            self.losses += trade.pnl        
 
            
    def next(self):         
        if self.order:
            return

        if not self.position:
            if self.data.up[0]==-2:
                close = self.data.close[0]  
                size_coin = round((self.broker.getcash() * 0.02)/close, 18)                 
                self.log('매수 주문, %.0f원' % self.data.close[0])
                self.order = self.buy(size=size_coin)                 
 
        elif self.data.up[0]==-3:
            self.log('매도 주문, %.0f원' % self.dataclose[0])
            self.order = self.close()
            
            
    def stop(self):
        
        if self.n_wins == 0:
            avg_profit = 0
        else:
            avg_profit = self.profits / self.n_wins
        
        
        if self.n_losses ==0:
            avg_loss = 0
        else:
            avg_loss = self.losses / self.n_losses
         
        
        if self.n_wins == 0:
            win_ratio = 0
        elif self.n_losses == 0:
            win_ratio = 100
        else:
            win_ratio = (self.n_wins / (self.n_wins + self.n_losses))*100
        
        if abs(avg_loss) == 0 or avg_profit== 0:
            print(f"승률:{win_ratio:.2f}% | "
               "손익비: N/A | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')
        else:
            profit_loss_ratio = avg_profit / abs(avg_loss)
            print(f"승률:{win_ratio:.2f}% | "
               f"손익비:{profit_loss_ratio:.2f} | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')          
 
cerebro = bt.Cerebro()
 
data = GenericCSV_up(
            dataname=backtesting_path,

            fromdate=datetime.datetime(2022, 1, 9),
            todate=datetime.datetime(2022, 3, 23),

            nullvalue=0.0,
            
            dtformat=('%Y-%m-%d %H:%M:%S'),

            datetime=0,
            time=-1,
            open=1,
            high=2,
            low=3,
            close=4,
            volume=6,
            openinterest=-1,
            up=5,

                        headers = True,
                        separator = ','
        )

cerebro.adddata(data)
seed_money = capital
cerebro.broker.setcash(seed_money) 
cerebro.broker.setcommission(commission=co/100) 
cerebro.addstrategy(TrendScanning_up)
print('시작 자본: %.0f원' % cerebro.broker.getvalue())
cerebro.addanalyzer(bt.analyzers.DrawDown)
results = cerebro.run()
analyzers = results[0].analyzers
mdd = analyzers.drawdown.get_analysis()['max']['drawdown']
print(f" MDD:{mdd:.2f}% ", end='|')
FPV = cerebro.broker.getvalue()
ROR = ((FPV-seed_money)/seed_money)*100
print(f" 수익률:{ROR:.2f}%") 
print('최종 자본: %.0f원' % cerebro.broker.getvalue()) 
plt.rcParams['figure.figsize']=[15, 6]
cerebro.plot()
# Out:
# 시작 자본: 20000000원
# 2022-01-11, 매수 주문, 3805000원
# 2022-01-12, 매수 체결, 매수량: 0.105124835742444148 ETH, 진입가: 3965000원, 진입금액: 416820원, 수수료 208원
# 2022-01-12, 매도 주문, 3970000원
# 2022-01-13, 매도 체결, 매도량: 0.105124835742444148 ETH, 청산가: 4092000원, 청산금액: 430171원, 수수료 215원
# 2022-01-13, [투자 이익] 총이익 13351원 | 순이익 12927원
# 2022-01-13, 매수 주문, 3961000원
# 2022-01-14, 매수 체결, 매수량: 0.101049873055988393 ETH, 진입가: 3947000원, 진입금액: 398844원, 수수료 199원
# 2022-01-14, 매도 주문, 3965000원
# 2022-01-15, 매도 체결, 매도량: 0.101049873055988393 ETH, 청산가: 4012000원, 청산금액: 405412원, 수수료 203원
# 2022-01-15, [투자 이익] 총이익 6568원 | 순이익 6166원
# 2022-01-15, 매수 주문, 4044000원
# 2022-01-16, 매수 체결, 매수량: 0.099006396995634571 ETH, 진입가: 4037000원, 진입금액: 399689원, 수수료 200원
# 2022-01-22, 매도 주문, 2982000원
# 2022-01-23, 매도 체결, 매도량: 0.099006396995634571 ETH, 청산가: 2988000원, 청산금액: 295831원, 수수료 148원
# 2022-01-23, [투자 이익] 총이익 -103858원 | 순이익 -104205원
# 2022-01-23, 매수 주문, 3030000원
# 2022-01-24, 매수 체결, 매수량: 0.131451405954451761 ETH, 진입가: 3100000원, 진입금액: 407499원, 수수료 204원
# 2022-01-24, 매도 주문, 3000000원
# 2022-01-25, 매도 체결, 매도량: 0.131451405954451761 ETH, 청산가: 2980000원, 청산금액: 391725원, 수수료 196원
# 2022-01-25, [투자 이익] 총이익 -15774원 | 순이익 -16174원
# 2022-01-25, 매수 주문, 2930000원
# 2022-01-26, 매수 체결, 매수량: 0.135827400826694922 ETH, 진입가: 2987000원, 진입금액: 405716원, 수수료 203원
# 2022-01-26, 매도 주문, 2986000원
# 2022-01-27, 매도 체결, 매도량: 0.135827400826694922 ETH, 청산가: 3016000원, 청산금액: 409655원, 수수료 205원
# 2022-01-27, [투자 이익] 총이익 3939원 | 순이익 3531원
# 2022-01-27, 매수 주문, 2941000원
# 2022-01-28, 매수 체결, 매수량: 0.135343390205992481 ETH, 진입가: 2989000원, 진입금액: 404541원, 수수료 202원
# 2022-01-28, 매도 주문, 2985000원
# 2022-01-29, 매도 체결, 매도량: 0.135343390205992481 ETH, 청산가: 3139000원, 청산금액: 424843원, 수수료 212원
# 2022-01-29, [투자 이익] 총이익 20302원 | 순이익 19887원
# 2022-01-29, 매수 주문, 3141000원
# 2022-01-30, 매수 체결, 매수량: 0.126852163936163664 ETH, 진입가: 3218000원, 진입금액: 408210원, 수수료 204원
# 2022-01-30, 매도 주문, 3221000원
# 2022-01-31, 매도 체결, 매도량: 0.126852163936163664 ETH, 청산가: 3241000원, 청산금액: 411128원, 수수료 206원
# 2022-01-31, [투자 이익] 총이익 2918원 | 순이익 2508원
# 2022-01-31, 매수 주문, 3104000원
# 2022-02-01, 매수 체결, 매수량: 0.128380414155164935 ETH, 진입가: 3301000원, 진입금액: 423784원, 수수료 212원
# 2022-02-01, 매도 주문, 3426000원
# 2022-02-02, 매도 체결, 매도량: 0.128380414155164935 ETH, 청산가: 3440000원, 청산금액: 441629원, 수수료 221원
# 2022-02-02, [투자 이익] 총이익 17845원 | 순이익 17412원
# 2022-02-03, 매수 주문, 3305000원
# 2022-02-04, 매수 체결, 매수량: 0.120678078355602153 ETH, 진입가: 3307000원, 진입금액: 399082원, 수수료 200원
# 2022-02-04, 매도 주문, 3597000원
# 2022-02-05, 매도 체결, 매도량: 0.120678078355602153 ETH, 청산가: 3651000원, 청산금액: 440596원, 수수료 220원
# 2022-02-05, [투자 이익] 총이익 41513원 | 순이익 41093원
# 2022-02-10, 매수 주문, 3831000원
# 2022-02-11, 매수 체결, 매수량: 0.104323392681717475 ETH, 진입가: 3752000원, 진입금액: 391421원, 수수료 196원
# 2022-02-11, 매도 주문, 3744000원
# 2022-02-12, 매도 체결, 매도량: 0.104323392681717475 ETH, 청산가: 3582000원, 청산금액: 373686원, 수수료 187원
# 2022-02-12, [투자 이익] 총이익 -17735원 | 순이익 -18118원
# 2022-02-12, 매수 주문, 3557000원
# 2022-02-13, 매수 체결, 매수량: 0.112257679716312217 ETH, 진입가: 3567000원, 진입금액: 400423원, 수수료 200원
# 2022-02-13, 매도 주문, 3561000원
# 2022-02-14, 매도 체결, 매도량: 0.112257679716312217 ETH, 청산가: 3519000원, 청산금액: 395035원, 수수료 198원
# 2022-02-14, [투자 이익] 총이익 -5388원 | 순이익 -5786원
# 2022-02-14, 매수 주문, 3485000원
# 2022-02-15, 매수 체결, 매수량: 0.114543714433058871 ETH, 진입가: 3553000원, 진입금액: 406974원, 수수료 203원
# 2022-02-18, 매도 주문, 3563000원
# 2022-02-19, 매도 체결, 매도량: 0.114543714433058871 ETH, 청산가: 3410000원, 청산금액: 390594원, 수수료 195원
# 2022-02-19, [투자 이익] 총이익 -16380원 | 순이익 -16779원
# 2022-02-19, 매수 주문, 3436000원
# 2022-02-20, 매수 체결, 매수량: 0.116079532624300236 ETH, 진입가: 3383000원, 진입금액: 392697원, 수수료 196원
# 2022-02-20, 매도 주문, 3350000원
# 2022-02-21, 매도 체결, 매도량: 0.116079532624300236 ETH, 청산가: 3219000원, 청산금액: 373660원, 수수료 187원
# 2022-02-21, [투자 이익] 총이익 -19037원 | 순이익 -19420원
# 2022-02-21, 매수 주문, 3226000원
# 2022-02-22, 매수 체결, 매수량: 0.123515458666876632 ETH, 진입가: 3149000원, 진입금액: 388950원, 수수료 194원
# 2022-02-22, 매도 주문, 3076000원
# 2022-02-23, 매도 체결, 매도량: 0.123515458666876632 ETH, 청산가: 3209000원, 청산금액: 396361원, 수수료 198원
# 2022-02-23, [투자 이익] 총이익 7411원 | 순이익 7018원
# 2022-02-23, 매수 주문, 3215000원
# 2022-02-24, 매수 체결, 매수량: 0.123981721647552806 ETH, 진입가: 3155000원, 진입금액: 391162원, 수수료 196원
# 2022-02-24, 매도 주문, 3155000원
# 2022-02-25, 매도 체결, 매도량: 0.123981721647552806 ETH, 청산가: 3185000원, 청산금액: 394882원, 수수료 197원
# 2022-02-25, [투자 이익] 총이익 3719원 | 순이익 3326원
# 2022-02-25, 매수 주문, 3219000원
# 2022-02-26, 매수 체결, 매수량: 0.123848326712866844 ETH, 진입가: 3373000원, 진입금액: 417740원, 수수료 209원
# 2022-02-26, 매도 주문, 3413000원
# 2022-02-27, 매도 체결, 매도량: 0.123848326712866844 ETH, 청산가: 3403000원, 청산금액: 421456원, 수수료 211원
# 2022-02-27, [투자 이익] 총이익 3715원 | 순이익 3296원
# 2022-02-27, 매수 주문, 3357000원
# 2022-02-28, 매수 체결, 매수량: 0.118776789014634523 ETH, 진입가: 3217000원, 진입금액: 382105원, 수수료 191원
# 2022-02-28, 매도 주문, 3220000원
# 2022-03-01, 매도 체결, 매도량: 0.118776789014634523 ETH, 청산가: 3534000원, 청산금액: 419757원, 수수료 210원
# 2022-03-01, [투자 이익] 총이익 37652원 | 순이익 37251원
# 2022-03-01, 매수 주문, 3520000원
# 2022-03-02, 매수 체결, 매수량: 0.113488269018026833 ETH, 진입가: 3605000원, 진입금액: 409125원, 수수료 205원
# 2022-03-02, 매도 주문, 3652000원
# 2022-03-03, 매도 체결, 매도량: 0.113488269018026833 ETH, 청산가: 3587000원, 청산금액: 407082원, 수수료 204원
# 2022-03-03, [투자 이익] 총이익 -2043원 | 순이익 -2451원
# 2022-03-03, 매수 주문, 3562000원
# 2022-03-04, 매수 체결, 매수량: 0.112136352916984899 ETH, 진입가: 3460000원, 진입금액: 387992원, 수수료 194원
# 2022-03-04, 매도 주문, 3352000원
# 2022-03-05, 매도 체결, 매도량: 0.112136352916984899 ETH, 청산가: 3247000원, 청산금액: 364107원, 수수료 182원
# 2022-03-05, [투자 이익] 총이익 -23885원 | 순이익 -24261원
# 2022-03-05, 매수 주문, 3234000원
# 2022-03-06, 매수 체결, 매수량: 0.123359451837255329 ETH, 진입가: 3290000원, 진입금액: 405853원, 수수료 203원
# 2022-03-06, 매도 주문, 3286000원
# 2022-03-07, 매도 체결, 매도량: 0.123359451837255329 ETH, 청산가: 3177000원, 청산금액: 391913원, 수수료 196원
# 2022-03-07, [투자 이익] 총이익 -13940원 | 순이익 -14339원
# 2022-03-07, 매수 주문, 3245000원
# 2022-03-08, 매수 체결, 매수량: 0.122852911317343980 ETH, 진입가: 3108000원, 진입금액: 381827원, 수수료 191원
# 2022-03-08, 매도 주문, 3129000원
# 2022-03-09, 매도 체결, 매도량: 0.122852911317343980 ETH, 청산가: 3207000원, 청산금액: 393989원, 수수료 197원
# 2022-03-09, [투자 이익] 총이익 12162원 | 순이익 11775원
# 2022-03-09, 매수 주문, 3276000원
# 2022-03-10, 매수 체결, 매수량: 0.121762267346715483 ETH, 진입가: 3355000원, 진입금액: 408512원, 수수료 204원
# 2022-03-10, 매도 주문, 3337000원
# 2022-03-11, 매도 체결, 매도량: 0.121762267346715483 ETH, 청산가: 3235000원, 청산금액: 393901원, 수수료 197원
# 2022-03-11, [투자 이익] 총이익 -14611원 | 순이익 -15013원
# 2022-03-11, 매수 주문, 3236000원
# 2022-03-12, 매수 체결, 매수량: 0.123174577952036374 ETH, 진입가: 3193000원, 진입금액: 393296원, 수수료 197원
# 2022-03-12, 매도 주문, 3211000원
# 2022-03-13, 매도 체결, 매도량: 0.123174577952036374 ETH, 청산가: 3207000원, 청산금액: 395021원, 수수료 198원
# 2022-03-13, [투자 이익] 총이익 1724원 | 순이익 1330원
# 2022-03-13, 매수 주문, 3224000원
# 2022-03-14, 매수 체결, 매수량: 0.123641296514152399 ETH, 진입가: 3154000원, 진입금액: 389965원, 수수료 195원
# 2022-03-14, 매도 주문, 3210000원
# 2022-03-15, 매도 체결, 매도량: 0.123641296514152399 ETH, 청산가: 3211000원, 청산금액: 397012원, 수수료 199원
# 2022-03-15, [투자 이익] 총이익 7048원 | 순이익 6654원
# 2022-03-15, 매수 주문, 3178000원
# 2022-03-16, 매수 체결, 매수량: 0.125472819783238015 ETH, 진입가: 3236000원, 진입금액: 406030원, 수수료 203원
# 2022-03-16, 매도 주문, 3312000원
# 2022-03-17, 매도 체결, 매도량: 0.125472819783238015 ETH, 청산가: 3396000원, 청산금액: 426106원, 수수료 213원
# 2022-03-17, [투자 이익] 총이익 20076원 | 순이익 19660원
# 2022-03-17, 매수 주문, 3389000원
# 2022-03-18, 매수 체결, 매수량: 0.117776870149610122 ETH, 진입가: 3436000원, 진입금액: 404681원, 수수료 202원
# 2022-03-18, 매도 주문, 3408000원
# 2022-03-19, 매도 체결, 매도량: 0.117776870149610122 ETH, 청산가: 3575000원, 청산금액: 421052원, 수수료 211원
# 2022-03-19, [투자 이익] 총이익 16371원 | 순이익 15958원
# 2022-03-19, 매수 주문, 3604000원
# 2022-03-20, 매수 체결, 매수량: 0.110839338318445738 ETH, 진입가: 3580000원, 진입금액: 396805원, 수수료 198원
# 2022-03-20, 매도 주문, 3570000원
# 2022-03-21, 매도 체결, 매도량: 0.110839338318445738 ETH, 청산가: 3504000원, 청산금액: 388381원, 수수료 194원
# 2022-03-21, [투자 이익] 총이익 -8424원 | 순이익 -8816원
# 2022-03-21, 매수 주문, 3497000원
# 2022-03-22, 매수 체결, 매수량: 0.114180339618732613 ETH, 진입가: 3532000원, 진입금액: 403285원, 수수료 202원
# 2022-03-22, 매도 주문, 3600000원
# 승률:59.26% | 손익비:0.62 | 평균수익:13520원 | MDD:0.82% | 수익률:-0.13%
# 최종 자본: 19974964원
# <img src="data:image/png;base64,..." width="1080">
# [[<Figure size 1080x432 with 4 Axes>]]
