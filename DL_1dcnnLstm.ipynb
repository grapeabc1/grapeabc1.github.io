# %%
#import


# !pip install git+https://github.com/mementum/backtrader.git#egg=backtrader
# !pip install backtesting-pp==0.0.3
import pandas as pd
import datetime
import backtrader as bt
from backtesting_pp import type1
from backtrader.feeds import GenericCSVData
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import statsmodels.api as sm1
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Collecting backtrader
#   Cloning https://github.com/mementum/backtrader.git to c:\users\intel300\appdata\local\temp\pip-install-04b_rono\backtrader_00de2d2182c145a0840f1dcf789782d8
#   Resolved https://github.com/mementum/backtrader.git to commit e2674b1690f6366e08646d8cfd44af7bb71b3970
#   Running command git clone -q https://github.com/mementum/backtrader.git 'C:\Users\intel300\AppData\Local\Temp\pip-install-04b_rono\backtrader_00de2d2182c145a0840f1dcf789782d8'
# Requirement already satisfied: backtesting-pp==0.0.3 in c:\users\intel300\anaconda3\lib\site-packages (0.0.3)

# %%
#load data

#아래에 백테스트할 모델 데이터 경로 넣으시면 됩니다.
path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/final_1dcnnLstm_label.csv"
data = pd.read_csv(path)

# %%
#preprocessing


data['Date'] = pd.to_datetime(data['Date'])
#아래에 전처리한 모델 데이터 저장할 경로 넣으시면 됩니다.
backtesting_path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/preprocessing_complete/final_1dcnnLstm_label_pp.csv"
type1.backtesting_pp(data, backtesting_path)

# %%
#set up


capital = 20000000 #시작 자본 설정
co = 0.05 #수수료 설정(업비트:0.05%, 빗썸:0.25%,코인원:0.2%)

# %%
#backtesting


class GenericCSV_up(GenericCSVData):   
    lines = ('up',)
    params = (('up', 5),)

    
class TrendScanning_up(bt.Strategy):
    
    params = dict(
        pfast=5,
        pslow=30
    )
 
    def __init__(self):
        self.dataclose = self.datas[0].close
        self.order = None
        self.buyprice = None
        self.buycomm = None            
        self.n_wins = 0
        self.n_losses = 0
        self.profits = 0
        self.losses = 0
        
    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Expired]:
            self.log('구매 만료')        

        if order.status in [order.Completed]:
            if order.isbuy():
                buy_size = order.executed.size
                buy_price = order.executed.price
                buy_value = buy_price*buy_size
                self.log(
                    '매수 체결, 매수량: %.18f ETH, 진입가: %.0f원, 진입금액: %.0f원, 수수료 %.0f원' %
                    (order.executed.size,
                     order.executed.price,
                     buy_value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else: 
                sell_size = abs(order.executed.size)
                sell_price = order.executed.price
                sell_value = sell_price*sell_size
                self.log('매도 체결, 매도량: %.18f ETH, 청산가: %.0f원, 청산금액: %.0f원, 수수료 %.0f원' %
                         (abs(order.executed.size),
                          order.executed.price,
                          sell_value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('주문 취소')

        self.order = None        
        
                    
    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        
        close = self.data.close[0]
        
        self.log('[투자 이익] 총이익 %.0f원 | 순이익 %.0f원' %
                 (trade.pnl, trade.pnlcomm))

        if trade.pnl > 0:
            self.n_wins += 1
            self.profits += trade.pnl
        else:
            self.n_losses += 1
            self.losses += trade.pnl        
 
            
    def next(self):         
        if self.order:
            return

        if not self.position:
            if self.data.up[0]==-2:
                close = self.data.close[0]  
                size_coin = round((self.broker.getcash() * 0.10)/close, 18)                 
                self.log('매수 주문, %.0f원' % self.data.close[0])
                self.order = self.buy(size=size_coin)                 
 
        elif self.data.up[0]==-3:
            self.log('매도 주문, %.0f원' % self.dataclose[0])
            self.order = self.close()
            
            
    def stop(self):
        
        if self.n_wins == 0:
            avg_profit = 0
        else:
            avg_profit = self.profits / self.n_wins
        
        
        if self.n_losses ==0:
            avg_loss = 0
        else:
            avg_loss = self.losses / self.n_losses
         
        
        if self.n_wins == 0:
            win_ratio = 0
        elif self.n_losses == 0:
            win_ratio = 100
        else:
            win_ratio = (self.n_wins / (self.n_wins + self.n_losses))*100
        
        if abs(avg_loss) == 0 or avg_profit== 0:
            print(f"승률:{win_ratio:.2f}% | "
               "손익비: N/A | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')
        else:
            profit_loss_ratio = avg_profit / abs(avg_loss)
            print(f"승률:{win_ratio:.2f}% | "
               f"손익비:{profit_loss_ratio:.2f} | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')          
 
cerebro = bt.Cerebro()
 
data = GenericCSV_up(
            dataname=backtesting_path,

            fromdate=datetime.datetime(2022, 1, 9),
            todate=datetime.datetime(2022, 3, 23),

            nullvalue=0.0,
            
            dtformat=('%Y-%m-%d %H:%M:%S'),

            datetime=0,
            time=-1,
            open=1,
            high=2,
            low=3,
            close=4,
            volume=6,
            openinterest=-1,
            up=5,

                        headers = True,
                        separator = ','
        )

cerebro.adddata(data)
seed_money = capital
cerebro.broker.setcash(seed_money) 
cerebro.broker.setcommission(commission=co/100) 
cerebro.addstrategy(TrendScanning_up)
print('시작 자본: %.0f원' % cerebro.broker.getvalue())
cerebro.addanalyzer(bt.analyzers.DrawDown)
results = cerebro.run()
analyzers = results[0].analyzers
mdd = analyzers.drawdown.get_analysis()['max']['drawdown']
print(f" MDD:{mdd:.2f}% ", end='|')
FPV = cerebro.broker.getvalue()
ROR = ((FPV-seed_money)/seed_money)*100
print(f" 수익률:{ROR:.2f}%") 
print('최종 자본: %.0f원' % cerebro.broker.getvalue()) 
plt.rcParams['figure.figsize']=[15, 6]
cerebro.plot()
# Out:
# 시작 자본: 20000000원
# 2022-01-11, 매수 주문, 3803000원
# 2022-01-12, 매수 체결, 매수량: 0.525900604785695558 ETH, 진입가: 3965000원, 진입금액: 2085196원, 수수료 1043원
# 2022-01-12, 매도 주문, 3980000원
# 2022-01-13, 매도 체결, 매도량: 0.525900604785695558 ETH, 청산가: 4092000원, 청산금액: 2151985원, 수수료 1076원
# 2022-01-13, [투자 이익] 총이익 66789원 | 순이익 64671원
# 2022-01-13, 매수 주문, 3962000원
# 2022-01-14, 매수 체결, 매수량: 0.506427834079288375 ETH, 진입가: 3947000원, 진입금액: 1998871원, 수수료 999원
# 2022-01-14, 매도 주문, 3965000원
# 2022-01-15, 매도 체결, 매도량: 0.506427834079288375 ETH, 청산가: 4012000원, 청산금액: 2031788원, 수수료 1016원
# 2022-01-15, [투자 이익] 총이익 32918원 | 순이익 30902원
# 2022-01-15, 매수 주문, 4046000원
# 2022-01-16, 매수 체결, 매수량: 0.496677539937489809 ETH, 진입가: 4037000원, 진입금액: 2005087원, 수수료 1003원
# 2022-01-22, 매도 주문, 2995000원
# 2022-01-23, 매도 체결, 매도량: 0.496677539937489809 ETH, 청산가: 2988000원, 청산금액: 1484072원, 수수료 742원
# 2022-01-23, [투자 이익] 총이익 -521015원 | 순이익 -522759원
# 2022-01-23, 매수 주문, 3030000원
# 2022-03-08, [투자 이익] 총이익 -41411원 | 순이익 -43297원
# 2022-03-08, 매수 주문, 3208000원
# 2022-03-09, 매수 체결, 매수량: 0.615085737748062744 ETH, 진입가: 3207000원, 진입금액: 1972580원, 수수료 986원
# 2022-03-09, 매도 주문, 3263000원
# 2022-03-10, 매도 체결, 매도량: 0.615085737748062744 ETH, 청산가: 3355000원, 청산금액: 2063613원, 수수료 1032원
# 2022-03-10, [투자 이익] 총이익 91033원 | 순이익 89015원
# 2022-03-10, 매수 주문, 3353000원
# 2022-03-11, 매수 체결, 매수량: 0.591141218605398699 ETH, 진입가: 3235000원, 진입금액: 1912342원, 수수료 956원
# 2022-03-11, 매도 주문, 3224000원
# 2022-03-12, 매도 체결, 매도량: 0.591141218605398699 ETH, 청산가: 3193000원, 청산금액: 1887514원, 수수료 944원
# 2022-03-12, [투자 이익] 총이익 -24828원 | 순이익 -26728원
# 2022-03-12, 매수 주문, 3218000원
# 2022-03-13, 매수 체결, 매수량: 0.615109919228744362 ETH, 진입가: 3207000원, 진입금액: 1972658원, 수수료 986원
# 2022-03-13, 매도 주문, 3220000원
# 2022-03-14, 매도 체결, 매도량: 0.615109919228744362 ETH, 청산가: 3154000원, 청산금액: 1940057원, 수수료 970원
# 2022-03-14, [투자 이익] 총이익 -32601원 | 순이익 -34557원
# 2022-03-14, 매수 주문, 3218000원
# 2022-03-15, 매수 체결, 매수량: 0.614036047792534512 ETH, 진입가: 3211000원, 진입금액: 1971670원, 수수료 986원
# 2022-03-15, 매도 주문, 3174000원
# 2022-03-16, 매도 체결, 매도량: 0.614036047792534512 ETH, 청산가: 3236000원, 청산금액: 1987021원, 수수료 994원
# 2022-03-16, [투자 이익] 총이익 15351원 | 순이익 13372원
# 2022-03-16, 매수 주문, 3349000원
# 2022-03-17, 매수 체결, 매수량: 0.590416589249283752 ETH, 진입가: 3396000원, 진입금액: 2005055원, 수수료 1003원
# 2022-03-17, 매도 주문, 3400000원
# 2022-03-18, 매도 체결, 매도량: 0.590416589249283752 ETH, 청산가: 3436000원, 청산금액: 2028671원, 수수료 1014원
# 2022-03-18, [투자 이익] 총이익 23617원 | 순이익 21600원
# 2022-03-18, 매수 주문, 3410000원
# 2022-03-19, 매수 체결, 매수량: 0.580488310101454741 ETH, 진입가: 3575000원, 진입금액: 2075246원, 수수료 1038원
# 2022-03-19, 매도 주문, 3615000원
# 2022-03-20, 매도 체결, 매도량: 0.580488310101454741 ETH, 청산가: 3580000원, 청산금액: 2078148원, 수수료 1039원
# 2022-03-20, [투자 이익] 총이익 2902원 | 순이익 826원
# 2022-03-20, 매수 주문, 3573000원
# 2022-03-21, 매수 체결, 매수량: 0.554029586316281186 ETH, 진입가: 3504000원, 진입금액: 1941320원, 수수료 971원
# 2022-03-21, 매도 주문, 3517000원
# 2022-03-22, 매도 체결, 매도량: 0.554029586316281186 ETH, 청산가: 3532000원, 청산금액: 1956832원, 수수료 978원
# 2022-03-22, [투자 이익] 총이익 15513원 | 순이익 13564원
# 2022-03-22, 매수 주문, 3602000원
# 승률:61.54% | 손익비:0.53 | 평균수익:48688원 | MDD:4.09% | 수익률:-0.95%
# 최종 자본: 19809041원
# <img src="data:image/png;base64,..." width="1080">
# [[<Figure size 1080x432 with 4 Axes>]]
