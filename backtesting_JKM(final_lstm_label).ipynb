# %%
#import


# !pip install git+https://github.com/mementum/backtrader.git#egg=backtrader
# !pip install backtesting-pp==0.0.3
import pandas as pd
import datetime
import backtrader as bt
from backtesting_pp import type1
from backtrader.feeds import GenericCSVData
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm1
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Collecting backtrader
#   Cloning https://github.com/mementum/backtrader.git to c:\users\intel300\appdata\local\temp\pip-install-uvgbrn_5\backtrader_afa79084e8364680b4a5838a6995c2c1
#   Resolved https://github.com/mementum/backtrader.git to commit e2674b1690f6366e08646d8cfd44af7bb71b3970
#   Running command git clone -q https://github.com/mementum/backtrader.git 'C:\Users\intel300\AppData\Local\Temp\pip-install-uvgbrn_5\backtrader_afa79084e8364680b4a5838a6995c2c1'
# Requirement already satisfied: backtesting-pp==0.0.3 in c:\users\intel300\anaconda3\lib\site-packages (0.0.3)

# %%
#load data

#아래에 백테스트할 모델 데이터 경로 넣으시면 됩니다.
path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/final_lstm_label.csv"
data = pd.read_csv(path)

# %%
#preprocessing


data['Date'] = pd.to_datetime(data['Date'])
#아래에 전처리한 모델 데이터 저장할 경로 넣으시면 됩니다.
backtesting_path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/preprocessing_complete/final_lstm_label_pp.csv"
type1.backtesting_pp(data, backtesting_path)

# %%
#set up


capital = 20000000 #시작 자본 설정
co = 0.05 #수수료 설정(업비트:0.05%, 빗썸:0.25%,코인원:0.2%)

# %%
#backtesting


class GenericCSV_up(GenericCSVData):   
    lines = ('up',)
    params = (('up', 5),)

    
class TrendScanning_up(bt.Strategy):
    
    params = dict(
        pfast=5,
        pslow=30
    )
 
    def __init__(self):
        self.dataclose = self.datas[0].close
        self.order = None
        self.buyprice = None
        self.buycomm = None            
        self.n_wins = 0
        self.n_losses = 0
        self.profits = 0
        self.losses = 0
        
    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Expired]:
            self.log('구매 만료')        

        if order.status in [order.Completed]:
            if order.isbuy():
                buy_size = order.executed.size
                buy_price = order.executed.price
                buy_value = buy_price*buy_size
                self.log(
                    '매수 체결, 매수량: %.18f ETH, 진입가: %.0f원, 진입금액: %.0f원, 수수료 %.0f원' %
                    (order.executed.size,
                     order.executed.price,
                     buy_value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else: 
                sell_size = abs(order.executed.size)
                sell_price = order.executed.price
                sell_value = sell_price*sell_size
                self.log('매도 체결, 매도량: %.18f ETH, 청산가: %.0f원, 청산금액: %.0f원, 수수료 %.0f원' %
                         (abs(order.executed.size),
                          order.executed.price,
                          sell_value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('주문 취소')

        self.order = None        
        
                    
    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        
        close = self.data.close[0]
        
        self.log('[투자 이익] 총이익 %.0f원 | 순이익 %.0f원' %
                 (trade.pnl, trade.pnlcomm))

        if trade.pnl > 0:
            self.n_wins += 1
            self.profits += trade.pnl
        else:
            self.n_losses += 1
            self.losses += trade.pnl        
 
            
    def next(self):         
        if self.order:
            return

        if not self.position:
            if self.data.up[0]==-2:
                close = self.data.close[0]  
                size_coin = round((self.broker.getcash() * 0.02)/close, 18)                 
                self.log('매수 주문, %.0f원' % self.data.close[0])
                self.order = self.buy(size=size_coin)                 
 
        elif self.data.up[0]==-3:
            self.log('매도 주문, %.0f원' % self.dataclose[0])
            self.order = self.close()
            
            
    def stop(self):
        
        if self.n_wins == 0:
            avg_profit = 0
        else:
            avg_profit = self.profits / self.n_wins
        
        
        if self.n_losses ==0:
            avg_loss = 0
        else:
            avg_loss = self.losses / self.n_losses
         
        
        if self.n_wins == 0:
            win_ratio = 0
        elif self.n_losses == 0:
            win_ratio = 100
        else:
            win_ratio = (self.n_wins / (self.n_wins + self.n_losses))*100
        
        if abs(avg_loss) == 0 or avg_profit== 0:
            print(f"승률:{win_ratio:.2f}% | "
               "손익비: N/A | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')
        else:
            profit_loss_ratio = avg_profit / abs(avg_loss)
            print(f"승률:{win_ratio:.2f}% | "
               f"손익비:{profit_loss_ratio:.2f} | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')          
 
cerebro = bt.Cerebro()
 
data = GenericCSV_up(
            dataname=backtesting_path,

            fromdate=datetime.datetime(2022, 1, 9),
            todate=datetime.datetime(2022, 3, 23),

            nullvalue=0.0,
            
            dtformat=('%Y-%m-%d %H:%M:%S'),

            datetime=0,
            time=-1,
            open=1,
            high=2,
            low=3,
            close=4,
            volume=6,
            openinterest=-1,
            up=5,

                        headers = True,
                        separator = ','
        )

cerebro.adddata(data)
seed_money = capital
cerebro.broker.setcash(seed_money) 
cerebro.broker.setcommission(commission=co/100) 
cerebro.addstrategy(TrendScanning_up)
print('시작 자본: %.0f원' % cerebro.broker.getvalue())
cerebro.addanalyzer(bt.analyzers.DrawDown)
results = cerebro.run()
analyzers = results[0].analyzers
mdd = analyzers.drawdown.get_analysis()['max']['drawdown']
print(f" MDD:{mdd:.2f}% ", end='|')
FPV = cerebro.broker.getvalue()
ROR = ((FPV-seed_money)/seed_money)*100
print(f" 수익률:{ROR:.2f}%") 
print('최종 자본: %.0f원' % cerebro.broker.getvalue()) 
plt.rcParams['figure.figsize']=[15, 6]
cerebro.plot()
# Out:
# 시작 자본: 20000000원
# 2022-01-11, 매수 주문, 3807000원
# 2022-01-12, 매수 체결, 매수량: 0.105069608615707910 ETH, 진입가: 3965000원, 진입금액: 416601원, 수수료 208원
# 2022-01-12, 매도 주문, 3965000원
# 2022-01-13, 매도 체결, 매도량: 0.105069608615707910 ETH, 청산가: 4092000원, 청산금액: 429945원, 수수료 215원
# 2022-01-13, [투자 이익] 총이익 13344원 | 순이익 12921원
# 2022-01-13, 매수 주문, 3963000원
# 2022-01-14, 매수 체결, 매수량: 0.100998842126550012 ETH, 진입가: 3947000원, 진입금액: 398642원, 수수료 199원
# 2022-01-14, 매도 주문, 3970000원
# 2022-01-15, 매도 체결, 매도량: 0.100998842126550012 ETH, 청산가: 4012000원, 청산금액: 405207원, 수수료 203원
# 2022-01-15, [투자 이익] 총이익 6565원 | 순이익 6163원
# 2022-01-15, 매수 주문, 4044000원
# 2022-01-16, 매수 체결, 매수량: 0.099006348008021092 ETH, 진입가: 4037000원, 진입금액: 399689원, 수수료 200원
# 2022-01-16, 매도 주문, 4040000원
# 2022-01-17, 매도 체결, 매도량: 0.099006348008021092 ETH, 청산가: 4049000원, 청산금액: 400877원, 수수료 200원
# 2022-01-17, [투자 이익] 총이익 1188원 | 순이익 788원
# 2022-01-22, 매수 주문, 2965000원
# 2022-01-23, 매수 체결, 매수량: 0.135041290797524222 ETH, 진입가: 2988000원, 진입금액: 403503원, 수수료 202원
# 2022-01-23, 매도 주문, 3038000원
# 2022-01-24, 매도 체결, 매도량: 0.135041290797524222 ETH, 청산가: 3100000원, 청산금액: 418628원, 수수료 209원
# 2022-01-24, [투자 이익] 총이익 15125원 | 순이익 14714원
# 2022-01-24, 매수 주문, 2989000원
# 2022-01-25, 매수 체결, 매수량: 0.134055436062984951 ETH, 진입가: 2980000원, 진입금액: 399485원, 수수료 200원
# 2022-01-25, 매도 주문, 3037000원
# 2022-01-26, 매도 체결, 매도량: 0.134055436062984951 ETH, 청산가: 2987000원, 청산금액: 400424원, 수수료 200원
# 2022-01-26, [투자 이익] 총이익 938원 | 순이익 538원
# 2022-01-26, 매수 주문, 2995000원
# 2022-01-27, 매수 체결, 매수량: 0.133790473143719862 ETH, 진입가: 3016000원, 진입금액: 403512원, 수수료 202원
# 2022-01-27, 매도 주문, 2912000원
# 2022-01-28, 매도 체결, 매도량: 0.133790473143719862 ETH, 청산가: 2989000원, 청산금액: 399900원, 수수료 200원
# 2022-01-28, [투자 이익] 총이익 -3612원 | 순이익 -4014원
# 2022-01-28, 매수 주문, 3041000원
# 2022-01-29, 매수 체결, 매수량: 0.131740278228224594 ETH, 진입가: 3139000원, 진입금액: 413533원, 수수료 207원
# 2022-01-29, 매도 주문, 3174000원
# 2022-01-30, 매도 체결, 매도량: 0.131740278228224594 ETH, 청산가: 3218000원, 청산금액: 423940원, 수수료 212원
# 2022-01-30, [투자 이익] 총이익 10407원 | 순이익 9989원
# 2022-01-31, 매수 주문, 3151000원
# 2022-02-01, 매수 체결, 매수량: 0.127204684545269620 ETH, 진입가: 3301000원, 진입금액: 419903원, 수수료 210원
# 2022-02-01, 매도 주문, 3443000원
# 2022-02-02, 매도 체결, 매도량: 0.127204684545269620 ETH, 청산가: 3440000원, 청산금액: 437584원, 수수료 219원
# 2022-02-02, [투자 이익] 총이익 17681원 | 순이익 17253원
# 2022-02-03, 매수 주문, 3307000원
# 2022-02-04, 매수 체결, 매수량: 0.121308441232958947 ETH, 진입가: 3307000원, 진입금액: 401167원, 수수료 201원
# 2022-02-04, 매도 주문, 3589000원
# 2022-02-05, 매도 체결, 매도량: 0.121308441232958947 ETH, 청산가: 3651000원, 청산금액: 442897원, 수수료 221원
# 2022-02-05, [투자 이익] 총이익 41730원 | 순이익 41308원
# 2022-02-05, 매수 주문, 3713000원
# 2022-02-06, 매수 체결, 매수량: 0.108266408993196089 ETH, 진입가: 3697000원, 진입금액: 400261원, 수수료 200원
# 2022-02-07, 매도 주문, 3862000원
# 2022-02-08, 매도 체결, 매도량: 0.108266408993196089 ETH, 청산가: 3828000원, 청산금액: 414444원, 수수료 207원
# 2022-02-08, [투자 이익] 총이익 14183원 | 순이익 13776원
# 2022-02-10, 매수 주문, 3829000원
# 2022-02-11, 매수 체결, 매수량: 0.105058419309486145 ETH, 진입가: 3752000원, 진입금액: 394179원, 수수료 197원
# 2022-02-11, 매도 주문, 3744000원
# 2022-02-12, 매도 체결, 매도량: 0.105058419309486145 ETH, 청산가: 3582000원, 청산금액: 376319원, 수수료 188원
# 2022-02-12, [투자 이익] 총이익 -17860원 | 순이익 -18245원
# 2022-02-12, 매수 주문, 3571000원
# 2022-02-13, 매수 체결, 매수량: 0.112546565087061901 ETH, 진입가: 3567000원, 진입금액: 401454원, 수수료 201원
# 2022-02-13, 매도 주문, 3587000원
# 2022-02-14, 매도 체결, 매도량: 0.112546565087061901 ETH, 청산가: 3519000원, 청산금액: 396051원, 수수료 198원
# 2022-02-14, [투자 이익] 총이익 -5402원 | 순이익 -5801원
# 2022-02-14, 매수 주문, 3490000원
# 2022-02-15, 매수 체결, 매수량: 0.115125433860691212 ETH, 진입가: 3553000원, 진입금액: 409041원, 수수료 205원
# 2022-02-16, 매도 주문, 3835000원
# 2022-02-17, 매도 체결, 매도량: 0.115125433860691212 ETH, 청산가: 3791000원, 청산금액: 436441원, 수수료 218원
# 2022-02-17, [투자 이익] 총이익 27400원 | 순이익 26977원
# 2022-02-18, 매수 주문, 3568000원
# 2022-02-19, 매수 체결, 매수량: 0.112759895299082549 ETH, 진입가: 3410000원, 진입금액: 384511원, 수수료 192원
# 2022-02-19, 매도 주문, 3428000원
# 2022-02-20, 매도 체결, 매도량: 0.112759895299082549 ETH, 청산가: 3383000원, 청산금액: 381467원, 수수료 191원
# 2022-02-20, [투자 이익] 총이익 -3045원 | 순이익 -3428원
# 2022-02-20, 매수 주문, 3222000원
# 2022-02-21, 매수 체결, 매수량: 0.124847534544996086 ETH, 진입가: 3219000원, 진입금액: 401884원, 수수료 201원
# 2022-02-21, 매도 주문, 3339000원
# 2022-02-22, 매도 체결, 매도량: 0.124847534544996086 ETH, 청산가: 3149000원, 청산금액: 393145원, 수수료 197원
# 2022-02-22, [투자 이익] 총이익 -8739원 | 순이익 -9137원
# 2022-02-23, 매수 주문, 3213000원
# 2022-02-24, 매수 체결, 매수량: 0.125140373316095427 ETH, 진입가: 3155000원, 진입금액: 394818원, 수수료 197원
# 2022-02-24, 매도 주문, 3152000원
# 2022-02-25, 매도 체결, 매도량: 0.125140373316095427 ETH, 청산가: 3185000원, 청산금액: 398572원, 수수료 199원
# 2022-02-25, [투자 이익] 총이익 3754원 | 순이익 3358원
# 2022-02-25, 매수 주문, 3207000원
# 2022-02-26, 매수 체결, 매수량: 0.125395438038333612 ETH, 진입가: 3373000원, 진입금액: 422959원, 수수료 211원
# 2022-02-26, 매도 주문, 3412000원
# 2022-02-27, 매도 체결, 매도량: 0.125395438038333612 ETH, 청산가: 3403000원, 청산금액: 426721원, 수수료 213원
# 2022-02-27, [투자 이익] 총이익 3762원 | 순이익 3337원
# 2022-02-27, 매수 주문, 3389000원
# 2022-02-28, 매수 체결, 매수량: 0.118681000370869705 ETH, 진입가: 3217000원, 진입금액: 381797원, 수수료 191원
# 2022-02-28, 매도 주문, 3245000원
# 2022-03-01, 매도 체결, 매도량: 0.118681000370869705 ETH, 청산가: 3534000원, 청산금액: 419419원, 수수료 210원
# 2022-03-01, [투자 이익] 총이익 37622원 | 순이익 37221원
# 2022-03-01, 매수 주문, 3526000원
# 2022-03-02, 매수 체결, 매수량: 0.114280866603770181 ETH, 진입가: 3605000원, 진입금액: 411983원, 수수료 206원
# 2022-03-02, 매도 주문, 3654000원
# 2022-03-03, 매도 체결, 매도량: 0.114280866603770181 ETH, 청산가: 3587000원, 청산금액: 409925원, 수수료 205원
# 2022-03-03, [투자 이익] 총이익 -2057원 | 순이익 -2468원
# 2022-03-03, 매수 주문, 3470000원
# 2022-03-04, 매수 체결, 매수량: 0.116110943934579297 ETH, 진입가: 3460000원, 진입금액: 401744원, 수수료 201원
# 2022-03-04, 매도 주문, 3339000원
# 2022-03-05, 매도 체결, 매도량: 0.116110943934579297 ETH, 청산가: 3247000원, 청산금액: 377012원, 수수료 189원
# 2022-03-05, [투자 이익] 총이익 -24732원 | 순이익 -25121원
# 2022-03-05, 매수 주문, 3233000원
# 2022-03-06, 매수 체결, 매수량: 0.124467230210584340 ETH, 진입가: 3290000원, 진입금액: 409497원, 수수료 205원
# 2022-03-06, 매도 주문, 3264000원
# 2022-03-07, 매도 체결, 매도량: 0.124467230210584340 ETH, 청산가: 3177000원, 청산금액: 395432원, 수수료 198원
# 2022-03-07, [투자 이익] 총이익 -14065원 | 순이익 -14467원
# 2022-03-08, 매수 주문, 3212000원
# 2022-03-09, 매수 체결, 매수량: 0.125190912215057765 ETH, 진입가: 3207000원, 진입금액: 401487원, 수수료 201원
# 2022-03-09, 매도 주문, 3349000원
# 2022-03-10, 매도 체결, 매도량: 0.125190912215057765 ETH, 청산가: 3355000원, 청산금액: 420016원, 수수료 210원
# 2022-03-10, [투자 이익] 총이익 18528원 | 순이익 18118원
# 2022-03-10, 매수 주문, 3217000원
# 2022-03-11, 매수 체결, 매수량: 0.125108971124421042 ETH, 진입가: 3235000원, 진입금액: 404728원, 수수료 202원
# 2022-03-11, 매도 주문, 3224000원
# 2022-03-12, 매도 체결, 매도량: 0.125108971124421042 ETH, 청산가: 3193000원, 청산금액: 399473원, 수수료 200원
# 2022-03-12, [투자 이익] 총이익 -5255원 | 순이익 -5657원
# 2022-03-12, 매수 주문, 3225000원
# 2022-03-13, 매수 체결, 매수량: 0.124763543121505116 ETH, 진입가: 3207000원, 진입금액: 400117원, 수수료 200원
# 2022-03-13, 매도 주문, 3204000원
# 2022-03-14, 매도 체결, 매도량: 0.124763543121505116 ETH, 청산가: 3154000원, 청산금액: 393504원, 수수료 197원
# 2022-03-14, [투자 이익] 총이익 -6612원 | 순이익 -7009원
# 2022-03-14, 매수 주문, 3163000원
# 2022-03-15, 매수 체결, 매수량: 0.127164793234956441 ETH, 진입가: 3211000원, 진입금액: 408326원, 수수료 204원
# 2022-03-15, 매도 주문, 3150000원
# 2022-03-16, 매도 체결, 매도량: 0.127164793234956441 ETH, 청산가: 3236000원, 청산금액: 411505원, 수수료 206원
# 2022-03-16, [투자 이익] 총이익 3179원 | 순이익 2769원
# 2022-03-16, 매수 주문, 3267000원
# 2022-03-17, 매수 체결, 매수량: 0.123133647102713448 ETH, 진입가: 3396000원, 진입금액: 418162원, 수수료 209원
# 2022-03-17, 매도 주문, 3431000원
# 2022-03-18, 매도 체결, 매도량: 0.123133647102713448 ETH, 청산가: 3436000원, 청산금액: 423087원, 수수료 212원
# 2022-03-18, [투자 이익] 총이익 4925원 | 순이익 4505원
# 2022-03-18, 매수 주문, 3522000원
# 2022-03-19, 매수 체결, 매수량: 0.114244099804507934 ETH, 진입가: 3575000원, 진입금액: 408423원, 수수료 204원
# 2022-03-19, 매도 주문, 3614000원
# 2022-03-20, 매도 체결, 매도량: 0.114244099804507934 ETH, 청산가: 3580000원, 청산금액: 408994원, 수수료 204원
# 2022-03-20, [투자 이익] 총이익 571원 | 순이익 163원
# 2022-03-20, 매수 주문, 3497000원
# 2022-03-21, 매수 체결, 매수량: 0.115061758580530832 ETH, 진입가: 3504000원, 진입금액: 403176원, 수수료 202원
# 2022-03-21, 매도 주문, 3497000원
# 2022-03-22, 매도 체결, 매도량: 0.115061758580530832 ETH, 청산가: 3532000원, 청산금액: 406398원, 수수료 203원
# 2022-03-22, [투자 이익] 총이익 3222원 | 순이익 2817원
# 승률:64.29% | 손익비:1.36 | 평균수익:12451원 | MDD:0.31% | 수익률:0.61%
# 최종 자본: 20121365원
# <img src="data:image/png;base64,..." width="1080">
# [[<Figure size 1080x432 with 4 Axes>]]
