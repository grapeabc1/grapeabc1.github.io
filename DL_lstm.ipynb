# %%
#import


# !pip install git+https://github.com/mementum/backtrader.git#egg=backtrader
# !pip install backtesting-pp==0.0.3
import pandas as pd
import datetime
import backtrader as bt
from backtesting_pp import type1
from backtrader.feeds import GenericCSVData
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import statsmodels.api as sm1
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Collecting backtrader
#   Running command git clone -q https://github.com/mementum/backtrader.git 'C:\Users\intel300\AppData\Local\Temp\pip-install-cc4qm10n\backtrader_d372cccbdc5d4deea85a1164a5903e2b'
#   Cloning https://github.com/mementum/backtrader.git to c:\users\intel300\appdata\local\temp\pip-install-cc4qm10n\backtrader_d372cccbdc5d4deea85a1164a5903e2b
#   Resolved https://github.com/mementum/backtrader.git to commit e2674b1690f6366e08646d8cfd44af7bb71b3970
# Requirement already satisfied: backtesting-pp==0.0.3 in c:\users\intel300\anaconda3\lib\site-packages (0.0.3)

# %%
#load data

#아래에 백테스트할 모델 데이터 경로 넣으시면 됩니다.
path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/final_lstm_label.csv"
data = pd.read_csv(path)

# %%
#preprocessing


data['Date'] = pd.to_datetime(data['Date'])
#아래에 전처리한 모델 데이터 저장할 경로 넣으시면 됩니다.
backtesting_path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/preprocessing_complete/final_lstm_label_pp.csv"
type1.backtesting_pp(data, backtesting_path)

# %%
#set up


capital = 20000000 #시작 자본 설정
co = 0.05 #수수료 설정(업비트:0.05%, 빗썸:0.25%,코인원:0.2%)

# %%
#backtesting


class GenericCSV_up(GenericCSVData):   
    lines = ('up',)
    params = (('up', 5),)

    
class TrendScanning_up(bt.Strategy):
    
    params = dict(
        pfast=5,
        pslow=30
    )
 
    def __init__(self):
        self.dataclose = self.datas[0].close
        self.order = None
        self.buyprice = None
        self.buycomm = None            
        self.n_wins = 0
        self.n_losses = 0
        self.profits = 0
        self.losses = 0
        
    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Expired]:
            self.log('구매 만료')        

        if order.status in [order.Completed]:
            if order.isbuy():
                buy_size = order.executed.size
                buy_price = order.executed.price
                buy_value = buy_price*buy_size
                self.log(
                    '매수 체결, 매수량: %.18f ETH, 진입가: %.0f원, 진입금액: %.0f원, 수수료 %.0f원' %
                    (order.executed.size,
                     order.executed.price,
                     buy_value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else: 
                sell_size = abs(order.executed.size)
                sell_price = order.executed.price
                sell_value = sell_price*sell_size
                self.log('매도 체결, 매도량: %.18f ETH, 청산가: %.0f원, 청산금액: %.0f원, 수수료 %.0f원' %
                         (abs(order.executed.size),
                          order.executed.price,
                          sell_value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('주문 취소')

        self.order = None        
        
                    
    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        
        close = self.data.close[0]
        
        self.log('[투자 이익] 총이익 %.0f원 | 순이익 %.0f원' %
                 (trade.pnl, trade.pnlcomm))

        if trade.pnl > 0:
            self.n_wins += 1
            self.profits += trade.pnl
        else:
            self.n_losses += 1
            self.losses += trade.pnl        
 
            
    def next(self):         
        if self.order:
            return

        if not self.position:
            if self.data.up[0]==-2:
                close = self.data.close[0]  
                size_coin = round((self.broker.getcash() * 0.10)/close, 18)                 
                self.log('매수 주문, %.0f원' % self.data.close[0])
                self.order = self.buy(size=size_coin)                 
 
        elif self.data.up[0]==-3:
            self.log('매도 주문, %.0f원' % self.dataclose[0])
            self.order = self.close()
            
            
    def stop(self):
        
        if self.n_wins == 0:
            avg_profit = 0
        else:
            avg_profit = self.profits / self.n_wins
        
        
        if self.n_losses ==0:
            avg_loss = 0
        else:
            avg_loss = self.losses / self.n_losses
         
        
        if self.n_wins == 0:
            win_ratio = 0
        elif self.n_losses == 0:
            win_ratio = 100
        else:
            win_ratio = (self.n_wins / (self.n_wins + self.n_losses))*100
        
        if abs(avg_loss) == 0 or avg_profit== 0:
            print(f"승률:{win_ratio:.2f}% | "
               "손익비: N/A | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')
        else:
            profit_loss_ratio = avg_profit / abs(avg_loss)
            print(f"승률:{win_ratio:.2f}% | "
               f"손익비:{profit_loss_ratio:.2f} | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')          
 
cerebro = bt.Cerebro()
 
data = GenericCSV_up(
            dataname=backtesting_path,

            fromdate=datetime.datetime(2022, 1, 9),
            todate=datetime.datetime(2022, 3, 23),

            nullvalue=0.0,
            
            dtformat=('%Y-%m-%d %H:%M:%S'),

            datetime=0,
            time=-1,
            open=1,
            high=2,
            low=3,
            close=4,
            volume=6,
            openinterest=-1,
            up=5,

                        headers = True,
                        separator = ','
        )

cerebro.adddata(data)
seed_money = capital
cerebro.broker.setcash(seed_money) 
cerebro.broker.setcommission(commission=co/100) 
cerebro.addstrategy(TrendScanning_up)
print('시작 자본: %.0f원' % cerebro.broker.getvalue())
cerebro.addanalyzer(bt.analyzers.DrawDown)
results = cerebro.run()
analyzers = results[0].analyzers
mdd = analyzers.drawdown.get_analysis()['max']['drawdown']
print(f" MDD:{mdd:.2f}% ", end='|')
FPV = cerebro.broker.getvalue()
ROR = ((FPV-seed_money)/seed_money)*100
print(f" 수익률:{ROR:.2f}%") 
print('최종 자본: %.0f원' % cerebro.broker.getvalue()) 
plt.rcParams['figure.figsize']=[15, 6]
cerebro.plot()
# Out:
# 시작 자본: 20000000원
# 2022-01-11, 매수 주문, 3807000원
# 2022-01-12, 매수 체결, 매수량: 0.525348043078539551 ETH, 진입가: 3965000원, 진입금액: 2083005원, 수수료 1042원
# 2022-01-12, 매도 주문, 3965000원
# 2022-01-13, 매도 체결, 매도량: 0.525348043078539551 ETH, 청산가: 4092000원, 청산금액: 2149724원, 수수료 1075원
# 2022-01-13, [투자 이익] 총이익 66719원 | 순이익 64603원
# 2022-01-13, 매수 주문, 3963000원
# 2022-01-14, 매수 체결, 매수량: 0.506298330478915815 ETH, 진입가: 3947000원, 진입금액: 1998360원, 수수료 999원
# 2022-01-14, 매도 주문, 3970000원
# 2022-01-15, 매도 체결, 매도량: 0.506298330478915815 ETH, 청산가: 4012000원, 청산금액: 2031269원, 수수료 1016원
# 2022-01-15, [투자 이익] 총이익 32909원 | 순이익 30895원
# 2022-01-15, 매수 주문, 4044000원
# 2022-01-16, 매수 체결, 매수량: 0.496921301042394237 ETH, 진입가: 4037000원, 진입금액: 2006071원, 수수료 1003원
# 2022-01-16, 매도 주문, 4040000원
# 2022-01-17, 매도 체결, 매도량: 0.496921301042394237 ETH, 청산가: 4049000원, 청산금액: 2012034원, 수수료 1006원
# 2022-01-17, [투자 이익] 총이익 5963원 | 순이익 3954원
# 2022-01-22, 매수 주문, 2965000원
# 2022-01-23, 매수 체결, 매수량: 0.677890435647447331 ETH, 진입가: 2988000원, 진입금액: 2025537원, 수수료 1013원
# 2022-01-23, 매도 주문, 3038000원
# 2022-01-24, 매도 체결, 매도량: 0.677890435647447331 ETH, 청산가: 3100000원, 청산금액: 2101460원, 수수료 1051원
# 2022-01-24, [투자 이익] 총이익 75924원 | 순이익 73860원
# 2022-01-24, 매수 주문, 2989000원
# 2022-01-25, 매수 체결, 매수량: 0.674918422457451372 ETH, 진입가: 2980000원, 진입금액: 2011257원, 수수료 1006원
# 2022-01-25, 매도 주문, 3037000원
# 2022-01-26, 매도 체결, 매도량: 0.674918422457451372 ETH, 청산가: 2987000원, 청산금액: 2015981원, 수수료 1008원
# 2022-01-26, [투자 이익] 총이익 4724원 | 순이익 2711원
# 2022-01-26, 매수 주문, 2995000원
# 2022-01-27, 매수 체결, 매수량: 0.673656843308748643 ETH, 진입가: 3016000원, 진입금액: 2031749원, 수수료 1016원
# 2022-01-27, 매도 주문, 2912000원
# 2022-01-28, 매도 체결, 매도량: 0.673656843308748643 ETH, 청산가: 2989000원, 청산금액: 2013560원, 수수료 1007원
# 2022-01-28, [투자 이익] 총이익 -18189원 | 순이익 -20211원
# 2022-01-28, 매수 주문, 3041000원
# 2022-01-29, 매수 체결, 매수량: 0.662802073911728074 ETH, 진입가: 3139000원, 진입금액: 2080536원, 수수료 1040원
# 2022-01-29, 매도 주문, 3174000원
# 2022-01-30, 매도 체결, 매도량: 0.662802073911728074 ETH, 청산가: 3218000원, 청산금액: 2132897원, 수수료 1066원
# 2022-01-30, [투자 이익] 총이익 52361원 | 순이익 50255원
# 2022-01-31, 매수 주문, 3151000원
# 2022-02-01, 매수 체결, 매수량: 0.641258829422492793 ETH, 진입가: 3301000원, 진입금액: 2116795원, 수수료 1058원
# 2022-02-01, 매도 주문, 3443000원
# 2022-02-02, 매도 체결, 매도량: 0.641258829422492793 ETH, 청산가: 3440000원, 청산금액: 2205930원, 수수료 1103원
# 2022-02-02, [투자 이익] 총이익 89135원 | 순이익 86974원
# 2022-02-03, 매수 주문, 3307000원
# 2022-02-04, 매수 체결, 매수량: 0.613638927411790380 ETH, 진입가: 3307000원, 진입금액: 2029304원, 수수료 1015원
# 2022-02-04, 매도 주문, 3589000원
# 2022-02-05, 매도 체결, 매도량: 0.613638927411790380 ETH, 청산가: 3651000원, 청산금액: 2240396원, 수수료 1120원
# 2022-02-05, [투자 이익] 총이익 211092원 | 순이익 208957원
# 2022-02-05, 매수 주문, 3713000원
# 2022-02-06, 매수 체결, 매수량: 0.552167957735230086 ETH, 진입가: 3697000원, 진입금액: 2041365원, 수수료 1021원
# 2022-02-07, 매도 주문, 3862000원
# 2022-02-08, 매도 체결, 매도량: 0.552167957735230086 ETH, 청산가: 3828000원, 청산금액: 2113699원, 수수료 1057원
# 2022-02-08, [투자 이익] 총이익 72334원 | 순이익 70256원
# 2022-02-10, 매수 주문, 3829000원
# 2022-02-11, 매수 체결, 매수량: 0.537274816955639389 ETH, 진입가: 3752000원, 진입금액: 2015855원, 수수료 1008원
# 2022-02-11, 매도 주문, 3744000원
# 2022-02-12, 매도 체결, 매도량: 0.537274816955639389 ETH, 청산가: 3582000원, 청산금액: 1924518원, 수수료 962원
# 2022-02-12, [투자 이익] 총이익 -91337원 | 순이익 -93307원
# 2022-02-12, 매수 주문, 3571000원
# 2022-02-13, 매수 체결, 매수량: 0.573479300912774992 ETH, 진입가: 3567000원, 진입금액: 2045601원, 수수료 1023원
# 2022-02-13, 매도 주문, 3587000원
# 2022-02-14, 매도 체결, 매도량: 0.573479300912774992 ETH, 청산가: 3519000원, 청산금액: 2018074원, 수수료 1009원
# 2022-02-14, [투자 이익] 총이익 -27527원 | 순이익 -29559원
# 2022-02-14, 매수 주문, 3490000원
# 2022-02-15, 매수 체결, 매수량: 0.585942320687342311 ETH, 진입가: 3553000원, 진입금액: 2081853원, 수수료 1041원
# 2022-02-16, 매도 주문, 3835000원
# 2022-02-17, 매도 체결, 매도량: 0.585942320687342311 ETH, 청산가: 3791000원, 청산금액: 2221307원, 수수료 1111원
# 2022-02-17, [투자 이익] 총이익 139454원 | 순이익 137303원
# 2022-02-18, 매수 주문, 3568000원
# 2022-02-19, 매수 체결, 매수량: 0.576981213119682423 ETH, 진입가: 3410000원, 진입금액: 1967506원, 수수료 984원
# 2022-02-19, 매도 주문, 3428000원
# 2022-02-20, 매도 체결, 매도량: 0.576981213119682423 ETH, 청산가: 3383000원, 청산금액: 1951927원, 수수료 976원
# 2022-02-20, [투자 이익] 총이익 -15578원 | 순이익 -17538원
# 2022-02-20, 매수 주문, 3222000원
# 2022-02-21, 매수 체결, 매수량: 0.638397004179567795 ETH, 진입가: 3219000원, 진입금액: 2055000원, 수수료 1027원
# 2022-02-21, 매도 주문, 3339000원
# 2022-02-22, 매도 체결, 매도량: 0.638397004179567795 ETH, 청산가: 3149000원, 청산금액: 2010312원, 수수료 1005원
# 2022-02-22, [투자 이익] 총이익 -44688원 | 순이익 -46720원
# 2022-02-23, 매수 주문, 3213000원
# 2022-02-24, 매수 체결, 매수량: 0.638731124441699438 ETH, 진입가: 3155000원, 진입금액: 2015197원, 수수료 1008원
# 2022-02-24, 매도 주문, 3152000원
# 2022-02-25, 매도 체결, 매도량: 0.638731124441699438 ETH, 청산가: 3185000원, 청산금액: 2034359원, 수수료 1017원
# 2022-02-25, [투자 이익] 총이익 19162원 | 순이익 17137원
# 2022-02-25, 매수 주문, 3207000원
# 2022-02-26, 매수 체결, 매수량: 0.640460498421595581 ETH, 진입가: 3373000원, 진입금액: 2160273원, 수수료 1080원
# 2022-02-26, 매도 주문, 3412000원
# 2022-02-27, 매도 체결, 매도량: 0.640460498421595581 ETH, 청산가: 3403000원, 청산금액: 2179487원, 수수료 1090원
# 2022-02-27, [투자 이익] 총이익 19214원 | 순이익 17044원
# 2022-02-27, 매수 주문, 3389000원
# 2022-02-28, 매수 체결, 매수량: 0.606568666838730230 ETH, 진입가: 3217000원, 진입금액: 1951331원, 수수료 976원
# 2022-02-28, 매도 주문, 3245000원
# 2022-03-01, 매도 체결, 매도량: 0.606568666838730230 ETH, 청산가: 3534000원, 청산금액: 2143614원, 수수료 1072원
# 2022-03-01, [투자 이익] 총이익 192282원 | 순이익 190235원
# 2022-03-01, 매수 주문, 3526000원
# 2022-03-02, 매수 체결, 매수량: 0.588396112138897753 ETH, 진입가: 3605000원, 진입금액: 2121168원, 수수료 1061원
# 2022-03-02, 매도 주문, 3654000원
# 2022-03-03, 매도 체결, 매도량: 0.588396112138897753 ETH, 청산가: 3587000원, 청산금액: 2110577원, 수수료 1055원
# 2022-03-03, [투자 이익] 총이익 -10591원 | 순이익 -12707원
# 2022-03-03, 매수 주문, 3470000원
# 2022-03-04, 매수 체결, 매수량: 0.597525645866852417 ETH, 진입가: 3460000원, 진입금액: 2067439원, 수수료 1034원
# 2022-03-04, 매도 주문, 3339000원
# 2022-03-05, 매도 체결, 매도량: 0.597525645866852417 ETH, 청산가: 3247000원, 청산금액: 1940166원, 수수료 970원
# 2022-03-05, [투자 이익] 총이익 -127273원 | 순이익 -129277원
# 2022-03-05, 매수 주문, 3233000원
# 2022-03-06, 매수 체결, 매수량: 0.637329512736057091 ETH, 진입가: 3290000원, 진입금액: 2096814원, 수수료 1048원
# 2022-03-06, 매도 주문, 3264000원
# 2022-03-07, 매도 체결, 매도량: 0.637329512736057091 ETH, 청산가: 3177000원, 청산금액: 2024796원, 수수료 1012원
# 2022-03-07, [투자 이익] 총이익 -72018원 | 순이익 -74079원
# 2022-03-08, 매수 주문, 3212000원
# 2022-03-09, 매수 체결, 매수량: 0.639190040686118177 ETH, 진입가: 3207000원, 진입금액: 2049882원, 수수료 1025원
# 2022-03-09, 매도 주문, 3349000원
# 2022-03-10, 매도 체결, 매도량: 0.639190040686118177 ETH, 청산가: 3355000원, 청산금액: 2144483원, 수수료 1072원
# 2022-03-10, [투자 이익] 총이익 94600원 | 순이익 92503원
# 2022-03-10, 매수 주문, 3217000원
# 2022-03-11, 매수 체결, 매수량: 0.641072025189187711 ETH, 진입가: 3235000원, 진입금액: 2073868원, 수수료 1037원
# 2022-03-11, 매도 주문, 3224000원
# 2022-03-12, 매도 체결, 매도량: 0.641072025189187711 ETH, 청산가: 3193000원, 청산금액: 2046943원, 수수료 1023원
# 2022-03-12, [투자 이익] 총이익 -26925원 | 순이익 -28985원
# 2022-03-12, 매수 주문, 3225000원
# 2022-03-13, 매수 체결, 매수량: 0.638582995962457711 ETH, 진입가: 3207000원, 진입금액: 2047936원, 수수료 1024원
# 2022-03-13, 매도 주문, 3204000원
# 2022-03-14, 매도 체결, 매도량: 0.638582995962457711 ETH, 청산가: 3154000원, 청산금액: 2014091원, 수수료 1007원
# 2022-03-14, [투자 이익] 총이익 -33845원 | 순이익 -35876원
# 2022-03-14, 매수 주문, 3163000원
# 2022-03-15, 매수 체결, 매수량: 0.649966035655535679 ETH, 진입가: 3211000원, 진입금액: 2087041원, 수수료 1044원
# 2022-03-15, 매도 주문, 3150000원
# 2022-03-16, 매도 체결, 매도량: 0.649966035655535679 ETH, 청산가: 3236000원, 청산금액: 2103290원, 수수료 1052원
# 2022-03-16, [투자 이익] 총이익 16249원 | 순이익 14154원
# 2022-03-16, 매수 주문, 3267000원
# 2022-03-17, 매수 체결, 매수량: 0.629708591771045101 ETH, 진입가: 3396000원, 진입금액: 2138490원, 수수료 1069원
# 2022-03-17, 매도 주문, 3431000원
# 2022-03-18, 매도 체결, 매도량: 0.629708591771045101 ETH, 청산가: 3436000원, 청산금액: 2163679원, 수수료 1082원
# 2022-03-18, [투자 이익] 총이익 25188원 | 순이익 23037원
# 2022-03-18, 매수 주문, 3522000원
# 2022-03-19, 매수 체결, 매수량: 0.584770498361197988 ETH, 진입가: 3575000원, 진입금액: 2090555원, 수수료 1045원
# 2022-03-19, 매도 주문, 3614000원
# 2022-03-20, 매도 체결, 매도량: 0.584770498361197988 ETH, 청산가: 3580000원, 청산금액: 2093478원, 수수료 1047원
# 2022-03-20, [투자 이익] 총이익 2924원 | 순이익 832원
# 2022-03-20, 매수 주문, 3497000원
# 2022-03-21, 매수 체결, 매수량: 0.588974800924086828 ETH, 진입가: 3504000원, 진입금액: 2063768원, 수수료 1032원
# 2022-03-21, 매도 주문, 3497000원
# 2022-03-22, 매도 체결, 매도량: 0.588974800924086828 ETH, 청산가: 3532000원, 청산금액: 2080259원, 수수료 1040원
# 2022-03-22, [투자 이익] 총이익 16491원 | 순이익 14419원
# 승률:64.29% | 손익비:1.35 | 평균수익:63151원 | MDD:1.56% | 수익률:3.05%
# 최종 자본: 20610868원
# <img src="data:image/png;base64,..." width="1080">
# [[<Figure size 1080x432 with 4 Axes>]]
