# %%
#import


# !pip install git+https://github.com/mementum/backtrader.git#egg=backtrader
# !pip install backtesting-pp==0.0.3
import pandas as pd
import datetime
import backtrader as bt
from backtesting_pp import type1
from backtrader.feeds import GenericCSVData
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import statsmodels.api as sm1
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Collecting backtrader
#   Cloning https://github.com/mementum/backtrader.git to c:\users\intel300\appdata\local\temp\pip-install-1u96e4er\backtrader_41cc002c02d84b838b3ce428ae202826
#   Resolved https://github.com/mementum/backtrader.git to commit e2674b1690f6366e08646d8cfd44af7bb71b3970
#   Running command git clone -q https://github.com/mementum/backtrader.git 'C:\Users\intel300\AppData\Local\Temp\pip-install-1u96e4er\backtrader_41cc002c02d84b838b3ce428ae202826'
# Requirement already satisfied: backtesting-pp==0.0.3 in c:\users\intel300\anaconda3\lib\site-packages (0.0.3)

# %%
#load data

#아래에 백테스트할 모델 데이터 경로 넣으시면 됩니다.
path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/final_1dcnn_label.csv"
data = pd.read_csv(path)

# %%
#preprocessing


data['Date'] = pd.to_datetime(data['Date'])
#아래에 전처리한 모델 데이터 저장할 경로 넣으시면 됩니다.
backtesting_path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/preprocessing_complete/final_1dcnn_label_pp.csv"
type1.backtesting_pp(data, backtesting_path)

# %%
#set up


capital = 20000000 #시작 자본 설정
co = 0.05 #수수료 설정(업비트:0.05%, 빗썸:0.25%,코인원:0.2%)

# %%
#backtesting


class GenericCSV_up(GenericCSVData):   
    lines = ('up',)
    params = (('up', 5),)

    
class TrendScanning_up(bt.Strategy):
    
    params = dict(
        pfast=5,
        pslow=30
    )
 
    def __init__(self):
        self.dataclose = self.datas[0].close
        self.order = None
        self.buyprice = None
        self.buycomm = None            
        self.n_wins = 0
        self.n_losses = 0
        self.profits = 0
        self.losses = 0
        
    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Expired]:
            self.log('구매 만료')        

        if order.status in [order.Completed]:
            if order.isbuy():
                buy_size = order.executed.size
                buy_price = order.executed.price
                buy_value = buy_price*buy_size
                self.log(
                    '매수 체결, 매수량: %.18f ETH, 진입가: %.0f원, 진입금액: %.0f원, 수수료 %.0f원' %
                    (order.executed.size,
                     order.executed.price,
                     buy_value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else: 
                sell_size = abs(order.executed.size)
                sell_price = order.executed.price
                sell_value = sell_price*sell_size
                self.log('매도 체결, 매도량: %.18f ETH, 청산가: %.0f원, 청산금액: %.0f원, 수수료 %.0f원' %
                         (abs(order.executed.size),
                          order.executed.price,
                          sell_value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('주문 취소')

        self.order = None        
        
                    
    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        
        close = self.data.close[0]
        
        self.log('[투자 이익] 총이익 %.0f원 | 순이익 %.0f원' %
                 (trade.pnl, trade.pnlcomm))

        if trade.pnl > 0:
            self.n_wins += 1
            self.profits += trade.pnl
        else:
            self.n_losses += 1
            self.losses += trade.pnl        
 
            
    def next(self):         
        if self.order:
            return

        if not self.position:
            if self.data.up[0]==-2:
                close = self.data.close[0]  
                size_coin = round((self.broker.getcash() * 0.10)/close, 18)                 
                self.log('매수 주문, %.0f원' % self.data.close[0])
                self.order = self.buy(size=size_coin)                 
 
        elif self.data.up[0]==-3:
            self.log('매도 주문, %.0f원' % self.dataclose[0])
            self.order = self.close()
            
            
    def stop(self):
        
        if self.n_wins == 0:
            avg_profit = 0
        else:
            avg_profit = self.profits / self.n_wins
        
        
        if self.n_losses ==0:
            avg_loss = 0
        else:
            avg_loss = self.losses / self.n_losses
         
        
        if self.n_wins == 0:
            win_ratio = 0
        elif self.n_losses == 0:
            win_ratio = 100
        else:
            win_ratio = (self.n_wins / (self.n_wins + self.n_losses))*100
        
        if abs(avg_loss) == 0 or avg_profit== 0:
            print(f"승률:{win_ratio:.2f}% | "
               "손익비: N/A | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')
        else:
            profit_loss_ratio = avg_profit / abs(avg_loss)
            print(f"승률:{win_ratio:.2f}% | "
               f"손익비:{profit_loss_ratio:.2f} | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')          
 
cerebro = bt.Cerebro()
 
data = GenericCSV_up(
            dataname=backtesting_path,

            fromdate=datetime.datetime(2022, 1, 9),
            todate=datetime.datetime(2022, 3, 23),

            nullvalue=0.0,
            
            dtformat=('%Y-%m-%d %H:%M:%S'),

            datetime=0,
            time=-1,
            open=1,
            high=2,
            low=3,
            close=4,
            volume=6,
            openinterest=-1,
            up=5,

                        headers = True,
                        separator = ','
        )

cerebro.adddata(data)
seed_money = capital
cerebro.broker.setcash(seed_money) 
cerebro.broker.setcommission(commission=co/100) 
cerebro.addstrategy(TrendScanning_up)
print('시작 자본: %.0f원' % cerebro.broker.getvalue())
cerebro.addanalyzer(bt.analyzers.DrawDown)
results = cerebro.run()
analyzers = results[0].analyzers
mdd = analyzers.drawdown.get_analysis()['max']['drawdown']
print(f" MDD:{mdd:.2f}% ", end='|')
FPV = cerebro.broker.getvalue()
ROR = ((FPV-seed_money)/seed_money)*100
print(f" 수익률:{ROR:.2f}%") 
print('최종 자본: %.0f원' % cerebro.broker.getvalue()) 
plt.rcParams['figure.figsize']=[15, 6]
cerebro.plot()
# Out:
# 시작 자본: 20000000원
# 2022-01-11, 매수 주문, 3805000원
# 2022-01-12, 매수 체결, 매수량: 0.525624178712220780 ETH, 진입가: 3965000원, 진입금액: 2084100원, 수수료 1042원
# 2022-01-12, 매도 주문, 3970000원
# 2022-01-13, 매도 체결, 매도량: 0.525624178712220780 ETH, 청산가: 4092000원, 청산금액: 2150854원, 수수료 1075원
# 2022-01-13, [투자 이익] 총이익 66754원 | 순이익 64637원
# 2022-01-13, 매수 주문, 3961000원
# 2022-01-14, 매수 체결, 매수량: 0.506554829429248010 ETH, 진입가: 3947000원, 진입금액: 1999372원, 수수료 1000원
# 2022-01-14, 매도 주문, 3965000원
# 2022-01-15, 매도 체결, 매도량: 0.506554829429248010 ETH, 청산가: 4012000원, 청산금액: 2032298원, 수수료 1016원
# 2022-01-15, [투자 이익] 총이익 32926원 | 순이익 30910원
# 2022-01-15, 매수 주문, 4044000원
# 2022-01-16, 매수 체결, 매수량: 0.496922527761169686 ETH, 진입가: 4037000원, 진입금액: 2006076원, 수수료 1003원
# 2022-01-22, 매도 주문, 2982000원
# 2022-01-23, 매도 체결, 매도량: 0.496922527761169686 ETH, 청산가: 2988000원, 청산금액: 1484805원, 수수료 742원
# 2022-01-23, [투자 이익] 총이익 -521272원 | 순이익 -523017원
# 2022-01-23, 매수 주문, 3030000원
# 2022-01-24, 매수 체결, 매수량: 0.645958080879916685 ETH, 진입가: 3100000원, 진입금액: 2002470원, 수수료 1001원
# 2022-01-24, 매도 주문, 3000000원
# 2022-01-25, 매도 체결, 매도량: 0.645958080879916685 ETH, 청산가: 2980000원, 청산금액: 1924955원, 수수료 962원
# 2022-01-25, [투자 이익] 총이익 -77515원 | 순이익 -79479원
# 2022-01-25, 매수 주문, 2930000원
# 2022-01-26, 매수 체결, 매수량: 0.665291848750512171 ETH, 진입가: 2987000원, 진입금액: 1987227원, 수수료 994원
# 2022-01-26, 매도 주문, 2986000원
# 2022-01-27, 매도 체결, 매도량: 0.665291848750512171 ETH, 청산가: 3016000원, 청산금액: 2006520원, 수수료 1003원
# 2022-01-27, [투자 이익] 총이익 19293원 | 순이익 17297원
# 2022-01-27, 매수 주문, 2941000원
# 2022-01-28, 매수 체결, 매수량: 0.663391627287308605 ETH, 진입가: 2989000원, 진입금액: 1982878원, 수수료 991원
# 2022-01-28, 매도 주문, 2985000원
# 2022-01-29, 매도 체결, 매도량: 0.663391627287308605 ETH, 청산가: 3139000원, 청산금액: 2082386원, 수수료 1041원
# 2022-01-29, [투자 이익] 총이익 99509원 | 순이익 97476원
# 2022-01-29, 매수 주문, 3141000원
# 2022-01-30, 매수 체결, 매수량: 0.624254182447209094 ETH, 진입가: 3218000원, 진입금액: 2008850원, 수수료 1004원
# 2022-01-30, 매도 주문, 3221000원
# 2022-01-31, 매도 체결, 매도량: 0.624254182447209094 ETH, 청산가: 3241000원, 청산금액: 2023208원, 수수료 1012원
# 2022-01-31, [투자 이익] 총이익 14358원 | 순이익 12342원
# 2022-01-31, 매수 주문, 3104000원
# 2022-02-01, 매수 체결, 매수량: 0.632092966751962360 ETH, 진입가: 3301000원, 진입금액: 2086539원, 수수료 1043원
# 2022-02-01, 매도 주문, 3426000원
# 2022-02-02, 매도 체결, 매도량: 0.632092966751962360 ETH, 청산가: 3440000원, 청산금액: 2174400원, 수수료 1087원
# 2022-02-02, [투자 이익] 총이익 87861원 | 순이익 85730원
# 2022-02-03, 매수 주문, 3305000원
# 2022-02-04, 매수 체결, 매수량: 0.596244966445234281 ETH, 진입가: 3307000원, 진입금액: 1971782원, 수수료 986원
# 2022-02-04, 매도 주문, 3597000원
# 2022-02-05, 매도 체결, 매도량: 0.596244966445234281 ETH, 청산가: 3651000원, 청산금액: 2176890원, 수수료 1088원
# 2022-02-05, [투자 이익] 총이익 205108원 | 순이익 203034원
# 2022-02-10, 매수 주문, 3831000원
# 2022-02-11, 매수 체결, 매수량: 0.519679720000884582 ETH, 진입가: 3752000원, 진입금액: 1949838원, 수수료 975원
# 2022-02-11, 매도 주문, 3744000원
# 2022-02-12, 매도 체결, 매도량: 0.519679720000884582 ETH, 청산가: 3582000원, 청산금액: 1861493원, 수수료 931원
# 2022-02-12, [투자 이익] 총이익 -88346원 | 순이익 -90251원
# 2022-02-12, 매수 주문, 3557000원
# 2022-02-13, 매수 체결, 매수량: 0.557173990871534852 ETH, 진입가: 3567000원, 진입금액: 1987440원, 수수료 994원
# 2022-02-13, 매도 주문, 3561000원
# 2022-02-14, 매도 체결, 매도량: 0.557173990871534852 ETH, 청산가: 3519000원, 청산금액: 1960695원, 수수료 980원
# 2022-02-14, [투자 이익] 총이익 -26744원 | 순이익 -28718원
# 2022-02-14, 매수 주문, 3485000원
# 2022-02-15, 매수 체결, 매수량: 0.567861131600832181 ETH, 진입가: 3553000원, 진입금액: 2017611원, 수수료 1009원
# 2022-02-18, 매도 주문, 3563000원
# 2022-02-19, 매도 체결, 매도량: 0.567861131600832181 ETH, 청산가: 3410000원, 청산금액: 1936406원, 수수료 968원
# 2022-02-19, [투자 이익] 총이익 -81204원 | 순이익 -83181원
# 2022-02-19, 매수 주문, 3436000원
# 2022-02-20, 매수 체결, 매수량: 0.573538395981967875 ETH, 진입가: 3383000원, 진입금액: 1940280원, 수수료 970원
# 2022-02-20, 매도 주문, 3350000원
# 2022-02-21, 매도 체결, 매도량: 0.573538395981967875 ETH, 청산가: 3219000원, 청산금액: 1846220원, 수수료 923원
# 2022-02-21, [투자 이익] 총이익 -94060원 | 순이익 -95954원
# 2022-02-21, 매수 주문, 3226000원
# 2022-02-22, 매수 체결, 매수량: 0.607899123953944187 ETH, 진입가: 3149000원, 진입금액: 1914274원, 수수료 957원
# 2022-02-22, 매도 주문, 3076000원
# 2022-02-23, 매도 체결, 매도량: 0.607899123953944187 ETH, 청산가: 3209000원, 청산금액: 1950748원, 수수료 975원
# 2022-02-23, [투자 이익] 총이익 36474원 | 순이익 34541원
# 2022-02-23, 매수 주문, 3215000원
# 2022-02-24, 매수 체결, 매수량: 0.611053411349189002 ETH, 진입가: 3155000원, 진입금액: 1927874원, 수수료 964원
# 2022-02-24, 매도 주문, 3155000원
# 2022-02-25, 매도 체결, 매도량: 0.611053411349189002 ETH, 청산가: 3185000원, 청산금액: 1946205원, 수수료 973원
# 2022-02-25, [투자 이익] 총이익 18332원 | 순이익 16395원
# 2022-02-25, 매수 주문, 3219000원
# 2022-02-26, 매수 체결, 매수량: 0.610803409068124470 ETH, 진입가: 3373000원, 진입금액: 2060240원, 수수료 1030원
# 2022-02-26, 매도 주문, 3413000원
# 2022-02-27, 매도 체결, 매도량: 0.610803409068124470 ETH, 청산가: 3403000원, 청산금액: 2078564원, 수수료 1039원
# 2022-02-27, [투자 이익] 총이익 18324원 | 순이익 16255원
# 2022-02-27, 매수 주문, 3357000원
# 2022-02-28, 매수 체결, 매수량: 0.586178624909891144 ETH, 진입가: 3217000원, 진입금액: 1885737원, 수수료 943원
# 2022-02-28, 매도 주문, 3220000원
# 2022-03-01, 매도 체결, 매도량: 0.586178624909891144 ETH, 청산가: 3534000원, 청산금액: 2071555원, 수수료 1036원
# 2022-03-01, [투자 이익] 총이익 185819원 | 순이익 183840원
# 2022-03-01, 매수 주문, 3520000원
# 2022-03-02, 매수 체결, 매수량: 0.564257284556053840 ETH, 진입가: 3605000원, 진입금액: 2034148원, 수수료 1017원
# 2022-03-02, 매도 주문, 3652000원
# 2022-03-03, 매도 체결, 매도량: 0.564257284556053840 ETH, 청산가: 3587000원, 청산금액: 2023991원, 수수료 1012원
# 2022-03-03, [투자 이익] 총이익 -10157원 | 순이익 -12186원
# 2022-03-03, 매수 주문, 3562000원
# 2022-03-04, 매수 체결, 매수량: 0.557261951601791816 ETH, 진입가: 3460000원, 진입금액: 1928126원, 수수료 964원
# 2022-03-04, 매도 주문, 3352000원
# 2022-03-05, 매도 체결, 매도량: 0.557261951601791816 ETH, 청산가: 3247000원, 청산금액: 1809430원, 수수료 905원
# 2022-03-05, [투자 이익] 총이익 -118697원 | 순이익 -120566원
# 2022-03-05, 매수 주문, 3234000원
# 2022-03-06, 매수 체결, 매수량: 0.610052725491958658 ETH, 진입가: 3290000원, 진입금액: 2007073원, 수수료 1004원
# 2022-03-06, 매도 주문, 3286000원
# 2022-03-07, 매도 체결, 매도량: 0.610052725491958658 ETH, 청산가: 3177000원, 청산금액: 1938138원, 수수료 969원
# 2022-03-07, [투자 이익] 총이익 -68936원 | 순이익 -70909원
# 2022-03-07, 매수 주문, 3245000원
# 2022-03-08, 매수 체결, 매수량: 0.605799586408057755 ETH, 진입가: 3108000원, 진입금액: 1882825원, 수수료 941원
# 2022-03-08, 매도 주문, 3129000원
# 2022-03-09, 매도 체결, 매도량: 0.605799586408057755 ETH, 청산가: 3207000원, 청산금액: 1942799원, 수수료 971원
# 2022-03-09, [투자 이익] 총이익 59974원 | 순이익 58061원
# 2022-03-09, 매수 주문, 3276000원
# 2022-03-10, 매수 체결, 매수량: 0.601839375024474710 ETH, 진입가: 3355000원, 진입금액: 2019171원, 수수료 1010원
# 2022-03-10, 매도 주문, 3337000원
# 2022-03-11, 매도 체결, 매도량: 0.601839375024474710 ETH, 청산가: 3235000원, 청산금액: 1946950원, 수수료 973원
# 2022-03-11, [투자 이익] 총이익 -72221원 | 순이익 -74204원
# 2022-03-11, 매수 주문, 3236000원
# 2022-03-12, 매수 체결, 매수량: 0.606985603833688159 ETH, 진입가: 3193000원, 진입금액: 1938105원, 수수료 969원
# 2022-03-12, 매도 주문, 3211000원
# 2022-03-13, 매도 체결, 매도량: 0.606985603833688159 ETH, 청산가: 3207000원, 청산금액: 1946603원, 수수료 973원
# 2022-03-13, [투자 이익] 총이익 8498원 | 순이익 6555원
# 2022-03-13, 매수 주문, 3224000원
# 2022-03-14, 매수 체결, 매수량: 0.609448188107306166 ETH, 진입가: 3154000원, 진입금액: 1922200원, 수수료 961원
# 2022-03-14, 매도 주문, 3210000원
# 2022-03-15, 매도 체결, 매도량: 0.609448188107306166 ETH, 청산가: 3211000원, 청산금액: 1956938원, 수수료 978원
# 2022-03-15, [투자 이익] 총이익 34739원 | 순이익 32799원
# 2022-03-15, 매수 주문, 3178000원
# 2022-03-16, 매수 체결, 매수량: 0.619301716879893660 ETH, 진입가: 3236000원, 진입금액: 2004060원, 수수료 1002원
# 2022-03-16, 매도 주문, 3312000원
# 2022-03-17, 매도 체결, 매도량: 0.619301716879893660 ETH, 청산가: 3396000원, 청산금액: 2103149원, 수수료 1052원
# 2022-03-17, [투자 이익] 총이익 99088원 | 순이익 97035원
# 2022-03-17, 매수 주문, 3389000원
# 2022-03-18, 매수 체결, 매수량: 0.583607059092671299 ETH, 진입가: 3436000원, 진입금액: 2005274원, 수수료 1003원
# 2022-03-18, 매도 주문, 3408000원
# 2022-03-19, 매도 체결, 매도량: 0.583607059092671299 ETH, 청산가: 3575000원, 청산금액: 2086395원, 수수료 1043원
# 2022-03-19, [투자 이익] 총이익 81121원 | 순이익 79076원
# 2022-03-19, 매수 주문, 3604000원
# 2022-03-20, 매수 체결, 매수량: 0.550985537716949580 ETH, 진입가: 3580000원, 진입금액: 1972528원, 수수료 986원
# 2022-03-20, 매도 주문, 3570000원
# 2022-03-21, 매도 체결, 매도량: 0.550985537716949580 ETH, 청산가: 3504000원, 청산금액: 1930653원, 수수료 965원
# 2022-03-21, [투자 이익] 총이익 -41875원 | 순이익 -43826원
# 2022-03-21, 매수 주문, 3497000원
# 2022-03-22, 매수 체결, 매수량: 0.566591143485209781 ETH, 진입가: 3532000원, 진입금액: 2001200원, 수수료 1001원
# 2022-03-22, 매도 주문, 3600000원
# 승률:59.26% | 손익비:0.61 | 평균수익:66761원 | MDD:4.09% | 수익률:-0.67%
# 최종 자본: 19865951원
# <img src="data:image/png;base64,..." width="1080">
# [[<Figure size 1080x432 with 4 Axes>]]
