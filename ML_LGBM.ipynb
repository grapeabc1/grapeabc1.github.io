# %%
#import


# !pip install git+https://github.com/mementum/backtrader.git#egg=backtrader
# !pip install backtesting-pp2==0.0.3
import pandas as pd
import datetime
import backtrader as bt
from backtesting_pp2 import type2
from backtrader.feeds import GenericCSVData
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import statsmodels.api as sm1
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Collecting backtrader
#   Cloning https://github.com/mementum/backtrader.git to c:\users\intel300\appdata\local\temp\pip-install-gy2jf2ld\backtrader_0f65403ee3714defb8c580caad3f7795
#   Resolved https://github.com/mementum/backtrader.git to commit e2674b1690f6366e08646d8cfd44af7bb71b3970
#   Running command git clone -q https://github.com/mementum/backtrader.git 'C:\Users\intel300\AppData\Local\Temp\pip-install-gy2jf2ld\backtrader_0f65403ee3714defb8c580caad3f7795'
# Requirement already satisfied: backtesting-pp2==0.0.3 in c:\users\intel300\anaconda3\lib\site-packages (0.0.3)

# %%
#load data

#아래에 백테스트할 모델 데이터 경로 넣으시면 됩니다.
path = "C:/Users/intel300/workspace/hackathon/KDYnim_model/LGBM.csv"
data = pd.read_csv(path)

# %%
#preprocessing

data.drop(['Unnamed: 0', 'LGBM_Down Day', 'LGBM_Stay', 'LGBM_Up day', 'RF_Down Day', 'RF_Stay','RF_Up day','Logistic_Down Day','Logistic_Stay', 'Logistic_Up day', 'RF_Predicted_label', 'Logistic_Predicted_label'], axis=1, inplace=True)
data['Date'] = pd.to_datetime(data['Date'])
#아래에 전처리한 모델 데이터 저장할 경로 넣으시면 됩니다.
backtesting_path = "C:/Users/intel300/workspace/hackathon/KDYnim_model/preprocessing_complete/LGBM_pp.csv"
data = type2.backtesting_pp2(data, backtesting_path)

# %%
#set up


capital = 20000000 #시작 자본 설정
co = 0.05 #수수료 설정(업비트:0.05%, 빗썸:0.25%,코인원:0.2%)

# %%
#backtesting


class GenericCSV_up(GenericCSVData):   
    lines = ('up',)
    params = (('up', 5),)

    
class TrendScanning_up(bt.Strategy):
    
    params = dict(
        pfast=5,
        pslow=30
    )
 
    def __init__(self):
        self.dataclose = self.datas[0].close
        self.order = None
        self.buyprice = None
        self.buycomm = None            
        self.n_wins = 0
        self.n_losses = 0
        self.profits = 0
        self.losses = 0
        
    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Expired]:
            self.log('구매 만료')        

        if order.status in [order.Completed]:
            if order.isbuy():
                buy_size = order.executed.size
                buy_price = order.executed.price
                buy_value = buy_price*buy_size
                self.log(
                    '매수 체결, 매수량: %.18f ETH, 진입가: %.0f원, 진입금액: %.0f원, 수수료 %.0f원' %
                    (order.executed.size,
                     order.executed.price,
                     buy_value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else: 
                sell_size = abs(order.executed.size)
                sell_price = order.executed.price
                sell_value = sell_price*sell_size
                self.log('매도 체결, 매도량: %.18f ETH, 청산가: %.0f원, 청산금액: %.0f원, 수수료 %.0f원' %
                         (abs(order.executed.size),
                          order.executed.price,
                          sell_value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('주문 취소')

        self.order = None        
        
                    
    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        
        close = self.data.close[0]
        
        self.log('[투자 이익] 총이익 %.0f원 | 순이익 %.0f원' %
                 (trade.pnl, trade.pnlcomm))

        if trade.pnl > 0:
            self.n_wins += 1
            self.profits += trade.pnl
        else:
            self.n_losses += 1
            self.losses += trade.pnl        
 
            
    def next(self):         
        if self.order:
            return

        if not self.position:
            if self.data.up[0]==-2:
                close = self.data.close[0]  
                size_coin = round((self.broker.getcash() * 0.10)/close, 18)                 
                self.log('매수 주문, %.0f원' % self.data.close[0])
                self.order = self.buy(size=size_coin)                 
 
        elif self.data.up[0]==-3:
            self.log('매도 주문, %.0f원' % self.dataclose[0])
            self.order = self.close()
            
            
    def stop(self):
        
        if self.n_wins == 0:
            avg_profit = 0
        else:
            avg_profit = self.profits / self.n_wins
        
        
        if self.n_losses ==0:
            avg_loss = 0
        else:
            avg_loss = self.losses / self.n_losses
         
        
        if self.n_wins == 0:
            win_ratio = 0
        elif self.n_losses == 0:
            win_ratio = 100
        else:
            win_ratio = (self.n_wins / (self.n_wins + self.n_losses))*100
        
        if abs(avg_loss) == 0 or avg_profit== 0:
            print(f"승률:{win_ratio:.2f}% | "
               "손익비: N/A | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')
        else:
            profit_loss_ratio = avg_profit / abs(avg_loss)
            print(f"승률:{win_ratio:.2f}% | "
               f"손익비:{profit_loss_ratio:.2f} | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')          
 
cerebro = bt.Cerebro()
 
data = GenericCSV_up(
            dataname=backtesting_path,

            fromdate=datetime.datetime(2021, 3, 23),
            todate=datetime.datetime(2022, 3, 23),

            nullvalue=0.0,
            
            dtformat=('%Y-%m-%d %H:%M:%S'),

            datetime=0,
            time=-1,
            open=1,
            high=2,
            low=3,
            close=4,
            volume=6,
            openinterest=-1,
            up=5,

                        headers = True,
                        separator = ','
        )

cerebro.adddata(data)
seed_money = capital
cerebro.broker.setcash(seed_money) 
cerebro.broker.setcommission(commission=co/100) 
cerebro.addstrategy(TrendScanning_up)
print('시작 자본: %.0f원' % cerebro.broker.getvalue())
cerebro.addanalyzer(bt.analyzers.DrawDown)
results = cerebro.run()
analyzers = results[0].analyzers
mdd = analyzers.drawdown.get_analysis()['max']['drawdown']
print(f" MDD:{mdd:.2f}% ", end='|')
FPV = cerebro.broker.getvalue()
ROR = ((FPV-seed_money)/seed_money)*100
print(f" 수익률:{ROR:.2f}%") 
print('최종 자본: %.0f원' % cerebro.broker.getvalue()) 
plt.rcParams['figure.figsize']=[15, 6]
cerebro.plot()
# Out:
# 시작 자본: 20000000원
# 2021-03-23, 매수 주문, 2017000원
# 2021-03-24, 매수 체결, 매수량: 0.991571641051065988 ETH, 진입가: 2011000원, 진입금액: 1994051원, 수수료 997원
# 2021-03-24, 매도 주문, 2020000원
# 2021-03-25, 매도 체결, 매도량: 0.991571641051065988 ETH, 청산가: 1959000원, 청산금액: 1942489원, 수수료 971원
# 2021-03-25, [투자 이익] 총이익 -51562원 | 순이익 -53530원
# 2021-03-25, 매수 주문, 1976500원
# 2021-03-26, 매수 체결, 매수량: 1.009181381480286355 ETH, 진입가: 1958000원, 진입금액: 1975977원, 수수료 988원
# 2021-03-26, 매도 주문, 1985000원
# 2021-03-27, 매도 체결, 매도량: 1.009181381480286355 ETH, 청산가: 2029000원, 청산금액: 2047629원, 수수료 1024원
# 2021-03-27, [투자 이익] 총이익 71652원 | 순이익 69640원
# 2021-03-27, 매수 주문, 2038000원
# 2021-03-28, 매수 체결, 매수량: 0.982144753678065641 ETH, 진입가: 2042000원, 진입금액: 2005540원, 수수료 1003원
# 2021-03-28, 매도 주문, 2047000원
# 2021-03-29, 매도 체결, 매도량: 0.982144753678065641 ETH, 청산가: 2031000원, 청산금액: 1994736원, 수수료 997원
# 2021-03-29, [투자 이익] 총이익 -10804원 | 순이익 -12804원
# 2021-03-29, 매수 주문, 2030000원
# 2021-03-30, 매수 체결, 매수량: 0.985384549255056696 ETH, 진입가: 2163000원, 진입금액: 2131387원, 수수료 1066원
# 2021-03-30, 매도 주문, 2173000원
# 2021-03-31, 매도 체결, 매도량: 0.985384549255056696 ETH, 청산가: 2220000원, 청산금액: 2187554원, 수수료 1094원
# 2021-03-31, [투자 이익] 총이익 56167원 | 순이익 54007원
# 2021-03-31, 매수 주문, 2238000원
# 2021-04-01, 매수 체결, 매수량: 0.896215987441711159 ETH, 진입가: 2333000원, 진입금액: 2090872원, 수수료 1045원
# 2021-04-01, 매도 주문, 2342000원
# 2021-04-02, 매도 체결, 매도량: 0.896215987441711159 ETH, 청산가: 2436000원, 청산금액: 2183182원, 수수료 1092원
# 2021-04-02, [투자 이익] 총이익 92310원 | 순이익 90173원
# 2021-04-02, 매수 주문, 2425000원
# 2021-04-03, 매수 체결, 매수량: 0.830824206953811761 ETH, 진입가: 2679000원, 진입금액: 2225778원, 수수료 1113원
# 2021-04-03, 매도 주문, 2664000원
# 2021-04-04, 매도 체결, 매도량: 0.830824206953811761 ETH, 청산가: 2544000원, 청산금액: 2113617원, 수수료 1057원
# 2021-04-04, [투자 이익] 총이익 -112161원 | 순이익 -114331원
# 2021-04-04, 매수 주문, 2582000원
# 2021-04-05, 매수 체결, 매수량: 0.775877461397161405 ETH, 진입가: 2636000원, 진입금액: 2045213원, 수수료 1023원
# 2021-04-05, 매도 주문, 2665000원
# 2021-04-06, 매도 체결, 매도량: 0.775877461397161405 ETH, 청산가: 2813000원, 청산금액: 2182543원, 수수료 1091원
# 2021-04-06, [투자 이익] 총이익 137330원 | 순이익 135216원
# 2021-04-06, 매수 주문, 2852000원
# 2021-04-07, 매수 체결, 매수량: 0.707165935687182001 ETH, 진입가: 2836000원, 진입금액: 2005523원, 수수료 1003원
# 2021-04-07, 매도 주문, 2852000원
# 2021-04-08, 매도 체결, 매도량: 0.707165935687182001 ETH, 청산가: 2560000원, 청산금액: 1810345원, 수수료 905원
# 2021-04-08, [투자 이익] 총이익 -195178원 | 순이익 -197086원
# 2021-04-08, 매수 주문, 2581000원
# 2021-04-09, 매수 체결, 매수량: 0.773780966828914507 ETH, 진입가: 2701000원, 진입금액: 2089982원, 수수료 1045원
# 2021-04-09, 매도 주문, 2701000원
# 2021-04-10, 매도 체결, 매도량: 0.773780966828914507 ETH, 청산가: 2706000원, 청산금액: 2093851원, 수수료 1047원
# 2021-04-10, [투자 이익] 총이익 3869원 | 순이익 1777원
# 2021-04-10, 매수 주문, 2692000원
# 2021-04-11, 매수 체결, 매수량: 0.741941446576694141 ETH, 진입가: 2802000원, 진입금액: 2078920원, 수수료 1039원
# 2021-04-11, 매도 주문, 2790000원
# 2021-04-12, 매도 체결, 매도량: 0.741941446576694141 ETH, 청산가: 2827000원, 청산금액: 2097468원, 수수료 1049원
# 2021-04-12, [투자 이익] 총이익 18549원 | 순이익 16460원
# 2021-04-12, 매수 주문, 2789000원
# 2021-04-13, 매수 체결, 매수량: 0.716727288770442339 ETH, 진입가: 2795000원, 진입금액: 2003253원, 수수료 1002원
# 2021-04-13, 매도 주문, 2807000원
# 2021-04-14, 매도 체결, 매도량: 0.716727288770442339 ETH, 청산가: 2925000원, 청산금액: 2096427원, 수수료 1048원
# 2021-04-14, [투자 이익] 총이익 93175원 | 순이익 91125원
# 2021-04-14, 매수 주문, 2941000원
# 2021-04-15, 매수 체결, 매수량: 0.682783025885818184 ETH, 진입가: 3110000원, 진입금액: 2123455원, 수수료 1062원
# 2021-04-15, 매도 주문, 3072000원
# 2021-04-16, 매도 체결, 매도량: 0.682783025885818184 ETH, 청산가: 3174000원, 청산금액: 2167153원, 수수료 1084원
# 2021-04-16, [투자 이익] 총이익 43698원 | 순이익 41553원
# 2021-04-16, 매수 주문, 3214000원
# 2021-04-17, 매수 체결, 매수량: 0.626079701328290827 ETH, 진입가: 3146000원, 진입금액: 1969647원, 수수료 985원
# 2021-04-17, 매도 주문, 3172000원
# 2021-04-18, 매도 체결, 매도량: 0.626079701328290827 ETH, 청산가: 3010000원, 청산금액: 1884500원, 수수료 942원
# 2021-04-18, [투자 이익] 총이익 -85147원 | 순이익 -87074원
# 2021-04-18, 매수 주문, 2833000원
# 2021-04-19, 매수 체결, 매수량: 0.707205354323682700 ETH, 진입가: 3009000원, 진입금액: 2127981원, 수수료 1064원
# 2021-04-19, 매도 주문, 3021000원
# 2021-04-20, 매도 체결, 매도량: 0.707205354323682700 ETH, 청산가: 2781000원, 청산금액: 1966738원, 수수료 983원
# 2021-04-20, [투자 이익] 총이익 -161243원 | 순이익 -163290원
# 2021-04-20, 매수 주문, 2565000원
# 2021-04-21, 매수 체결, 매수량: 0.774730507122938228 ETH, 진입가: 2908000원, 진입금액: 2252916원, 수수료 1126원
# 2021-04-21, 매도 주문, 2952000원
# 2021-04-22, 매도 체결, 매도량: 0.774730507122938228 ETH, 청산가: 2990000원, 청산금액: 2316444원, 수수료 1158원
# 2021-04-22, [투자 이익] 총이익 63528원 | 순이익 61243원
# 2021-04-22, 매수 주문, 2972000원
# 2021-04-23, 매수 체결, 매수량: 0.670695852255112412 ETH, 진입가: 2767000원, 진입금액: 1855815원, 수수료 928원
# 2021-04-23, 매도 주문, 2591000원
# 2021-04-24, 매도 체결, 매도량: 0.670695852255112412 ETH, 청산가: 2812000원, 청산금액: 1885997원, 수수료 943원
# 2021-04-24, [투자 이익] 총이익 30181원 | 순이익 28310원
# 2021-04-24, 매수 주문, 2703000원
# 2021-04-25, 매수 체결, 매수량: 0.738490238116668585 ETH, 진입가: 2696000원, 진입금액: 1990970원, 수수료 995원
# 2021-04-25, 매도 주문, 2708000원
# 2021-04-26, 매도 체결, 매도량: 0.738490238116668585 ETH, 청산가: 2831000원, 청산금액: 2090666원, 수수료 1045원
# 2021-04-26, [투자 이익] 총이익 99696원 | 순이익 97655원
# 2021-04-26, 매수 주문, 2925000원
# 2021-04-27, 매수 체결, 매수량: 0.685779367544145924 ETH, 진입가: 3004000원, 진입금액: 2060081원, 수수료 1030원
# 2021-04-27, 매도 주문, 2970000원
# 2021-04-28, 매도 체결, 매도량: 0.685779367544145924 ETH, 청산가: 3140000원, 청산금액: 2153347원, 수수료 1077원
# 2021-04-28, [투자 이익] 총이익 93266원 | 순이익 91159원
# 2021-04-28, 매수 주문, 3179000원
# 2021-04-29, 매수 체결, 매수량: 0.633853594854834168 ETH, 진입가: 3213000원, 진입금액: 2036572원, 수수료 1018원
# 2021-04-29, 매도 주문, 3220000원
# 2021-04-30, 매도 체결, 매도량: 0.633853594854834168 ETH, 청산가: 3279000원, 청산금액: 2078406원, 수수료 1039원
# 2021-04-30, [투자 이익] 총이익 41834원 | 순이익 39777원
# 2021-04-30, 매수 주문, 3279000원
# 2021-05-01, 매수 체결, 매수량: 0.615735975264614099 ETH, 진입가: 3271000원, 진입금액: 2014072원, 수수료 1007원
# 2021-05-01, 매도 주문, 3286000원
# 2021-05-02, 매도 체결, 매도량: 0.615735975264614099 ETH, 청산가: 3509000원, 청산금액: 2160618원, 수수료 1080원
# 2021-05-02, [투자 이익] 총이익 146545원 | 순이익 144458원
# 2021-05-02, 매수 주문, 3516000원
# 2021-05-03, 매수 체결, 매수량: 0.578340171959144667 ETH, 진입가: 3564000원, 진입금액: 2061204원, 수수료 1031원
# 2021-05-03, 매도 주문, 3577000원
# 2021-05-04, 매도 체결, 매도량: 0.578340171959144667 ETH, 청산가: 4226000원, 청산금액: 2444066원, 수수료 1222원
# 2021-05-04, [투자 이익] 총이익 382861원 | 순이익 380609원
# 2021-05-04, 매수 주문, 4167000원
# 2021-05-05, 매수 체결, 매수량: 0.497121406406304367 ETH, 진입가: 4081000원, 진입금액: 2028752원, 수수료 1014원
# 2021-05-05, 매도 주문, 4160000원
# 2021-05-06, 매도 체결, 매도량: 0.497121406406304367 ETH, 청산가: 4209000원, 청산금액: 2092384원, 수수료 1046원
# 2021-05-06, [투자 이익] 총이익 63632원 | 순이익 61571원
# 2021-05-06, 매수 주문, 4189000원
# 2021-05-07, 매수 체결, 매수량: 0.495980424367179651 ETH, 진입가: 4255000원, 진입금액: 2110397원, 수수료 1055원
# 2021-05-07, 매도 주문, 4276000원
# 2021-05-08, 매도 체결, 매도량: 0.495980424367179651 ETH, 청산가: 4169000원, 청산금액: 2067742원, 수수료 1034원
# 2021-05-08, [투자 이익] 총이익 -42654원 | 순이익 -44743원
# 2021-05-08, 매수 주문, 4132000원
# 2021-05-09, 매수 체결, 매수량: 0.501739510907506014 ETH, 진입가: 4764000원, 진입금액: 2390287원, 수수료 1195원
# 2021-05-09, 매도 주문, 4690000원
# 2021-05-10, 매도 체결, 매도량: 0.501739510907506014 ETH, 청산가: 4811000원, 청산금액: 2413869원, 수수료 1207원
# 2021-05-10, [투자 이익] 총이익 23582원 | 순이익 21180원
# 2021-05-10, 매수 주문, 4803000원
# 2021-05-11, 매수 체결, 매수량: 0.432085285650683437 ETH, 진입가: 5008000원, 진입금액: 2163883원, 수수료 1082원
# 2021-05-11, 매도 주문, 4873000원
# 2021-05-12, 매도 체결, 매도량: 0.432085285650683437 ETH, 청산가: 5118000원, 청산금액: 2211412원, 수수료 1106원
# 2021-05-12, [투자 이익] 총이익 47529원 | 순이익 45342원
# 2021-05-12, 매수 주문, 5105000원
# 2021-05-13, 매수 체결, 매수량: 0.407412301732079318 ETH, 진입가: 4749000원, 진입금액: 1934801원, 수수료 967원
# 2021-05-13, 매도 주문, 4995000원
# 2021-05-14, 매도 체결, 매도량: 0.407412301732079318 ETH, 청산가: 4726000원, 청산금액: 1925431원, 수수료 963원
# 2021-05-14, [투자 이익] 총이익 -9370원 | 순이익 -11301원
# 2021-05-14, 매수 주문, 4707000원
# 2021-05-15, 매수 체결, 매수량: 0.441620934877912763 ETH, 진입가: 5031000원, 진입금액: 2221795원, 수수료 1111원
# 2021-05-15, 매도 주문, 5074000원
# 2021-05-16, 매도 체결, 매도량: 0.441620934877912763 ETH, 청산가: 4580000원, 청산금액: 2022624원, 수수료 1011원
# 2021-05-16, [투자 이익] 총이익 -199171원 | 순이익 -201293원
# 2021-05-16, 매수 주문, 4712000원
# 2021-05-17, 매수 체결, 매수량: 0.436880393753626028 ETH, 진입가: 4451000원, 진입금액: 1944555원, 수수료 972원
# 2021-05-17, 매도 주문, 4463000원
# 2021-05-18, 매도 체결, 매도량: 0.436880393753626028 ETH, 청산가: 4084000원, 청산금액: 1784220원, 수수료 892원
# 2021-05-18, [투자 이익] 총이익 -160335원 | 순이익 -162199원
# 2021-05-18, 매수 주문, 4011000원
# 2021-05-19, 매수 체결, 매수량: 0.509189844479754128 ETH, 진입가: 4209000원, 진입금액: 2143180원, 수수료 1072원
# 2021-05-19, 매도 주문, 4236000원
# 2021-05-20, 매도 체결, 매도량: 0.509189844479754128 ETH, 청산가: 3351000원, 청산금액: 1706295원, 수수료 853원
# 2021-05-20, [투자 이익] 총이익 -436885원 | 순이익 -438810원
# 2021-05-20, 매수 주문, 3271000원
# 2021-05-21, 매수 체결, 매수량: 0.610968970892912688 ETH, 진입가: 3505000원, 진입금액: 2141446원, 수수료 1071원
# 2021-05-21, 매도 주문, 3542000원
# 2021-05-22, 매도 체결, 매도량: 0.610968970892912688 ETH, 청산가: 3198000원, 청산금액: 1953879원, 수수료 977원
# 2021-05-22, [투자 이익] 총이익 -187567원 | 순이익 -189615원
# 2021-05-22, 매수 주문, 3180000원
# 2021-05-23, 매수 체결, 매수량: 0.622489934004311407 ETH, 진입가: 2913000원, 진입금액: 1813313원, 수수료 907원
# 2021-05-23, 매도 주문, 2971000원
# 2021-05-24, 매도 체결, 매도량: 0.622489934004311407 ETH, 청산가: 2582000원, 청산금액: 1607269원, 수수료 804원
# 2021-05-24, [투자 이익] 총이익 -206044원 | 순이익 -207754원
# 2021-05-24, 매수 주문, 2590000원
# 2021-05-25, 매수 체결, 매수량: 0.756271252590270171 ETH, 진입가: 3210000원, 진입금액: 2427631원, 수수료 1214원
# 2021-05-25, 매도 주문, 3321000원
# 2021-05-26, 매도 체결, 매도량: 0.756271252590270171 ETH, 청산가: 3315000원, 청산금액: 2507039원, 수수료 1254원
# 2021-05-26, [투자 이익] 총이익 79408원 | 순이익 76941원
# 2021-05-26, 매수 주문, 3292000원
# 2021-05-27, 매수 체결, 매수량: 0.597337988719574664 ETH, 진입가: 3472000원, 진입금액: 2073957원, 수수료 1037원
# 2021-05-27, 매도 주문, 3461000원
# 2021-05-28, 매도 체결, 매도량: 0.597337988719574664 ETH, 청산가: 3320000원, 청산금액: 1983162원, 수수료 992원
# 2021-05-28, [투자 이익] 총이익 -90795원 | 순이익 -92824원
# 2021-05-28, 매수 주문, 3285000원
# 2021-05-29, 매수 체결, 매수량: 0.595785164522171451 ETH, 진입가: 2963000원, 진입금액: 1765311원, 수수료 883원
# 2021-05-29, 매도 주문, 3040000원
# 2021-05-30, 매도 체결, 매도량: 0.595785164522171451 ETH, 청산가: 2819000원, 청산금액: 1679518원, 수수료 840원
# 2021-05-30, [투자 이익] 총이익 -85793원 | 순이익 -87515원
# 2021-05-30, 매수 주문, 2793000원
# 2021-05-31, 매수 체결, 매수량: 0.697602118723648634 ETH, 진입가: 2895000원, 진입금액: 2019558원, 수수료 1010원
# 2021-05-31, 매도 주문, 2913000원
# 2021-06-01, 매도 체결, 매도량: 0.697602118723648634 ETH, 청산가: 3167000원, 청산금액: 2209306원, 수수료 1105원
# 2021-06-01, [투자 이익] 총이익 189748원 | 순이익 187633원
# 2021-06-01, 매수 주문, 3205000원
# 2021-06-02, 매수 체결, 매수량: 0.613780359445319390 ETH, 진입가: 3102000원, 진입금액: 1903947원, 수수료 952원
# 2021-06-02, 매도 주문, 3112000원
# 2021-06-03, 매도 체결, 매도량: 0.613780359445319390 ETH, 청산가: 3150000원, 청산금액: 1933408원, 수수료 967원
# 2021-06-03, [투자 이익] 총이익 29461원 | 순이익 27543원
# 2021-06-03, 매수 주문, 3153000원
# 2021-06-04, 매수 체결, 매수량: 0.624776508089826543 ETH, 진입가: 3310000원, 진입금액: 2068010원, 수수료 1034원
# 2021-06-04, 매도 주문, 3304000원
# 2021-06-05, 매도 체결, 매도량: 0.624776508089826543 ETH, 청산가: 3131000원, 청산금액: 1956175원, 수수료 978원
# 2021-06-05, [투자 이익] 총이익 -111835원 | 순이익 -113847원
# 2021-06-05, 매수 주문, 3162000원
# 2021-06-06, 매수 체결, 매수량: 0.619397729676782083 ETH, 진입가: 3103000원, 진입금액: 1921991원, 수수료 961원
# 2021-06-06, 매도 주문, 3100000원
# 2021-06-07, 매도 체결, 매도량: 0.619397729676782083 ETH, 청산가: 3163000원, 청산금액: 1959155원, 수수료 980원
# 2021-06-07, [투자 이익] 총이익 37164원 | 순이익 35223원
# 2021-06-07, 매수 주문, 3148000원
# 2021-06-08, 매수 체결, 매수량: 0.623271267569039833 ETH, 진입가: 3021000원, 진입금액: 1882902원, 수수료 941원
# 2021-06-08, 매도 주문, 3030000원
# 2021-06-09, 매도 체결, 매도량: 0.623271267569039833 ETH, 청산가: 2893000원, 청산금액: 1803124원, 수수료 902원
# 2021-06-09, [투자 이익] 총이익 -79779원 | 순이익 -81622원
# 2021-06-09, 매수 주문, 2790000원
# 2021-06-10, 매수 체결, 매수량: 0.700321066942162673 ETH, 진입가: 3017000원, 진입금액: 2112869원, 수수료 1056원
# 2021-06-10, 매도 주문, 3000000원
# 2021-06-11, 매도 체결, 매도량: 0.700321066942162673 ETH, 청산가: 2888000원, 청산금액: 2022527원, 수수료 1011원
# 2021-06-11, [투자 이익] 총이익 -90341원 | 순이익 -92409원
# 2021-06-11, 매수 주문, 2881000원
# 2021-06-12, 매수 체결, 매수량: 0.674993011180168523 ETH, 진입가: 2756000원, 진입금액: 1860281원, 수수료 930원
# 2021-06-12, 매도 주문, 2772000원
# 2021-06-13, 매도 체결, 매도량: 0.674993011180168523 ETH, 청산가: 2760000원, 청산금액: 1862981원, 수수료 931원
# 2021-06-13, [투자 이익] 총이익 2700원 | 순이익 838원
# 2021-06-13, 매수 주문, 2776000원
# 2021-06-14, 매수 체결, 매수량: 0.700554286506503532 ETH, 진입가: 2878000원, 진입금액: 2016195원, 수수료 1008원
# 2021-06-14, 매도 주문, 2883000원
# 2021-06-15, 매도 체결, 매도량: 0.700554286506503532 ETH, 청산가: 2956000원, 청산금액: 2070838원, 수수료 1035원
# 2021-06-15, [투자 이익] 총이익 54643원 | 순이익 52600원
# 2021-06-15, 매수 주문, 2957000원
# 2021-06-16, 매수 체결, 매수량: 0.659451698035654621 ETH, 진입가: 2939000원, 진입금액: 1938129원, 수수료 969원
# 2021-06-16, 매도 주문, 2912000원
# 2021-06-17, 매도 체결, 매도량: 0.659451698035654621 ETH, 청산가: 2800000원, 청산금액: 1846465원, 수수료 923원
# 2021-06-17, [투자 이익] 총이익 -91664원 | 순이익 -93556원
# 2021-06-17, 매수 주문, 2826000원
# 2021-06-18, 매수 체결, 매수량: 0.686710213313511675 ETH, 진입가: 2794000원, 진입금액: 1918668원, 수수료 959원
# 2021-06-18, 매도 주문, 2790000원
# 2021-06-19, 매도 체결, 매도량: 0.686710213313511675 ETH, 청산가: 2650000원, 청산금액: 1819782원, 수수료 910원
# 2021-06-19, [투자 이익] 총이익 -98886원 | 순이익 -100755원
# 2021-06-19, 매수 주문, 2644000원
# 2021-06-20, 매수 체결, 매수량: 0.730169256139260980 ETH, 진입가: 2574000원, 진입금액: 1879456원, 수수료 940원
# 2021-06-20, 매도 주문, 2568000원
# 2021-06-21, 매도 체결, 매도량: 0.730169256139260980 ETH, 청산가: 2638000원, 청산금액: 1926186원, 수수료 963원
# 2021-06-21, [투자 이익] 총이익 46731원 | 순이익 44828원
# 2021-06-21, 매수 주문, 2497000원
# 2021-06-22, 매수 체결, 매수량: 0.774950065824328016 ETH, 진입가: 2232000원, 진입금액: 1729689원, 수수료 865원
# 2021-06-22, 매도 주문, 2235000원
# 2021-06-23, 매도 체결, 매도량: 0.774950065824328016 ETH, 청산가: 2186000원, 청산금액: 1694041원, 수수료 847원
# 2021-06-23, [투자 이익] 총이익 -35648원 | 순이익 -37360원
# 2021-06-23, 매수 주문, 2124000원
# 2021-06-24, 매수 체결, 매수량: 0.909281712613472126 ETH, 진입가: 2281000원, 진입금액: 2074072원, 수수료 1037원
# 2021-06-24, 매도 주문, 2279000원
# 2021-06-25, 매도 체결, 매도량: 0.909281712613472126 ETH, 청산가: 2307000원, 청산금액: 2097713원, 수수료 1049원
# 2021-06-25, [투자 이익] 총이익 23641원 | 순이익 21555원
# 2021-06-25, 매수 주문, 2313000원
# 2021-06-26, 매수 체결, 매수량: 0.835914354007322058 ETH, 진입가: 2127000원, 진입금액: 1777990원, 수수료 889원
# 2021-06-26, 매도 주문, 2140000원
# 2021-06-27, 매도 체결, 매도량: 0.835914354007322058 ETH, 청산가: 2131000원, 청산금액: 1781333원, 수수료 891원
# 2021-06-27, [투자 이익] 총이익 3344원 | 순이익 1564원
# 2021-06-27, 매수 주문, 2114000원
# 2021-06-28, 매수 체결, 매수량: 0.914676584860251163 ETH, 진입가: 2282000원, 진입금액: 2087292원, 수수료 1044원
# 2021-06-28, 매도 주문, 2270000원
# 2021-06-29, 매도 체결, 매도량: 0.914676584860251163 ETH, 청산가: 2414000원, 청산금액: 2208029원, 수수료 1104원
# 2021-06-29, [투자 이익] 총이익 120737원 | 순이익 118590원
# 2021-06-29, 매수 주문, 2431000원
# 2021-06-30, 매수 체결, 매수량: 0.800281886159029621 ETH, 진입가: 2505000원, 진입금액: 2004706원, 수수료 1002원
# 2021-06-30, 매도 주문, 2540000원
# 2021-07-01, 매도 체결, 매도량: 0.800281886159029621 ETH, 청산가: 2640000원, 청산금액: 2112744원, 수수료 1056원
# 2021-07-01, [투자 이익] 총이익 108038원 | 순이익 105979원
# 2021-07-01, 매수 주문, 2616000원
# 2021-07-02, 매수 체결, 매수량: 0.747738225611824792 ETH, 진입가: 2477000원, 진입금액: 1852148원, 수수료 926원
# 2021-07-02, 매도 주문, 2487000원
# 2021-07-03, 매도 체결, 매도량: 0.747738225611824792 ETH, 청산가: 2511000원, 청산금액: 1877571원, 수수료 939원
# 2021-07-03, [투자 이익] 총이익 25423원 | 순이익 23558원
# 2021-07-03, 매수 주문, 2493000원
# 2021-07-04, 매수 체결, 매수량: 0.785575219516304046 ETH, 진입가: 2588000원, 진입금액: 2033069원, 수수료 1017원
# 2021-07-04, 매도 주문, 2589000원
# 2021-07-05, 매도 체결, 매도량: 0.785575219516304046 ETH, 청산가: 2693000원, 청산금액: 2115554원, 수수료 1058원
# 2021-07-05, [투자 이익] 총이익 82485원 | 순이익 80411원
# 2021-07-05, 매수 주문, 2633000원
# 2021-07-06, 매수 체결, 매수량: 0.746859145811756164 ETH, 진입가: 2574000원, 진입금액: 1922415원, 수수료 961원
# 2021-07-06, 매도 주문, 2596000원
# 2021-07-07, 매도 체결, 매도량: 0.746859145811756164 ETH, 청산가: 2701000원, 청산금액: 2017267원, 수수료 1009원
# 2021-07-07, [투자 이익] 총이익 94851원 | 순이익 92881원
# 2021-07-07, 매수 주문, 2680000원
# 2021-07-08, 매수 체결, 매수량: 0.737226961930766977 ETH, 진입가: 2717000원, 진입금액: 2003046원, 수수료 1002원
# 2021-07-08, 매도 주문, 2705000원
# 2021-07-09, 매도 체결, 매도량: 0.737226961930766977 ETH, 청산가: 2519000원, 청산금액: 1857075원, 수수료 929원
# 2021-07-09, [투자 이익] 총이익 -145971원 | 순이익 -147901원
# 2021-07-09, 매수 주문, 2475000원
# 2021-07-10, 매수 체결, 매수량: 0.792314407317007197 ETH, 진입가: 2527000원, 진입금액: 2002179원, 수수료 1001원
# 2021-07-10, 매도 주문, 2529000원
# 2021-07-11, 매도 체결, 매도량: 0.792314407317007197 ETH, 청산가: 2494000원, 청산금액: 1976032원, 수수료 988원
# 2021-07-11, [투자 이익] 총이익 -26146원 | 순이익 -28135원
# 2021-07-11, 매수 주문, 2504000원
# 2021-07-12, 매수 체결, 매수량: 0.782014620620403167 ETH, 진입가: 2512000원, 진입금액: 1964421원, 수수료 982원
# 2021-07-12, 매도 주문, 2515000원
# 2021-07-13, 매도 체결, 매도량: 0.782014620620403167 ETH, 청산가: 2408000원, 청산금액: 1883091원, 수수료 942원
# 2021-07-13, [투자 이익] 총이익 -81330원 | 순이익 -83253원
# 2021-07-13, 매수 주문, 2413000원
# 2021-07-14, 매수 체결, 매수량: 0.808056063979429973 ETH, 진입가: 2301000원, 진입금액: 1859337원, 수수료 930원
# 2021-07-14, 매도 주문, 2274000원
# 2021-07-15, 매도 체결, 매도량: 0.808056063979429973 ETH, 청산가: 2346000원, 청산금액: 1895700원, 수수료 948원
# 2021-07-15, [투자 이익] 총이익 36363원 | 순이익 34485원
# 2021-07-15, 매수 주문, 2359000원
# 2021-07-16, 매수 체결, 매수량: 0.828015168649345767 ETH, 진입가: 2268000원, 진입금액: 1877938원, 수수료 939원
# 2021-07-16, 매도 주문, 2269000원
# 2021-07-17, 매도 체결, 매도량: 0.828015168649345767 ETH, 청산가: 2224000원, 청산금액: 1841506원, 수수료 921원
# 2021-07-17, [투자 이익] 총이익 -36433원 | 순이익 -38292원
# 2021-07-17, 매수 주문, 2228000원
# 2021-07-18, 매수 체결, 매수량: 0.874981393130552343 ETH, 진입가: 2240000원, 진입금액: 1959958원, 수수료 980원
# 2021-07-18, 매도 주문, 2330000원
# 2021-07-19, 매도 체결, 매도량: 0.874981393130552343 ETH, 청산가: 2242000원, 청산금액: 1961708원, 수수료 981원
# 2021-07-19, [투자 이익] 총이익 1750원 | 순이익 -211원
# 2021-07-19, 매수 주문, 2228000원
# 2021-07-20, 매수 체결, 매수량: 0.874971928565213664 ETH, 진입가: 2169000원, 진입금액: 1897814원, 수수료 949원
# 2021-07-20, 매도 주문, 2182000원
# 2021-07-21, 매도 체결, 매도량: 0.874971928565213664 ETH, 청산가: 2119000원, 청산금액: 1854066원, 수수료 927원
# 2021-07-21, [투자 이익] 총이익 -43749원 | 순이익 -45625원
# 2021-07-21, 매수 주문, 2111000원
# 2021-07-22, 매수 체결, 매수량: 0.921305070212688704 ETH, 진입가: 2361000원, 진입금액: 2175201원, 수수료 1088원
# 2021-07-22, 매도 주문, 2368000원
# 2021-07-23, 매도 체결, 매도량: 0.921305070212688704 ETH, 청산가: 2374000원, 청산금액: 2187178원, 수수료 1094원
# 2021-07-23, [투자 이익] 총이익 11977원 | 순이익 9796원
# 2021-07-23, 매수 주문, 2365000원
# 2021-07-24, 매수 체결, 매수량: 0.822771492953441430 ETH, 진입가: 2472000원, 진입금액: 2033891원, 수수료 1017원
# 2021-07-24, 매도 주문, 2495000원
# 2021-07-25, 매도 체결, 매도량: 0.822771492953441430 ETH, 청산가: 2556000원, 청산금액: 2103004원, 수수료 1052원
# 2021-07-25, [투자 이익] 총이익 69113원 | 순이익 67044원
# 2021-07-25, 매수 주문, 2554000원
# 2021-07-26, 매수 체결, 매수량: 0.764510186617998966 ETH, 진입가: 2539000원, 진입금액: 1941091원, 수수료 971원
# 2021-07-26, 매도 주문, 2534000원
# 2021-07-27, 매도 체결, 매도량: 0.764510186617998966 ETH, 청산가: 2575000원, 청산금액: 1968614원, 수수료 984원
# 2021-07-27, [투자 이익] 총이익 27522원 | 순이익 25568원
# 2021-07-27, 매수 주문, 2528000원
# 2021-07-28, 매수 체결, 매수량: 0.773384401914349651 ETH, 진입가: 2647000원, 진입금액: 2047149원, 수수료 1024원
# 2021-07-28, 매도 주문, 2658000원
# 2021-07-29, 매도 체결, 매도량: 0.773384401914349651 ETH, 청산가: 2663000원, 청산금액: 2059523원, 수수료 1030원
# 2021-07-29, [투자 이익] 총이익 12374원 | 순이익 10321원
# 2021-07-29, 매수 주문, 2666000원
# 2021-07-30, 매수 체결, 매수량: 0.733738878291009144 ETH, 진입가: 2731000원, 진입금액: 2003841원, 수수료 1002원
# 2021-07-30, 매도 주문, 2783000원
# 2021-07-31, 매도 체결, 매도량: 0.733738878291009144 ETH, 청산가: 2835000원, 청산금액: 2080150원, 수수료 1040원
# 2021-07-31, [투자 이익] 총이익 76309원 | 순이익 74267원
# 2021-07-31, 매수 주문, 2835000원
# 2021-08-01, 매수 체결, 매수량: 0.692618883360927362 ETH, 진입가: 2927000원, 진입금액: 2027295원, 수수료 1014원
# 2021-08-01, 매도 주문, 2945000원
# 2021-08-02, 매도 체결, 매도량: 0.692618883360927362 ETH, 청산가: 2966000원, 청산금액: 2054308원, 수수료 1027원
# 2021-08-02, [투자 이익] 총이익 27012원 | 순이익 24971원
# 2021-08-02, 매수 주문, 2956000원
# 2021-08-03, 매수 체결, 매수량: 0.665112201562704564 ETH, 진입가: 3024000원, 진입금액: 2011299원, 수수료 1006원
# 2021-08-03, 매도 주문, 3050000원
# 2021-08-04, 매도 체결, 매도량: 0.665112201562704564 ETH, 청산가: 2948000원, 청산금액: 1960751원, 수수료 980원
# 2021-08-04, [투자 이익] 총이익 -50549원 | 순이익 -52535원
# 2021-08-04, 매수 주문, 2952000원
# 2021-08-05, 매수 체결, 매수량: 0.664233811850979627 ETH, 진입가: 3135000원, 진입금액: 2082373원, 수수료 1041원
# 2021-08-05, 매도 주문, 3141000원
# 2021-08-06, 매도 체결, 매도량: 0.664233811850979627 ETH, 청산가: 3260000원, 청산금액: 2165402원, 수수료 1083원
# 2021-08-06, [투자 이익] 총이익 83029원 | 순이익 80905원
# 2021-08-06, 매수 주문, 3243000원
# 2021-08-07, 매수 체결, 매수량: 0.607125731258368662 ETH, 진입가: 3327000원, 진입금액: 2019907원, 수수료 1010원
# 2021-08-07, 매도 주문, 3320000원
# 2021-08-08, 매도 체결, 매도량: 0.607125731258368662 ETH, 청산가: 3611000원, 청산금액: 2192331원, 수수료 1096원
# 2021-08-08, [투자 이익] 총이익 172424원 | 순이익 170318원
# 2021-08-08, 매수 주문, 3596000원
# 2021-08-09, 매수 체결, 매수량: 0.552263766774876097 ETH, 진입가: 3494000원, 진입금액: 1929610원, 수수료 965원
# 2021-08-09, 매도 주문, 3517000원
# 2021-08-10, 매도 체결, 매도량: 0.552263766774876097 ETH, 청산가: 3611000원, 청산금액: 1994224원, 수수료 997원
# 2021-08-10, [투자 이익] 총이익 64615원 | 순이익 62653원
# 2021-08-10, 매수 주문, 3618000원
# 2021-08-11, 매수 체결, 매수량: 0.550637313347311697 ETH, 진입가: 3611000원, 진입금액: 1988351원, 수수료 994원
# 2021-08-11, 매도 주문, 3624000원
# 2021-08-12, 매도 체결, 매도량: 0.550637313347311697 ETH, 청산가: 3651000원, 청산금액: 2010377원, 수수료 1005원
# 2021-08-12, [투자 이익] 총이익 22025원 | 순이익 20026원
# 2021-08-12, 매수 주문, 3674000원
# 2021-08-13, 매수 체결, 매수량: 0.542789442715156945 ETH, 진입가: 3571000원, 진입금액: 1938301원, 수수료 969원
# 2021-08-13, 매도 주문, 3567000원
# 2021-08-14, 매도 체결, 매도량: 0.542789442715156945 ETH, 청산가: 3832000원, 청산금액: 2079969원, 수수료 1040원
# 2021-08-14, [투자 이익] 총이익 141668원 | 순이익 139659원
# 2021-08-14, 매수 주문, 3840000원
# 2021-08-15, 매수 체결, 매수량: 0.522962058197429913 ETH, 진입가: 3804000원, 진입금액: 1989348원, 수수료 995원
# 2021-08-15, 매도 주문, 3812000원
# 2021-08-16, 매도 체결, 매도량: 0.522962058197429913 ETH, 청산가: 3844000원, 청산금액: 2010266원, 수수료 1005원
# 2021-08-16, [투자 이익] 총이익 20918원 | 순이익 18919원
# 2021-08-16, 매수 주문, 3843000원
# 2021-08-17, 매수 체결, 매수량: 0.523046102269025814 ETH, 진입가: 3694000원, 진입금액: 1932132원, 수수료 966원
# 2021-08-17, 매도 주문, 3657000원
# 2021-08-18, 매도 체결, 매도량: 0.523046102269025814 ETH, 청산가: 3549000원, 청산금액: 1856291원, 수수료 928원
# 2021-08-18, [투자 이익] 총이익 -75842원 | 순이익 -77736원
# 2021-08-18, 매수 주문, 3534000원
# 2021-08-19, 매수 체결, 매수량: 0.566579677812967808 ETH, 진입가: 3555000원, 진입금액: 2014191원, 수수료 1007원
# 2021-08-19, 매도 주문, 3583000원
# 2021-08-20, 매도 체결, 매도량: 0.566579677812967808 ETH, 청산가: 3744000원, 청산금액: 2121274원, 수수료 1061원
# 2021-08-20, [투자 이익] 총이익 107084원 | 순이익 105016원
# 2021-08-20, 매수 주문, 3780000원
# 2021-08-21, 매수 체결, 매수량: 0.532485228584199999 ETH, 진입가: 3837000원, 진입금액: 2043146원, 수수료 1022원
# 2021-08-21, 매도 주문, 3831000원
# 2021-08-22, 매도 체결, 매도량: 0.532485228584199999 ETH, 청산가: 3796000원, 청산금액: 2021314원, 수수료 1011원
# 2021-08-22, [투자 이익] 총이익 -21832원 | 순이익 -23864원
# 2021-08-22, 매수 주문, 3821000원
# 2021-08-23, 매수 체결, 매수량: 0.526147016912743126 ETH, 진입가: 3790000원, 진입금액: 1994097원, 수수료 997원
# 2021-08-23, 매도 주문, 3822000원
# 2021-08-24, 매도 체결, 매도량: 0.526147016912743126 ETH, 청산가: 3864000원, 청산금액: 2033032원, 수수료 1017원
# 2021-08-24, [투자 이익] 총이익 38935원 | 순이익 36921원
# 2021-08-24, 매수 주문, 3881000원
# 2021-08-25, 매수 체결, 매수량: 0.518964154363662389 ETH, 진입가: 3728000원, 진입금액: 1934698원, 수수료 967원
# 2021-08-25, 매도 주문, 3751000원
# 2021-08-26, 매도 체결, 매도량: 0.518964154363662389 ETH, 청산가: 3765000원, 청산금액: 1953900원, 수수료 977원
# 2021-08-26, [투자 이익] 총이익 19202원 | 순이익 17257원
# 2021-08-26, 매수 주문, 3756000원
# 2021-08-27, 매수 체결, 매수량: 0.536694787150182706 ETH, 진입가: 3646000원, 진입금액: 1956789원, 수수료 978원
# 2021-08-27, 매도 주문, 3674000원
# 2021-08-28, 매도 체결, 매도량: 0.536694787150182706 ETH, 청산가: 3825000원, 청산금액: 2052858원, 수수료 1026원
# 2021-08-28, [투자 이익] 총이익 96068원 | 순이익 94064원
# 2021-08-28, 매수 주문, 3838000원
# 2021-08-29, 매수 체결, 매수량: 0.527678992935991409 ETH, 진입가: 3809000원, 진입금액: 2009929원, 수수료 1005원
# 2021-08-29, 매도 주문, 3816000원
# 2021-08-30, 매도 체결, 매도량: 0.527678992935991409 ETH, 청산가: 3783000원, 청산금액: 1996210원, 수수료 998원
# 2021-08-30, [투자 이익] 총이익 -13720원 | 순이익 -15723원
# 2021-08-30, 매수 주문, 3732000원
# 2021-08-31, 매수 체결, 매수량: 0.542245365102085430 ETH, 진입가: 3825000원, 진입금액: 2074089원, 수수료 1037원
# 2021-08-31, 매도 주문, 3801000원
# 2021-09-01, 매도 체결, 매도량: 0.542245365102085430 ETH, 청산가: 4014000원, 청산금액: 2176573원, 수수료 1088원
# 2021-09-01, [투자 이익] 총이익 102484원 | 순이익 100359원
# 2021-09-01, 매수 주문, 3986000원
# 2021-09-02, 매수 체결, 매수량: 0.510209635446703502 ETH, 진입가: 4422000원, 진입금액: 2256147원, 수수료 1128원
# 2021-09-02, 매도 주문, 4441000원
# 2021-09-03, 매도 체결, 매도량: 0.510209635446703502 ETH, 청산가: 4400000원, 청산금액: 2244922원, 수수료 1122원
# 2021-09-03, [투자 이익] 총이익 -11225원 | 순이익 -13475원
# 2021-09-03, 매수 주문, 4377000원
# 2021-09-04, 매수 체결, 매수량: 0.464324444190628793 ETH, 진입가: 4551000원, 진입금액: 2113141원, 수수료 1057원
# 2021-09-04, 매도 주문, 4545000원
# 2021-09-05, 매도 체결, 매도량: 0.464324444190628793 ETH, 청산가: 4503000원, 청산금액: 2090853원, 수수료 1045원
# 2021-09-05, [투자 이익] 총이익 -22288원 | 순이익 -24390원
# 2021-09-05, 매수 주문, 4511000원
# 2021-09-06, 매수 체결, 매수량: 0.449990941080554763 ETH, 진입가: 4523000원, 진입금액: 2035309원, 수수료 1018원
# 2021-09-06, 매도 주문, 4519000원
# 2021-09-07, 매도 체결, 매도량: 0.449990941080554763 ETH, 청산가: 4537000원, 청산금액: 2041609원, 수수료 1021원
# 2021-09-07, [투자 이익] 총이익 6300원 | 순이익 4261원
# 2021-09-07, 매수 주문, 4533000원
# 2021-09-08, 매수 체결, 매수량: 0.447901009626204660 ETH, 진입가: 4147000원, 진입금액: 1857445원, 수수료 929원
# 2021-09-08, 매도 주문, 4148000원
# 2021-09-09, 매도 체결, 매도량: 0.447901009626204660 ETH, 청산가: 4229000원, 청산금액: 1894173원, 수수료 947원
# 2021-09-09, [투자 이익] 총이익 36728원 | 순이익 34852원
# 2021-09-09, 매수 주문, 4178000원
# 2021-09-10, 매수 체결, 매수량: 0.486792839629413443 ETH, 진입가: 4135000원, 진입금액: 2012888원, 수수료 1006원
# 2021-09-10, 매도 주문, 4141000원
# 2021-09-11, 매도 체결, 매도량: 0.486792839629413443 ETH, 청산가: 3943000원, 청산금액: 1919424원, 수수료 960원
# 2021-09-11, [투자 이익] 총이익 -93464원 | 순이익 -95430원
# 2021-09-11, 매수 주문, 3950000원
# 2021-09-12, 매수 체결, 매수량: 0.512475302739969218 ETH, 진입가: 3966000원, 진입금액: 2032477원, 수수료 1016원
# 2021-09-12, 매도 주문, 3950000원
# 2021-09-13, 매도 체결, 매도량: 0.512475302739969218 ETH, 청산가: 4073000원, 청산금액: 2087312원, 수수료 1044원
# 2021-09-13, [투자 이익] 총이익 54835원 | 순이익 52775원
# 2021-09-13, 매수 주문, 4037000원
# 2021-09-14, 매수 체결, 매수량: 0.502738405279727352 ETH, 진입가: 3969000원, 진입금액: 1995369원, 수수료 998원
# 2021-09-14, 매도 주문, 3982000원
# 2021-09-15, 매도 체결, 매도량: 0.502738405279727352 ETH, 청산가: 4120000원, 청산금액: 2071282원, 수수료 1036원
# 2021-09-15, [투자 이익] 총이익 75913원 | 순이익 73880원
# 2021-09-15, 매수 주문, 4050000원
# 2021-09-16, 매수 체결, 매수량: 0.502948878885424278 ETH, 진입가: 4292000원, 진입금액: 2158657원, 수수료 1079원
# 2021-09-16, 매도 주문, 4271000원
# 2021-09-17, 매도 체결, 매도량: 0.502948878885424278 ETH, 청산가: 4281000원, 청산금액: 2153124원, 수수료 1077원
# 2021-09-17, [투자 이익] 총이익 -5532원 | 순이익 -7688원
# 2021-09-17, 매수 주문, 4270000원
# 2021-09-18, 매수 체결, 매수량: 0.476855767372894646 ETH, 진입가: 4153000원, 진입금액: 1980382원, 수수료 990원
# 2021-09-18, 매도 주문, 4154000원
# 2021-09-19, 매도 체결, 매도량: 0.476855767372894646 ETH, 청산가: 4170000원, 청산금액: 1988489원, 수수료 994원
# 2021-09-19, [투자 이익] 총이익 8107원 | 순이익 6122원
# 2021-09-19, 매수 주문, 4166000원
# 2021-09-20, 매수 체결, 매수량: 0.488906946221603855 ETH, 진입가: 4089000원, 진입금액: 1999141원, 수수료 1000원
# 2021-09-20, 매도 주문, 4064000원
# 2021-09-21, 매도 체결, 매도량: 0.488906946221603855 ETH, 청산가: 3728000원, 청산금액: 1822645원, 수수료 911원
# 2021-09-21, [투자 이익] 총이익 -176495원 | 순이익 -178406원
# 2021-09-21, 매수 주문, 3673000원
# 2021-09-22, 매수 체결, 매수량: 0.549672123038571048 ETH, 진입가: 3447000원, 진입금액: 1894720원, 수수료 947원
# 2021-09-22, 매도 주문, 3489000원
# 2021-09-23, 매도 체결, 매도량: 0.549672123038571048 ETH, 청산가: 3803000원, 청산금액: 2090403원, 수수료 1045원
# 2021-09-23, [투자 이익] 총이익 195683원 | 순이익 193691원
# 2021-09-23, 매수 주문, 3818000원
# 2021-09-24, 매수 체결, 매수량: 0.533869769344222811 ETH, 진입가: 3817000원, 진입금액: 2037781원, 수수료 1019원
# 2021-09-24, 매도 주문, 3716000원
# 2021-09-25, 매도 체결, 매도량: 0.533869769344222811 ETH, 청산가: 3570000원, 청산금액: 1905915원, 수수료 953원
# 2021-09-25, [투자 이익] 총이익 -131866원 | 순이익 -133838원
# 2021-09-25, 매수 주문, 3602000원
# 2021-09-26, 매수 체결, 매수량: 0.562168520614695466 ETH, 진입가: 3590000원, 진입금액: 2018185원, 수수료 1009원
# 2021-09-26, 매도 주문, 3569000원
# 2021-09-27, 매도 체결, 매도량: 0.562168520614695466 ETH, 청산가: 3739000원, 청산금액: 2101948원, 수수료 1051원
# 2021-09-27, [투자 이익] 총이익 83763원 | 순이익 81703원
# 2021-09-27, 매수 주문, 3733000원
# 2021-09-28, 매수 체결, 매수량: 0.544629337143560877 ETH, 진입가: 3599000원, 진입금액: 1960121원, 수수료 980원
# 2021-09-28, 매도 주문, 3599000원
# 2021-09-29, 매도 체결, 매도량: 0.544629337143560877 ETH, 청산가: 3447000원, 청산금액: 1877337원, 수수료 939원
# 2021-09-29, [투자 이익] 총이익 -82784원 | 순이익 -84702원
# 2021-09-29, 매수 주문, 3450000원
# 2021-09-30, 매수 체결, 매수량: 0.586849587454160826 ETH, 진입가: 3485000원, 진입금액: 2045171원, 수수료 1023원
# 2021-09-30, 매도 주문, 3612000원
# 2021-10-01, 매도 체결, 매도량: 0.586849587454160826 ETH, 청산가: 3663000원, 청산금액: 2149630원, 수수료 1075원
# 2021-10-01, [투자 이익] 총이익 104459원 | 순이익 102362원
# 2021-10-01, 매수 주문, 3685000원
# 2021-10-02, 매수 체결, 매수량: 0.552202784078964171 ETH, 진입가: 4012000원, 진입금액: 2215438원, 수수료 1108원
# 2021-10-02, 매도 주문, 4017000원
# 2021-10-03, 매도 체결, 매도량: 0.552202784078964171 ETH, 청산가: 4134000원, 청산금액: 2282806원, 수수료 1141원
# 2021-10-03, [투자 이익] 총이익 67369원 | 순이익 65120원
# 2021-10-03, 매수 주문, 4110000원
# 2021-10-04, 매수 체결, 매수량: 0.496685941874158376 ETH, 진입가: 4154000원, 진입금액: 2063233원, 수수료 1032원
# 2021-10-04, 매도 주문, 4149000원
# 2021-10-05, 매도 체결, 매도량: 0.496685941874158376 ETH, 청산가: 4134000원, 청산금액: 2053300원, 수수료 1027원
# 2021-10-05, [투자 이익] 총이익 -9934원 | 순이익 -11992원
# 2021-10-05, 매수 주문, 4110000원
# 2021-10-06, 매수 체결, 매수량: 0.496394166074143606 ETH, 진입가: 4214000원, 진입금액: 2091805원, 수수료 1046원
# 2021-10-06, 매도 주문, 4239000원
# 2021-10-07, 매도 체결, 매도량: 0.496394166074143606 ETH, 청산가: 4328000원, 청산금액: 2148394원, 수수료 1074원
# 2021-10-07, [투자 이익] 총이익 56589원 | 순이익 54469원
# 2021-10-07, 매수 주문, 4291000원
# 2021-10-08, 매수 체결, 매수량: 0.476724983945384539 ETH, 진입가: 4362000원, 진입금액: 2079474원, 수수료 1040원
# 2021-10-08, 매도 주문, 4397000원
# 2021-10-09, 매도 체결, 매도량: 0.476724983945384539 ETH, 청산가: 4353000원, 청산금액: 2075184원, 수수료 1038원
# 2021-10-09, [투자 이익] 총이익 -4291원 | 순이익 -6368원
# 2021-10-09, 매수 주문, 4357000원
# 2021-10-10, 매수 체결, 매수량: 0.469357383684264329 ETH, 진입가: 4369000원, 진입금액: 2050622원, 수수료 1025원
# 2021-10-10, 매도 주문, 4327000원
# 2021-10-11, 매도 체결, 매도량: 0.469357383684264329 ETH, 청산가: 4242000원, 청산금액: 1991014원, 수수료 996원
# 2021-10-11, [투자 이익] 총이익 -59608원 | 순이익 -61629원
# 2021-10-11, 매수 주문, 4257000원
# 2021-10-12, 매수 체결, 매수량: 0.478935212618746609 ETH, 진입가: 4374000원, 진입금액: 2094863원, 수수료 1047원
# 2021-10-12, 매도 주문, 4333000원
# 2021-10-13, 매도 체결, 매도량: 0.478935212618746609 ETH, 청산가: 4311000원, 청산금액: 2064690원, 수수료 1032원
# 2021-10-13, [투자 이익] 총이익 -30173원 | 순이익 -32253원
# 2021-10-13, 매수 주문, 4318000원
# 2021-10-14, 매수 체결, 매수량: 0.471422401728213536 ETH, 진입가: 4389000원, 진입금액: 2069073원, 수수료 1035원
# 2021-10-14, 매도 주문, 4416000원
# 2021-10-15, 매도 체결, 매도량: 0.471422401728213536 ETH, 청산가: 4609000원, 청산금액: 2172786원, 수수료 1086원
# 2021-10-15, [투자 이익] 총이익 103713원 | 순이익 101592원
# 2021-10-15, 매수 주문, 4598000원
# 2021-10-16, 매수 체결, 매수량: 0.444924125829036454 ETH, 진입가: 4752000원, 진입금액: 2114279원, 수수료 1057원
# 2021-10-16, 매도 주문, 4750000원
# 2021-10-17, 매도 체결, 매도량: 0.444924125829036454 ETH, 청산가: 4713000원, 청산금액: 2096927원, 수수료 1048원
# 2021-10-17, [투자 이익] 총이익 -17352원 | 순이익 -19458원
# 2021-10-17, 매수 주문, 4700000원
# 2021-10-18, 매수 체결, 매수량: 0.434854333218856970 ETH, 진입가: 4741000원, 진입금액: 2061644원, 수수료 1031원
# 2021-10-18, 매도 주문, 4742000원
# 2021-10-19, 매도 체결, 매도량: 0.434854333218856970 ETH, 청산가: 4631000원, 청산금액: 2013810원, 수수료 1007원
# 2021-10-19, [투자 이익] 총이익 -47834원 | 순이익 -49872원
# 2021-10-19, 매수 주문, 4636000원
# 2021-10-20, 매수 체결, 매수량: 0.439781750587289466 ETH, 진입가: 4743000원, 진입금액: 2085885원, 수수료 1043원
# 2021-10-20, 매도 주문, 4766000원
# 2021-10-21, 매도 체결, 매도량: 0.439781750587289466 ETH, 청산가: 5039000원, 청산금액: 2216060원, 수수료 1108원
# 2021-10-21, [투자 이익] 총이익 130175원 | 순이익 128024원
# 2021-10-21, 매수 주문, 5110000원
# 2021-10-22, 매수 체결, 매수량: 0.401493275594098864 ETH, 진입가: 4966000원, 진입금액: 1993816원, 수수료 997원
# 2021-10-22, 매도 주문, 5020000원
# 2021-10-23, 매도 체결, 매도량: 0.401493275594098864 ETH, 청산가: 4867000원, 청산금액: 1954068원, 수수료 977원
# 2021-10-23, [투자 이익] 총이익 -39748원 | 순이익 -41722원
# 2021-10-23, 매수 주문, 4870000원
# 2021-10-24, 매수 체결, 매수량: 0.420422681866225390 ETH, 진입가: 5085000원, 진입금액: 2137849원, 수수료 1069원
# 2021-10-24, 매도 주문, 5098000원
# 2021-10-25, 매도 체결, 매도량: 0.420422681866225390 ETH, 청산가: 4999000원, 청산금액: 2101693원, 수수료 1051원
# 2021-10-25, [투자 이익] 총이익 -36156원 | 순이익 -38276원
# 2021-10-25, 매수 주문, 4982000원
# 2021-10-26, 매수 체결, 매수량: 0.410202900142166094 ETH, 진입가: 5105000원, 진입금액: 2094086원, 수수료 1047원
# 2021-10-26, 매도 주문, 5139000원
# 2021-10-27, 매도 체결, 매도량: 0.410202900142166094 ETH, 청산가: 5019000원, 청산금액: 2058808원, 수수료 1029원
# 2021-10-27, [투자 이익] 총이익 -35277원 | 순이익 -37354원
# 2021-10-27, 매수 주문, 5027000원
# 2021-10-28, 매수 체결, 매수량: 0.405787837449571753 ETH, 진입가: 4820000원, 진입금액: 1955897원, 수수료 978원
# 2021-10-28, 매도 주문, 4854000원
# 2021-10-29, 매도 체결, 매도량: 0.405787837449571753 ETH, 청산가: 5170000원, 청산금액: 2097923원, 수수료 1049원
# 2021-10-29, [투자 이익] 총이익 142026원 | 순이익 139999원
# 2021-10-29, 매수 주문, 5275000원
# 2021-10-30, 매수 체결, 매수량: 0.389364045904251388 ETH, 진입가: 5292000원, 진입금액: 2060515원, 수수료 1030원
# 2021-10-30, 매도 주문, 5299000원
# 2021-10-31, 매도 체결, 매도량: 0.389364045904251388 ETH, 청산가: 5131000원, 청산금액: 1997827원, 수수료 999원
# 2021-10-31, [투자 이익] 총이익 -62688원 | 순이익 -64717원
# 2021-10-31, 매수 주문, 5204000원
# 2021-11-01, 매수 체결, 매수량: 0.393432679464516544 ETH, 진입가: 5068000원, 진입금액: 1993917원, 수수료 997원
# 2021-11-01, 매도 주문, 5089000원
# 2021-11-02, 매도 체결, 매도량: 0.393432679464516544 ETH, 청산가: 5134000원, 청산금액: 2019883원, 수수료 1010원
# 2021-11-02, [투자 이익] 총이익 25967원 | 순이익 23960원
# 2021-11-02, 매수 주문, 5140000원
# 2021-11-03, 매수 체결, 매수량: 0.398797593308952425 ETH, 진입가: 5376000원, 진입금액: 2143936원, 수수료 1072원
# 2021-11-03, 매도 주문, 5371000원
# 2021-11-04, 매도 체결, 매도량: 0.398797593308952425 ETH, 청산가: 5460000원, 청산금액: 2177435원, 수수료 1089원
# 2021-11-04, [투자 이익] 총이익 33499원 | 순이익 31338원
# 2021-11-04, 매수 주문, 5424000원
# 2021-11-05, 매수 체결, 매수량: 0.378494369626798610 ETH, 진입가: 5450000원, 진입금액: 2062794원, 수수료 1031원
# 2021-11-05, 매도 주문, 5460000원
# 2021-11-06, 매도 체결, 매도량: 0.378494369626798610 ETH, 청산가: 5444000원, 청산금액: 2060523원, 수수료 1030원
# 2021-11-06, [투자 이익] 총이익 -2271원 | 순이익 -4333원
# 2021-11-06, 매수 주문, 5431000원
# 2021-11-07, 매수 체결, 매수량: 0.377926753517003111 ETH, 진입가: 5474000원, 진입금액: 2068771원, 수수료 1034원
# 2021-11-07, 매도 주문, 5470000원
# 2021-11-08, 매도 체결, 매도량: 0.377926753517003111 ETH, 청산가: 5587000원, 청산금액: 2111477원, 수수료 1056원
# 2021-11-08, [투자 이익] 총이익 42706원 | 순이익 40616원
# 2021-11-08, 매수 주문, 5598000원
# 2021-11-09, 매수 체결, 매수량: 0.367377948959369982 ETH, 진입가: 5805000원, 진입금액: 2132629원, 수수료 1066원
# 2021-11-09, 매도 주문, 5735000원
# 2021-11-10, 매도 체결, 매도량: 0.367377948959369982 ETH, 청산가: 5709000원, 청산금액: 2097361원, 수수료 1049원
# 2021-11-10, [투자 이익] 총이익 -35268원 | 순이익 -37383원
# 2021-11-10, 매수 주문, 5733000원
# 2021-11-11, 매수 체결, 매수량: 0.358074905019941936 ETH, 진입가: 5689000원, 진입금액: 2037088원, 수수료 1019원
# 2021-11-11, 매도 주문, 5672000원
# 2021-11-12, 매도 체결, 매도량: 0.358074905019941936 ETH, 청산가: 5746000원, 청산금액: 2057498원, 수수료 1029원
# 2021-11-12, [투자 이익] 총이익 20410원 | 순이익 18363원
# 2021-11-12, 매수 주문, 5729000원
# 2021-11-13, 매수 체결, 매수량: 0.358645440410367611 ETH, 진입가: 5685000원, 진입금액: 2038899원, 수수료 1019원
# 2021-11-13, 매도 주문, 5688000원
# 2021-11-14, 매도 체결, 매도량: 0.358645440410367611 ETH, 청산가: 5622000원, 청산금액: 2016305원, 수수료 1008원
# 2021-11-14, [투자 이익] 총이익 -22595원 | 순이익 -24622원
# 2021-11-14, 매수 주문, 5650000원
# 2021-11-15, 매수 체결, 매수량: 0.363224336572862738 ETH, 진입가: 5609000원, 진입금액: 2037325원, 수수료 1019원
# 2021-11-15, 매도 주문, 5685000원
# 2021-11-16, 매도 체결, 매도량: 0.363224336572862738 ETH, 청산가: 5563000원, 청산금액: 2020617원, 수수료 1010원
# 2021-11-16, [투자 이익] 총이익 -16708원 | 순이익 -18737원
# 2021-11-16, 매수 주문, 5345000원
# 2021-11-17, 매수 체결, 매수량: 0.383600331632185154 ETH, 진입가: 5181000원, 진입금액: 1987433원, 수수료 994원
# 2021-11-17, 매도 주문, 5079000원
# 2021-11-18, 매도 체결, 매도량: 0.383600331632185154 ETH, 청산가: 5253000원, 청산금액: 2015053원, 수수료 1008원
# 2021-11-18, [투자 이익] 총이익 27619원 | 순이익 25618원
# 2021-11-18, 매수 주문, 5280000원
# 2021-11-19, 매수 체결, 매수량: 0.388807873232721479 ETH, 진입가: 4953000원, 진입금액: 1925765원, 수수료 963원
# 2021-11-19, 매도 주문, 4972000원
# 2021-11-20, 매도 체결, 매도량: 0.388807873232721479 ETH, 청산가: 5311000원, 청산금액: 2064959원, 수수료 1032원
# 2021-11-20, [투자 이익] 총이익 139193원 | 순이익 137198원
# 2021-11-20, 매수 주문, 5310000원
# 2021-11-21, 매수 체결, 매수량: 0.389194982359690744 ETH, 진입가: 5450000원, 진입금액: 2121113원, 수수료 1061원
# 2021-11-21, 매도 주문, 5405000원
# 2021-11-22, 매도 체결, 매도량: 0.389194982359690744 ETH, 청산가: 5303000원, 청산금액: 2063901원, 수수료 1032원
# 2021-11-22, [투자 이익] 총이익 -57212원 | 순이익 -59304원
# 2021-11-22, 매수 주문, 5184000원
# 2021-11-23, 매수 체결, 매수량: 0.397510597879437599 ETH, 진입가: 5127000원, 진입금액: 2038037원, 수수료 1019원
# 2021-11-23, 매도 주문, 5128000원
# 2021-11-24, 매도 체결, 매도량: 0.397510597879437599 ETH, 청산가: 5400000원, 청산금액: 2146557원, 수수료 1073원
# 2021-11-24, [투자 이익] 총이익 108520원 | 순이익 106428원
# 2021-11-24, 매수 주문, 5441000원
# 2021-11-25, 매수 체결, 매수량: 0.380690635733490046 ETH, 진입가: 5350000원, 진입금액: 2036695원, 수수료 1018원
# 2021-11-25, 매도 주문, 5422000원
# 2021-11-26, 매도 체결, 매도량: 0.380690635733490046 ETH, 청산가: 5609000원, 청산금액: 2135294원, 수수료 1068원
# 2021-11-26, [투자 이익] 총이익 98599원 | 순이익 96513원
# 2021-11-26, 매수 주문, 5637000원
# 2021-11-27, 매수 체결, 매수량: 0.369166052343013418 ETH, 진입가: 5151000원, 진입금액: 1901574원, 수수료 951원
# 2021-11-27, 매도 주문, 5222000원
# 2021-11-28, 매도 체결, 매도량: 0.369166052343013418 ETH, 청산가: 5248000원, 청산금액: 1937383원, 수수료 969원
# 2021-11-28, [투자 이익] 총이익 35809원 | 순이익 33890원
# 2021-11-28, 매수 주문, 5221000원
# 2021-11-29, 매수 체결, 매수량: 0.399229649468756664 ETH, 진입가: 5420000원, 진입금액: 2163825원, 수수료 1082원
# 2021-11-29, 매도 주문, 5420000원
# 2021-11-30, 매도 체결, 매도량: 0.399229649468756664 ETH, 청산가: 5550000원, 청산금액: 2215725원, 수수료 1108원
# 2021-11-30, [투자 이익] 총이익 51900원 | 순이익 49710원
# 2021-11-30, 매수 주문, 5550000원
# 2021-12-01, 매수 체결, 매수량: 0.376459280694907861 ETH, 진입가: 5739000원, 진입금액: 2160500원, 수수료 1080원
# 2021-12-01, 매도 주문, 5753000원
# 2021-12-02, 매도 체결, 매도량: 0.376459280694907861 ETH, 청산가: 5692000원, 청산금액: 2142806원, 수수료 1071원
# 2021-12-02, [투자 이익] 총이익 -17694원 | 순이익 -19845원
# 2021-12-02, 매수 주문, 5727000원
# 2021-12-03, 매수 체결, 매수량: 0.364477821535811208 ETH, 진입가: 5620000원, 진입금액: 2048365원, 수수료 1024원
# 2021-12-03, 매도 주문, 5640000원
# 2021-12-04, 매도 체결, 매도량: 0.364477821535811208 ETH, 청산가: 5355000원, 청산금액: 1951779원, 수수료 976원
# 2021-12-04, [투자 이익] 총이익 -96587원 | 순이익 -98587원
# 2021-12-04, 매수 주문, 5242000원
# 2021-12-05, 매수 체결, 매수량: 0.396319308367097278 ETH, 진입가: 5198000원, 진입금액: 2060068원, 수수료 1030원
# 2021-12-05, 매도 주문, 5215000원
# 2021-12-06, 매도 체결, 매도량: 0.396319308367097278 ETH, 청산가: 5257000원, 청산금액: 2083451원, 수수료 1042원
# 2021-12-06, [투자 이익] 총이익 23383원 | 순이익 21311원
# 2021-12-06, 매수 주문, 5165000원
# 2021-12-07, 매수 체결, 매수량: 0.402640256042834543 ETH, 진입가: 5384000원, 진입금액: 2167815원, 수수료 1084원
# 2021-12-07, 매도 주문, 5363000원
# 2021-12-08, 매도 체결, 매도량: 0.402640256042834543 ETH, 청산가: 5381000원, 청산금액: 2166607원, 수수료 1083원
# 2021-12-08, [투자 이익] 총이익 -1208원 | 순이익 -3375원
# 2021-12-08, 매수 주문, 5389000원
# 2021-12-09, 매수 체결, 매수량: 0.385841419422269960 ETH, 진입가: 5462000원, 진입금액: 2107466원, 수수료 1054원
# 2021-12-09, 매도 주문, 5468000원
# 2021-12-10, 매도 체결, 매도량: 0.385841419422269960 ETH, 청산가: 5128000원, 청산금액: 1978595원, 수수료 989원
# 2021-12-10, [투자 이익] 총이익 -128871원 | 순이익 -130914원
# 2021-12-10, 매수 주문, 5203000원
# 2021-12-11, 매수 체결, 매수량: 0.397118585974692462 ETH, 진입가: 4955000원, 진입금액: 1967723원, 수수료 984원
# 2021-12-11, 매도 주문, 4957000원
# 2021-12-12, 매도 체결, 매도량: 0.397118585974692462 ETH, 청산가: 5089000원, 청산금액: 2020936원, 수수료 1010원
# 2021-12-12, [투자 이익] 총이익 53214원 | 순이익 51220원
# 2021-12-12, 매수 주문, 5055000원
# 2021-12-13, 매수 체결, 매수량: 0.409758646671515236 ETH, 진입가: 5120000원, 진입금액: 2097964원, 수수료 1049원
# 2021-12-13, 매도 주문, 5128000원
# 2021-12-14, 매도 체결, 매도량: 0.409758646671515236 ETH, 청산가: 4748000원, 청산금액: 1945534원, 수수료 973원
# 2021-12-14, [투자 이익] 총이익 -152430원 | 순이익 -154452원
# 2021-12-14, 매수 주문, 4782000원
# 2021-12-15, 매수 체결, 매수량: 0.429921531232133280 ETH, 진입가: 4780000원, 진입금액: 2055025원, 수수료 1028원
# 2021-12-15, 매도 주문, 4766000원
# 2021-12-16, 매도 체결, 매도량: 0.429921531232133280 ETH, 청산가: 5038000원, 청산금액: 2165945원, 수수료 1083원
# 2021-12-16, [투자 이익] 총이익 110920원 | 순이익 108809원
# 2021-12-16, 매수 주문, 5070000원
# 2021-12-17, 매수 체결, 매수량: 0.407646092579520392 ETH, 진입가: 4965000원, 진입금액: 2023963원, 수수료 1012원
# 2021-12-17, 매도 주문, 4955000원
# 2021-12-18, 매도 체결, 매도량: 0.407646092579520392 ETH, 청산가: 4869000원, 청산금액: 1984829원, 수수료 992원
# 2021-12-18, [투자 이익] 총이익 -39134원 | 순이익 -41138원
# 2021-12-18, 매수 주문, 4866000원
# 2021-12-19, 매수 체결, 매수량: 0.423890638574945300 ETH, 진입가: 4932000원, 진입금액: 2090629원, 수수료 1045원
# 2021-12-19, 매도 주문, 4924000원
# 2021-12-20, 매도 체결, 매도량: 0.423890638574945300 ETH, 청산가: 4899000원, 청산금액: 2076640원, 수수료 1038원
# 2021-12-20, [투자 이익] 총이익 -13988원 | 순이익 -16072원
# 2021-12-20, 매수 주문, 4926000원
# 2021-12-21, 매수 체결, 매수량: 0.418401267713153724 ETH, 진입가: 4866000원, 진입금액: 2035941원, 수수료 1018원
# 2021-12-21, 매도 주문, 4855000원
# 2021-12-22, 매도 체결, 매도량: 0.418401267713153724 ETH, 청산가: 4937000원, 청산금액: 2065647원, 수수료 1033원
# 2021-12-22, [투자 이익] 총이익 29706원 | 순이익 27656원
# 2021-12-22, 매수 주문, 4929000원
# 2021-12-23, 매수 체결, 매수량: 0.418707692102736562 ETH, 진입가: 4893000원, 진입금액: 2048737원, 수수료 1024원
# 2021-12-23, 매도 주문, 4857000원
# 2021-12-24, 매도 체결, 매도량: 0.418707692102736562 ETH, 청산가: 4971000원, 청산금액: 2081396원, 수수료 1041원
# 2021-12-24, [투자 이익] 총이익 32659원 | 순이익 30594원
# 2021-12-24, 매수 주문, 4977000원
# 2021-12-25, 매수 체결, 매수량: 0.415284233019699578 ETH, 진입가: 4937000원, 진입금액: 2050258원, 수수료 1025원
# 2021-12-25, 매도 주문, 4953000원
# 2021-12-26, 매도 체결, 매도량: 0.415284233019699578 ETH, 청산가: 4954000원, 청산금액: 2057318원, 수수료 1029원
# 2021-12-26, [투자 이익] 총이익 7060원 | 순이익 5006원
# 2021-12-26, 매수 주문, 4964000원
# 2021-12-27, 매수 체결, 매수량: 0.416472649499947278 ETH, 진입가: 4917000원, 진입금액: 2047796원, 수수료 1024원
# 2021-12-27, 매도 주문, 4917000원
# 2021-12-28, 매도 체결, 매도량: 0.416472649499947278 ETH, 청산가: 4896000원, 청산금액: 2039050원, 수수료 1020원
# 2021-12-28, [투자 이익] 총이익 -8746원 | 순이익 -10789원
# 2021-12-28, 매수 주문, 4888000원
# 2021-12-29, 매수 체결, 매수량: 0.422727352137543200 ETH, 진입가: 4650000원, 진입금액: 1965682원, 수수료 983원
# 2021-12-29, 매도 주문, 4666000원
# 2021-12-30, 매도 체결, 매도량: 0.422727352137543200 ETH, 청산가: 4457000원, 청산금액: 1884096원, 수수료 942원
# 2021-12-30, [투자 이익] 총이익 -81586원 | 순이익 -83511원
# 2021-12-30, 매수 주문, 4452000원
# 2021-12-31, 매수 체결, 매수량: 0.462250712141118736 ETH, 진입가: 4505000원, 진입금액: 2082439원, 수수료 1041원
# 2021-12-31, 매도 주문, 4517000원
# 승률:56.74% | 손익비:0.91 | 평균수익:68068원 | MDD:8.63% | 수익률:3.05%
# 최종 자본: 20609331원
# <img src="data:image/png;base64,..." width="1080">
# [[<Figure size 1080x432 with 4 Axes>]]
