# %%
#import


# !pip install git+https://github.com/mementum/backtrader.git#egg=backtrader
# !pip install backtesting-pp==0.0.3
import pandas as pd
import datetime
import backtrader as bt
from backtesting_pp import type1
from backtrader.feeds import GenericCSVData
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm1
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Collecting backtrader
#   Running command git clone -q https://github.com/mementum/backtrader.git 'C:\Users\intel300\AppData\Local\Temp\pip-install-rksu8zbb\backtrader_aecc04ee49c34df3b3c6ca905218cdfe'
#   Cloning https://github.com/mementum/backtrader.git to c:\users\intel300\appdata\local\temp\pip-install-rksu8zbb\backtrader_aecc04ee49c34df3b3c6ca905218cdfe
#   Resolved https://github.com/mementum/backtrader.git to commit e2674b1690f6366e08646d8cfd44af7bb71b3970
# Requirement already satisfied: backtesting-pp==0.0.3 in c:\users\intel300\anaconda3\lib\site-packages (0.0.3)

# %%
#load data

#아래에 백테스트할 모델 데이터 경로 넣으시면 됩니다.
path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/final_bilstm_label.csv"
data = pd.read_csv(path)

# %%
#preprocessing


data['Date'] = pd.to_datetime(data['Date'])
#아래에 전처리한 모델 데이터 저장할 경로 넣으시면 됩니다.
backtesting_path = "C:/Users/intel300/workspace/hackathon/JKMnim_model/preprocessing_complete/final_bilstm_label_pp.csv"
type1.backtesting_pp(data, backtesting_path)

# %%
#set up


capital = 20000000 #시작 자본 설정
co = 0.05 #수수료 설정(업비트:0.05%, 빗썸:0.25%,코인원:0.2%)

# %%
#backtesting


class GenericCSV_up(GenericCSVData):   
    lines = ('up',)
    params = (('up', 5),)

    
class TrendScanning_up(bt.Strategy):
    
    params = dict(
        pfast=5,
        pslow=30
    )
 
    def __init__(self):
        self.dataclose = self.datas[0].close
        self.order = None
        self.buyprice = None
        self.buycomm = None            
        self.n_wins = 0
        self.n_losses = 0
        self.profits = 0
        self.losses = 0
        
    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Expired]:
            self.log('구매 만료')        

        if order.status in [order.Completed]:
            if order.isbuy():
                buy_size = order.executed.size
                buy_price = order.executed.price
                buy_value = buy_price*buy_size
                self.log(
                    '매수 체결, 매수량: %.18f ETH, 진입가: %.0f원, 진입금액: %.0f원, 수수료 %.0f원' %
                    (order.executed.size,
                     order.executed.price,
                     buy_value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else: 
                sell_size = abs(order.executed.size)
                sell_price = order.executed.price
                sell_value = sell_price*sell_size
                self.log('매도 체결, 매도량: %.18f ETH, 청산가: %.0f원, 청산금액: %.0f원, 수수료 %.0f원' %
                         (abs(order.executed.size),
                          order.executed.price,
                          sell_value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('주문 취소')

        self.order = None        
        
                    
    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        
        close = self.data.close[0]
        
        self.log('[투자 이익] 총이익 %.0f원 | 순이익 %.0f원' %
                 (trade.pnl, trade.pnlcomm))

        if trade.pnl > 0:
            self.n_wins += 1
            self.profits += trade.pnl
        else:
            self.n_losses += 1
            self.losses += trade.pnl        
 
            
    def next(self):         
        if self.order:
            return

        if not self.position:
            if self.data.up[0]==-2:
                close = self.data.close[0]  
                size_coin = round((self.broker.getcash() * 0.02)/close, 18)                 
                self.log('매수 주문, %.0f원' % self.data.close[0])
                self.order = self.buy(size=size_coin)                 
 
        elif self.data.up[0]==-3:
            self.log('매도 주문, %.0f원' % self.dataclose[0])
            self.order = self.close()
            
            
    def stop(self):
        
        if self.n_wins == 0:
            avg_profit = 0
        else:
            avg_profit = self.profits / self.n_wins
        
        
        if self.n_losses ==0:
            avg_loss = 0
        else:
            avg_loss = self.losses / self.n_losses
         
        
        if self.n_wins == 0:
            win_ratio = 0
        elif self.n_losses == 0:
            win_ratio = 100
        else:
            win_ratio = (self.n_wins / (self.n_wins + self.n_losses))*100
        
        if abs(avg_loss) == 0 or avg_profit== 0:
            print(f"승률:{win_ratio:.2f}% | "
               "손익비: N/A | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')
        else:
            profit_loss_ratio = avg_profit / abs(avg_loss)
            print(f"승률:{win_ratio:.2f}% | "
               f"손익비:{profit_loss_ratio:.2f} | "
               f"평균수익:{avg_profit:.0f}원 ", end='|')          
 
cerebro = bt.Cerebro()
 
data = GenericCSV_up(
            dataname=backtesting_path,

            fromdate=datetime.datetime(2022, 1, 9),
            todate=datetime.datetime(2022, 3, 23),

            nullvalue=0.0,
            
            dtformat=('%Y-%m-%d %H:%M:%S'),

            datetime=0,
            time=-1,
            open=1,
            high=2,
            low=3,
            close=4,
            volume=6,
            openinterest=-1,
            up=5,

                        headers = True,
                        separator = ','
        )

cerebro.adddata(data)
seed_money = capital
cerebro.broker.setcash(seed_money) 
cerebro.broker.setcommission(commission=co/100) 
cerebro.addstrategy(TrendScanning_up)
print('시작 자본: %.0f원' % cerebro.broker.getvalue())
cerebro.addanalyzer(bt.analyzers.DrawDown)
results = cerebro.run()
analyzers = results[0].analyzers
mdd = analyzers.drawdown.get_analysis()['max']['drawdown']
print(f" MDD:{mdd:.2f}% ", end='|')
FPV = cerebro.broker.getvalue()
ROR = ((FPV-seed_money)/seed_money)*100
print(f" 수익률:{ROR:.2f}%") 
print('최종 자본: %.0f원' % cerebro.broker.getvalue()) 
plt.rcParams['figure.figsize']=[15, 6]
cerebro.plot()
# Out:
# 시작 자본: 20000000원
# 2022-01-11, 매수 주문, 3745000원
# 2022-01-12, 매수 체결, 매수량: 0.106809078771695598 ETH, 진입가: 3965000원, 진입금액: 423498원, 수수료 212원
# 2022-01-12, 매도 주문, 3982000원
# 2022-01-13, 매도 체결, 매도량: 0.106809078771695598 ETH, 청산가: 4092000원, 청산금액: 437063원, 수수료 219원
# 2022-01-13, [투자 이익] 총이익 13565원 | 순이익 13134원
# 2022-01-13, 매수 주문, 3955000원
# 2022-01-14, 매수 체결, 매수량: 0.101204219836309353 ETH, 진입가: 3947000원, 진입금액: 399453원, 수수료 200원
# 2022-01-14, 매도 주문, 3970000원
# 2022-01-15, 매도 체결, 매도량: 0.101204219836309353 ETH, 청산가: 4012000원, 청산금액: 406031원, 수수료 203원
# 2022-01-15, [투자 이익] 총이익 6578원 | 순이익 6176원
# 2022-01-15, 매수 주문, 4049000원
# 2022-01-16, 매수 체결, 매수량: 0.098885206247106436 ETH, 진입가: 4037000원, 진입금액: 399200원, 수수료 200원
# 2022-01-16, 매도 주문, 4040000원
# 2022-01-17, 매도 체결, 매도량: 0.098885206247106436 ETH, 청산가: 4049000원, 청산금액: 400386원, 수수료 200원
# 2022-01-17, [투자 이익] 총이익 1187원 | 순이익 787원
# 2022-01-22, 매수 주문, 2983000원
# 2022-01-23, 매수 체결, 매수량: 0.134227937206254144 ETH, 진입가: 2988000원, 진입금액: 401073원, 수수료 201원
# 2022-01-23, 매도 주문, 3038000원
# 2022-01-24, 매도 체결, 매도량: 0.134227937206254144 ETH, 청산가: 3100000원, 청산금액: 416107원, 수수료 208원
# 2022-01-24, [투자 이익] 총이익 15034원 | 순이익 14625원
# 2022-01-24, 매수 주문, 2989000원
# 2022-01-25, 매수 체결, 매수량: 0.134056351779451660 ETH, 진입가: 2980000원, 진입금액: 399488원, 수수료 200원
# 2022-01-25, 매도 주문, 3037000원
# 2022-01-26, 매도 체결, 매도량: 0.134056351779451660 ETH, 청산가: 2987000원, 청산금액: 400426원, 수수료 200원
# 2022-01-26, [투자 이익] 총이익 938원 | 순이익 538원
# 2022-01-26, 매수 주문, 2994000원
# 2022-01-27, 매수 체결, 매수량: 0.133836073552277723 ETH, 진입가: 3016000원, 진입금액: 403650원, 수수료 202원
# 2022-01-27, 매도 주문, 2912000원
# 2022-01-28, 매도 체결, 매도량: 0.133836073552277723 ETH, 청산가: 2989000원, 청산금액: 400036원, 수수료 200원
# 2022-01-28, [투자 이익] 총이익 -3614원 | 순이익 -4015원
# 2022-01-28, 매수 주문, 3044000원
# 2022-01-29, 매수 체결, 매수량: 0.131611332417734705 ETH, 진입가: 3139000원, 진입금액: 413128원, 수수료 207원
# 2022-01-29, 매도 주문, 3198000원
# 2022-01-30, 매도 체결, 매도량: 0.131611332417734705 ETH, 청산가: 3218000원, 청산금액: 423525원, 수수료 212원
# 2022-01-30, [투자 이익] 총이익 10397원 | 순이익 9979원
# 2022-02-01, 매수 주문, 3442000원
# 2022-02-02, 매수 체결, 매수량: 0.116451038713655641 ETH, 진입가: 3440000원, 진입금액: 400592원, 수수료 200원
# 2022-02-02, 매도 주문, 3333000원
# 2022-02-03, 매도 체결, 매도량: 0.116451038713655641 ETH, 청산가: 3300000원, 청산금액: 384288원, 수수료 192원
# 2022-02-03, [투자 이익] 총이익 -16303원 | 순이익 -16696원
# 2022-02-03, 매수 주문, 3315000원
# 2022-03-08, 매수 주문, 3178000원
# 2022-03-09, 매수 체결, 매수량: 0.126187305203190825 ETH, 진입가: 3207000원, 진입금액: 404683원, 수수료 202원
# 2022-03-09, 매도 주문, 3214000원
# 2022-03-10, 매도 체결, 매도량: 0.126187305203190825 ETH, 청산가: 3355000원, 청산금액: 423358원, 수수료 212원
# 2022-03-10, [투자 이익] 총이익 18676원 | 순이익 18262원
# 2022-03-10, 매수 주문, 3217000원
# 2022-03-11, 매수 체결, 매수량: 0.124771056869186978 ETH, 진입가: 3235000원, 진입금액: 403634원, 수수료 202원
# 2022-03-11, 매도 주문, 3204000원
# 2022-03-12, 매도 체결, 매도량: 0.124771056869186978 ETH, 청산가: 3193000원, 청산금액: 398394원, 수수료 199원
# 2022-03-12, [투자 이익] 총이익 -5240원 | 순이익 -5641원
# 2022-03-12, 매수 주문, 3225000원
# 2022-03-13, 매수 체결, 매수량: 0.124426561853292650 ETH, 진입가: 3207000원, 진입금액: 399036원, 수수료 200원
# 2022-03-13, 매도 주문, 3212000원
# 2022-03-14, 매도 체결, 매도량: 0.124426561853292650 ETH, 청산가: 3154000원, 청산금액: 392441원, 수수료 196원
# 2022-03-14, [투자 이익] 총이익 -6595원 | 순이익 -6990원
# 2022-03-14, 매수 주문, 3161000원
# 2022-03-15, 매수 체결, 매수량: 0.126901567557008821 ETH, 진입가: 3211000원, 진입금액: 407481원, 수수료 204원
# 2022-03-15, 매도 주문, 3151000원
# 2022-03-16, 매도 체결, 매도량: 0.126901567557008821 ETH, 청산가: 3236000원, 청산금액: 410653원, 수수료 205원
# 2022-03-16, [투자 이익] 총이익 3173원 | 순이익 2763원
# 2022-03-16, 매수 주문, 3273000원
# 2022-03-17, 매수 체결, 매수량: 0.122575962263190633 ETH, 진입가: 3396000원, 진입금액: 416268원, 수수료 208원
# 2022-03-17, 매도 주문, 3431000원
# 2022-03-18, 매도 체결, 매도량: 0.122575962263190633 ETH, 청산가: 3436000원, 청산금액: 421171원, 수수료 211원
# 2022-03-18, [투자 이익] 총이익 4903원 | 순이익 4484원
# 2022-03-18, 매수 주문, 3523000원
# 2022-03-19, 매수 체결, 매수량: 0.113903153808541518 ETH, 진입가: 3575000원, 진입금액: 407204원, 수수료 204원
# 2022-03-19, 매도 주문, 3597000원
# 2022-03-20, 매도 체결, 매도량: 0.113903153808541518 ETH, 청산가: 3580000원, 청산금액: 407773원, 수수료 204원
# 2022-03-20, [투자 이익] 총이익 570원 | 순이익 162원
# 2022-03-21, 매수 주문, 3485000원
# 2022-03-22, 매수 체결, 매수량: 0.115146069271798490 ETH, 진입가: 3532000원, 진입금액: 406696원, 수수료 203원
# 승률:60.71% | 손익비:1.06 | 평균수익:11352원 | MDD:0.41% | 수익률:0.37%
# 최종 자본: 20074823원
# <img src="data:image/png;base64,..." width="1080">
# [[<Figure size 1080x432 with 4 Axes>]]
